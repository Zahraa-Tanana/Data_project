# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
from datetime import datetime

# %%
# %matplotlib inline

# %%
plt.rcParams["figure.figsize"] = (10, 5)

# %%
saved_style_state = matplotlib.rcParams.copy()

# %%
Secondary_completion_rates = pd.read_csv("Secondary completion rates.csv", skiprows=1)
print("done")
# Out:
# done

# %%
Secondary_completion_rates.head()
# Out:
#   LOCATION INDICATOR SUBJECT MEASURE FREQUENCY  TIME   Value  Flag Codes
# 0      AUT  GRADRATE  UPPSRY      PC         A  2010  84.210         NaN
# 1      AUT  GRADRATE  UPPSRY      PC         A  2011  83.621         NaN
# 2      AUT  GRADRATE  UPPSRY      PC         A  2012  84.955         NaN
# 3      AUT  GRADRATE  UPPSRY      PC         A  2013  83.765         NaN
# 4      AUT  GRADRATE  UPPSRY      PC         A  2014  83.544         NaN

# %%
Secondary_completion_rates.sample(5)
# Out:
#      LOCATION INDICATOR         SUBJECT MEASURE FREQUENCY  TIME   Value  \
# 856       COL  GRADRATE    UPPSRY_WOMEN      PC         A  2020  80.208
# 63        CAN  GRADRATE      UPPSRY_MEN      PC         A  2014  79.769
# 679       CHE  GRADRATE          UPPSRY      PC         A  2019  83.669
# 793       BRA  GRADRATE      UPPSRY_MEN      PC         A  2018  56.636
# 1009      AUT  GRADRATE  P_SRY_NTRY_MEN      PC         A  2012   1.678
#
#       Flag Codes
# 856          NaN
# 63           NaN
# 679          NaN
# 793          NaN
# 1009         NaN

# %%
Secondary_completion_rates.columns
# Out:
# Index(['LOCATION', 'INDICATOR', 'SUBJECT', 'MEASURE', 'FREQUENCY', 'TIME',
#        'Value', 'Flag Codes'],
#       dtype='object')

# %%
row_one = Secondary_completion_rates.iloc[1]
row_one
# Out:
# LOCATION           AUT
# INDICATOR     GRADRATE
# SUBJECT         UPPSRY
# MEASURE             PC
# FREQUENCY            A
# TIME              2011
# Value           83.621
# Flag Codes         NaN
# Name: 1, dtype: object

# %%
row_one = ["Value"]

# %%
Secondary_completion_rates.Value
# Out:
# 0       84.210
# 1       83.621
# 2       84.955
# 3       83.765
# 4       83.544
#          ...
# 1757    81.416
# 1758    82.614
# 1759    83.794
# 1760    83.810
# 1761    85.871
# Name: Value, Length: 1762, dtype: float64

# %%
# Secondary_completion_rates["Value"].plot()
# Secondary_completion_rates["Value"].plot(x="TIME", y="Value")
Secondary_completion_rates_sorted = Secondary_completion_rates.sort_values(by='LOCATION')
Secondary_completion_rates.plot(x='LOCATION', y='Value')
plt.xlabel("LOCATION")
plt.ylabel("Value")
plt.show()

# %%
# Secondary_completion_rates.Value.hist()
# Secondary_completion_rates.plot(x="LOCATION", y="Value", kind='hist')
Secondary_completion_rates_sorted = Secondary_completion_rates.sort_values(by='LOCATION')
plt.bar(range(len(Secondary_completion_rates_sorted['LOCATION'])), Secondary_completion_rates_sorted['Value'])
step =40
plt.xticks(range(0, len(Secondary_completion_rates_sorted['LOCATION']), step), 
        Secondary_completion_rates_sorted['LOCATION'][::step], rotation=90)
# plt.hist(Secondary_completion_rates_sorted['Value'])
plt.xlabel("LOCATION")
plt.ylabel("Value")
# Out:
# Text(0, 0.5, 'Value')

# %%
Secondary_completion_rates_sorted = Secondary_completion_rates.sort_values(by='LOCATION')
plt.bar(range(len(Secondary_completion_rates_sorted['LOCATION'])), Secondary_completion_rates_sorted['Value'])
step =40
plt.xticks(range(0, len(Secondary_completion_rates_sorted['LOCATION']), step), 
        Secondary_completion_rates_sorted['LOCATION'][::step], rotation=90)
filtered_data = Secondary_completion_rates[Secondary_completion_rates['Value'] >= 50]
filtered_data_sorted = filtered_data.sort_values(by='LOCATION')
plt.bar(range(len(filtered_data_sorted['LOCATION'])), filtered_data_sorted['Value'])
plt.xlabel("LOCATION")
plt.ylabel("Value")
plt.xticks(range(len(filtered_data_sorted['LOCATION'])), filtered_data_sorted['LOCATION'], rotation=90)
# Out:
# ([<matplotlib.axis.XTick at 0x2d4b91f10>,
#   <matplotlib.axis.XTick at 0x2d4b92850>,
#   <matplotlib.axis.XTick at 0x2d5eae590>,
#   <matplotlib.axis.XTick at 0x2d6174dd0>,
#   <matplotlib.axis.XTick at 0x2d6177390>,
#   <matplotlib.axis.XTick at 0x2d617cb90>,
#   <matplotlib.axis.XTick at 0x2d617ecd0>,
#   <matplotlib.axis.XTick at 0x2d6184f50>,
#   <matplotlib.axis.XTick at 0x2d61872d0>,
#   <matplotlib.axis.XTick at 0x2d618d550>,
#   <matplotlib.axis.XTick at 0x2d6184850>,
#   <matplotlib.axis.XTick at 0x2d618ff50>,
#   <matplotlib.axis.XTick at 0x2d6196190>,
#   <matplotlib.axis.XTick at 0x2d61a03d0>,
#   <matplotlib.axis.XTick at 0x2d61a26d0>,
#   <matplotlib.axis.XTick at 0x2d61a4810>,
#   <matplotlib.axis.XTick at 0x2d617d390>,
#   <matplotlib.axis.XTick at 0x2d61a6f50>,
#   <matplotlib.axis.XTick at 0x2d61a91d0>,
#   <matplotlib.axis.XTick at 0x2d61ab450>,
#   <matplotlib.axis.XTick at 0x2d61ad5d0>,
#   <matplotlib.axis.XTick at 0x2d61a67d0>,
#   <matplotlib.axis.XTick at 0x2d61afcd0>,
#   <matplotlib.axis.XTick at 0x2d61b1e50>,
#   <matplotlib.axis.XTick at 0x2d61b8190>,
#   <matplotlib.axis.XTick at 0x2d61ba210>,
#   <matplotlib.axis.XTick at 0x2d61c0410>,
#   <matplotlib.axis.XTick at 0x2d61aacd0>,
#   <matplotlib.axis.XTick at 0x2d61c2890>,
#   <matplotlib.axis.XTick at 0x2d61c8990>,
#   <matplotlib.axis.XTick at 0x2d61cac50>,
#   <matplotlib.axis.XTick at 0x2d61d0d50>,
#   <matplotlib.axis.XTick at 0x2d61c1690>,
#   <matplotlib.axis.XTick at 0x2d61d3310>,
#   <matplotlib.axis.XTick at 0x2d61d9510>,
#   <matplotlib.axis.XTick at 0x2d61db690>,
#   <matplotlib.axis.XTick at 0x2d61dd890>,
#   <matplotlib.axis.XTick at 0x2d61d9cd0>,
#   <matplotlib.axis.XTick at 0x2d61dff90>,
#   <matplotlib.axis.XTick at 0x2d61ee0d0>,
#   <matplotlib.axis.XTick at 0x2d61f0250>,
#   <matplotlib.axis.XTick at 0x2d61f2290>,
#   <matplotlib.axis.XTick at 0x2d61fc610>,
#   <matplotlib.axis.XTick at 0x2d61c9c10>,
#   <matplotlib.axis.XTick at 0x2d61fdb50>,
#   <matplotlib.axis.XTick at 0x2d33a3650>,
#   <matplotlib.axis.XTick at 0x2d6b89810>,
#   <matplotlib.axis.XTick at 0x2d6b89190>,
#   <matplotlib.axis.XTick at 0x2d6b8d2d0>,
#   <matplotlib.axis.XTick at 0x2d6b8f550>,
#   <matplotlib.axis.XTick at 0x2d6b95910>,
#   <matplotlib.axis.XTick at 0x2d6b97990>,
#   <matplotlib.axis.XTick at 0x2d618c2d0>,
#   <matplotlib.axis.XTick at 0x2d6ba27d0>,
#   <matplotlib.axis.XTick at 0x2d6ba47d0>,
#   <matplotlib.axis.XTick at 0x2d6ba6950>,
#   <matplotlib.axis.XTick at 0x2d6bb0a90>,
#   <matplotlib.axis.XTick at 0x2d6ba41d0>,
#   <matplotlib.axis.XTick at 0x2d6bb3350>,
#   <matplotlib.axis.XTick at 0x2d6bb9450>,
#   <matplotlib.axis.XTick at 0x2d6bbb650>,
#   <matplotlib.axis.XTick at 0x2d6bc16d0>,
#   <matplotlib.axis.XTick at 0x2d6bb8dd0>,
#   <matplotlib.axis.XTick at 0x2d6bc4250>,
#   <matplotlib.axis.XTick at 0x2d6bc6250>,
#   <matplotlib.axis.XTick at 0x2d6bd0250>,
#   <matplotlib.axis.XTick at 0x2d6bd2510>,
#   <matplotlib.axis.XTick at 0x2d6bd45d0>,
#   <matplotlib.axis.XTick at 0x2d6bb2bd0>,
#   <matplotlib.axis.XTick at 0x2d6bd6c90>,
#   <matplotlib.axis.XTick at 0x2d6bd8e90>,
#   <matplotlib.axis.XTick at 0x2d6bdaf10>,
#   <matplotlib.axis.XTick at 0x2d6bdd010>,
#   <matplotlib.axis.XTick at 0x2d6bd7810>,
#   <matplotlib.axis.XTick at 0x2d6bdf690>,
#   <matplotlib.axis.XTick at 0x2d6be9790>,
#   <matplotlib.axis.XTick at 0x2d6beb910>,
#   <matplotlib.axis.XTick at 0x2d6beda50>,
#   <matplotlib.axis.XTick at 0x2d6befb10>,
#   <matplotlib.axis.XTick at 0x2d6bd8950>,
#   <matplotlib.axis.XTick at 0x2d6bf5f50>,
#   <matplotlib.axis.XTick at 0x2d6bf7fd0>,
#   <matplotlib.axis.XTick at 0x2d6c06110>,
#   <matplotlib.axis.XTick at 0x2d6c08250>,
#   <matplotlib.axis.XTick at 0x2d6bf66d0>,
#   <matplotlib.axis.XTick at 0x2d6c0a990>,
#   <matplotlib.axis.XTick at 0x2d6c14a10>,
#   <matplotlib.axis.XTick at 0x2d6c16ad0>,
#   <matplotlib.axis.XTick at 0x2d6c18ad0>,
#   <matplotlib.axis.XTick at 0x2d6c16190>,
#   <matplotlib.axis.XTick at 0x2d6c1b290>,
#   <matplotlib.axis.XTick at 0x2d6c1d490>,
#   <matplotlib.axis.XTick at 0x2d6c1f410>,
#   <matplotlib.axis.XTick at 0x2d6c213d0>,
#   <matplotlib.axis.XTick at 0x2d6c23510>,
#   <matplotlib.axis.XTick at 0x2d6c22390>,
#   <matplotlib.axis.XTick at 0x2d6c35b10>,
#   <matplotlib.axis.XTick at 0x2d6c37a90>,
#   <matplotlib.axis.XTick at 0x2d6c3db50>,
#   <matplotlib.axis.XTick at 0x2d6c3fbd0>,
#   <matplotlib.axis.XTick at 0x2d6c37190>,
#   <matplotlib.axis.XTick at 0x2d6c422d0>,
#   <matplotlib.axis.XTick at 0x2d6c44390>,
#   <matplotlib.axis.XTick at 0x2d6c46450>,
#   <matplotlib.axis.XTick at 0x2d6c48550>,
#   <matplotlib.axis.XTick at 0x2d6c4a710>,
#   <matplotlib.axis.XTick at 0x2d6c49f50>,
#   <matplotlib.axis.XTick at 0x2d6c54950>,
#   <matplotlib.axis.XTick at 0x2d6c56a90>,
#   <matplotlib.axis.XTick at 0x2d6c68a90>,
#   <matplotlib.axis.XTick at 0x2d6c6aad0>,
#   <matplotlib.axis.XTick at 0x2d6c45bd0>,
#   <matplotlib.axis.XTick at 0x2d6ba0590>,
#   <matplotlib.axis.XTick at 0x2d6c6d710>,
#   <matplotlib.axis.XTick at 0x2d6c6f810>,
#   <matplotlib.axis.XTick at 0x2d6c71890>,
#   <matplotlib.axis.XTick at 0x2d6c739d0>,
#   <matplotlib.axis.XTick at 0x2d6c19950>,
#   <matplotlib.axis.XTick at 0x2d6c75c50>,
#   <matplotlib.axis.XTick at 0x2d6c77d10>,
#   <matplotlib.axis.XTick at 0x2d6c7dd50>,
#   <matplotlib.axis.XTick at 0x2d6c7fe90>,
#   <matplotlib.axis.XTick at 0x2d6c76750>,
#   <matplotlib.axis.XTick at 0x2d6c864d0>,
#   <matplotlib.axis.XTick at 0x2d6c8c590>,
#   <matplotlib.axis.XTick at 0x2d6c8e6d0>,
#   <matplotlib.axis.XTick at 0x2d6c90690>,
#   <matplotlib.axis.XTick at 0x2d6bbbf10>,
#   <matplotlib.axis.XTick at 0x2d6c92ad0>,
#   <matplotlib.axis.XTick at 0x2d6c98a90>,
#   <matplotlib.axis.XTick at 0x2d6c9ab50>,
#   <matplotlib.axis.XTick at 0x2d6c9cd10>,
#   <matplotlib.axis.XTick at 0x2d6c9ee50>,
#   <matplotlib.axis.XTick at 0x2d6c15bd0>,
#   <matplotlib.axis.XTick at 0x2d6cad390>,
#   <matplotlib.axis.XTick at 0x2d6caf150>,
#   <matplotlib.axis.XTick at 0x2d6cb5190>,
#   <matplotlib.axis.XTick at 0x2d6cb7290>,
#   <matplotlib.axis.XTick at 0x2d6cb4890>,
#   <matplotlib.axis.XTick at 0x2d6cbd7d0>,
#   <matplotlib.axis.XTick at 0x2d6cbf810>,
#   <matplotlib.axis.XTick at 0x2d6cc17d0>,
#   <matplotlib.axis.XTick at 0x2d6cc3850>,
#   <matplotlib.axis.XTick at 0x2d6cc5890>,
#   <matplotlib.axis.XTick at 0x2d6cc4f50>,
#   <matplotlib.axis.XTick at 0x2d6cc7e10>,
#   <matplotlib.axis.XTick at 0x2d6cd1dd0>,
#   <matplotlib.axis.XTick at 0x2d6cd3f10>,
#   <matplotlib.axis.XTick at 0x2d6cd9ed0>,
#   <matplotlib.axis.XTick at 0x2d6cc7490>,
#   <matplotlib.axis.XTick at 0x2d6cdc510>,
#   <matplotlib.axis.XTick at 0x2d6cde510>,
#   <matplotlib.axis.XTick at 0x2d6ce4650>,
#   <matplotlib.axis.XTick at 0x2d6ce6690>,
#   <matplotlib.axis.XTick at 0x2d6ce8650>,
#   <matplotlib.axis.XTick at 0x2d6bc3390>,
#   <matplotlib.axis.XTick at 0x2d6cea910>,
#   <matplotlib.axis.XTick at 0x2d6cf0890>,
#   <matplotlib.axis.XTick at 0x2d6cf2850>,
#   <matplotlib.axis.XTick at 0x2d6cfc890>,
#   <matplotlib.axis.XTick at 0x2d6ce92d0>,
#   <matplotlib.axis.XTick at 0x2d6cfee10>,
#   <matplotlib.axis.XTick at 0x2d6d04e90>,
#   <matplotlib.axis.XTick at 0x2d6d06e90>,
#   <matplotlib.axis.XTick at 0x2d6d08f10>,
#   <matplotlib.axis.XTick at 0x2d6d067d0>,
#   <matplotlib.axis.XTick at 0x2d6d0b610>,
#   <matplotlib.axis.XTick at 0x2d6d116d0>,
#   <matplotlib.axis.XTick at 0x2d6d13810>,
#   <matplotlib.axis.XTick at 0x2d6d19810>,
#   <matplotlib.axis.XTick at 0x2d6d1b810>,
#   <matplotlib.axis.XTick at 0x2d6d09650>,
#   <matplotlib.axis.XTick at 0x2d6d21d10>,
#   <matplotlib.axis.XTick at 0x2d6d23dd0>,
#   <matplotlib.axis.XTick at 0x2d6d29e10>,
#   <matplotlib.axis.XTick at 0x2d6d2be50>,
#   <matplotlib.axis.XTick at 0x2d6d22850>,
#   <matplotlib.axis.XTick at 0x2d6c9f550>,
#   <matplotlib.axis.XTick at 0x2d6d2f110>,
#   <matplotlib.axis.XTick at 0x2d6d310d0>,
#   <matplotlib.axis.XTick at 0x2d6d332d0>,
#   <matplotlib.axis.XTick at 0x2d6d41150>,
#   <matplotlib.axis.XTick at 0x2d6d29850>,
#   <matplotlib.axis.XTick at 0x2d6d43550>,
#   <matplotlib.axis.XTick at 0x2d6d45690>,
#   <matplotlib.axis.XTick at 0x2d6d47690>,
#   <matplotlib.axis.XTick at 0x2d6d51690>,
#   <matplotlib.axis.XTick at 0x2d6d41f50>,
#   <matplotlib.axis.XTick at 0x2d6d53d10>,
#   <matplotlib.axis.XTick at 0x2d6d5dd10>,
#   <matplotlib.axis.XTick at 0x2d6d5fdd0>,
#   <matplotlib.axis.XTick at 0x2d6d61dd0>,
#   <matplotlib.axis.XTick at 0x2d6d63ed0>,
#   <matplotlib.axis.XTick at 0x2d6ce40d0>,
#   <matplotlib.axis.XTick at 0x2d6d6a210>,
#   <matplotlib.axis.XTick at 0x2d6d70350>,
#   <matplotlib.axis.XTick at 0x2d6d72310>,
#   <matplotlib.axis.XTick at 0x2d6d74410>,
#   <matplotlib.axis.XTick at 0x2d6d6b190>,
#   <matplotlib.axis.XTick at 0x2d6d76990>,
#   <matplotlib.axis.XTick at 0x2d6d7ca10>,
#   <matplotlib.axis.XTick at 0x2d6d7ea10>,
#   <matplotlib.axis.XTick at 0x2d6d80a90>,
#   <matplotlib.axis.XTick at 0x2d6c6a2d0>,
#   <matplotlib.axis.XTick at 0x2d6d82dd0>,
#   <matplotlib.axis.XTick at 0x2d6d88e90>,
#   <matplotlib.axis.XTick at 0x2d6d8aed0>,
#   <matplotlib.axis.XTick at 0x2d6d8cfd0>,
#   <matplotlib.axis.XTick at 0x2d6d8ef50>,
#   <matplotlib.axis.XTick at 0x2d6c6bb50>,
#   <matplotlib.axis.XTick at 0x2d6d95410>,
#   <matplotlib.axis.XTick at 0x2d6d974d0>,
#   <matplotlib.axis.XTick at 0x2d6da5550>,
#   <matplotlib.axis.XTick at 0x2d6da7590>,
#   <matplotlib.axis.XTick at 0x2d6da4c90>,
#   <matplotlib.axis.XTick at 0x2d6da9c50>,
#   <matplotlib.axis.XTick at 0x2d6dabd50>,
#   <matplotlib.axis.XTick at 0x2d6db5d10>,
#   <matplotlib.axis.XTick at 0x2d6db7e50>,
#   <matplotlib.axis.XTick at 0x2d6db9e10>,
#   <matplotlib.axis.XTick at 0x2d6db96d0>,
#   <matplotlib.axis.XTick at 0x2d6dc02d0>,
#   <matplotlib.axis.XTick at 0x2d6dc2350>,
#   <matplotlib.axis.XTick at 0x2d6dc83d0>,
#   <matplotlib.axis.XTick at 0x2d6dca490>,
#   <matplotlib.axis.XTick at 0x2d6dbb190>,
#   <matplotlib.axis.XTick at 0x2d6dd0a50>,
#   <matplotlib.axis.XTick at 0x2d6dd2850>,
#   <matplotlib.axis.XTick at 0x2d6dd8890>,
#   <matplotlib.axis.XTick at 0x2d6dda990>,
#   <matplotlib.axis.XTick at 0x2d6ddca10>,
#   <matplotlib.axis.XTick at 0x2d6ce9310>,
#   <matplotlib.axis.XTick at 0x2d6ddecd0>,
#   <matplotlib.axis.XTick at 0x2d6de0c50>,
#   <matplotlib.axis.XTick at 0x2d6de2d50>,
#   <matplotlib.axis.XTick at 0x2d6de8e50>,
#   <matplotlib.axis.XTick at 0x2d6dddc10>,
#   <matplotlib.axis.XTick at 0x2d6deb4d0>,
#   <matplotlib.axis.XTick at 0x2d6df1410>,
#   <matplotlib.axis.XTick at 0x2d6df3490>,
#   <matplotlib.axis.XTick at 0x2d6df9410>,
#   <matplotlib.axis.XTick at 0x2d6df1f50>,
#   <matplotlib.axis.XTick at 0x2d6d74f90>,
#   <matplotlib.axis.XTick at 0x2d6e00610>,
#   <matplotlib.axis.XTick at 0x2d6e02710>,
#   <matplotlib.axis.XTick at 0x2d6e08650>,
#   <matplotlib.axis.XTick at 0x2d6e0a750>,
#   <matplotlib.axis.XTick at 0x2d6dd1950>,
#   <matplotlib.axis.XTick at 0x2d6e0cd90>,
#   <matplotlib.axis.XTick at 0x2d6e0ed90>,
#   <matplotlib.axis.XTick at 0x2d6e14c90>,
#   <matplotlib.axis.XTick at 0x2d6e16d10>,
#   <matplotlib.axis.XTick at 0x2d6e153d0>,
#   <matplotlib.axis.XTick at 0x2d6e1d190>,
#   <matplotlib.axis.XTick at 0x2d6e1f210>,
#   <matplotlib.axis.XTick at 0x2d6e29350>,
#   <matplotlib.axis.XTick at 0x2d6e2b490>,
#   <matplotlib.axis.XTick at 0x2d6e2d590>,
#   <matplotlib.axis.XTick at 0x2d6e2cf90>,
#   <matplotlib.axis.XTick at 0x2d6e2fad0>,
#   <matplotlib.axis.XTick at 0x2d6e31bd0>,
#   <matplotlib.axis.XTick at 0x2d6e33d90>,
#   <matplotlib.axis.XTick at 0x2d6e39d90>,
#   <matplotlib.axis.XTick at 0x2d6e2f1d0>,
#   <matplotlib.axis.XTick at 0x2d6e484d0>,
#   <matplotlib.axis.XTick at 0x2d6e4a550>,
#   <matplotlib.axis.XTick at 0x2d6e543d0>,
#   <matplotlib.axis.XTick at 0x2d6e564d0>,
#   <matplotlib.axis.XTick at 0x2d6e584d0>,
#   <matplotlib.axis.XTick at 0x2d6e32e10>,
#   <matplotlib.axis.XTick at 0x2d6e5a8d0>,
#   <matplotlib.axis.XTick at 0x2d6e5c9d0>,
#   <matplotlib.axis.XTick at 0x2d6e5ea10>,
#   <matplotlib.axis.XTick at 0x2d6e609d0>,
#   <matplotlib.axis.XTick at 0x2d6e5a1d0>,
#   <matplotlib.axis.XTick at 0x2d6e62fd0>,
#   <matplotlib.axis.XTick at 0x2d6e68f90>,
#   <matplotlib.axis.XTick at 0x2d6e6b010>,
#   <matplotlib.axis.XTick at 0x2d6e71190>,
#   <matplotlib.axis.XTick at 0x2d6e6b7d0>,
#   <matplotlib.axis.XTick at 0x2d6e73890>,
#   <matplotlib.axis.XTick at 0x2d6e7d8d0>,
#   <matplotlib.axis.XTick at 0x2d6e7f990>,
#   <matplotlib.axis.XTick at 0x2d6e81a10>,
#   <matplotlib.axis.XTick at 0x2d6e83b50>,
#   <matplotlib.axis.XTick at 0x2d6e70a90>,
#   <matplotlib.axis.XTick at 0x2d6e86150>,
#   <matplotlib.axis.XTick at 0x2d6e880d0>,
#   <matplotlib.axis.XTick at 0x2d6e8a0d0>,
#   <matplotlib.axis.XTick at 0x2d6e90250>,
#   <matplotlib.axis.XTick at 0x2d6e71b90>,
#   <matplotlib.axis.XTick at 0x2d6e927d0>,
#   <matplotlib.axis.XTick at 0x2d6ea07d0>,
#   <matplotlib.axis.XTick at 0x2d6ea2850>,
#   <matplotlib.axis.XTick at 0x2d6ea8810>,
#   <matplotlib.axis.XTick at 0x2d6eaa910>,
#   <matplotlib.axis.XTick at 0x2d6ea8f90>,
#   <matplotlib.axis.XTick at 0x2d6eb0a10>,
#   <matplotlib.axis.XTick at 0x2d6eb2ad0>,
#   <matplotlib.axis.XTick at 0x2d6eb4b90>,
#   <matplotlib.axis.XTick at 0x2d6eb6c50>,
#   <matplotlib.axis.XTick at 0x2d6eb0390>,
#   <matplotlib.axis.XTick at 0x2d6ebd250>,
#   <matplotlib.axis.XTick at 0x2d6ebf190>,
#   <matplotlib.axis.XTick at 0x2d6ec1150>,
#   <matplotlib.axis.XTick at 0x2d6ec3150>,
#   <matplotlib.axis.XTick at 0x2d6ec1910>,
#   <matplotlib.axis.XTick at 0x2d6e61190>,
#   <matplotlib.axis.XTick at 0x2d6ecdf50>,
#   <matplotlib.axis.XTick at 0x2d6ecff90>,
#   <matplotlib.axis.XTick at 0x2d6ed6190>,
#   <matplotlib.axis.XTick at 0x2d6ed8150>,
#   <matplotlib.axis.XTick at 0x2d6e91f90>,
#   <matplotlib.axis.XTick at 0x2d6eda6d0>,
#   <matplotlib.axis.XTick at 0x2d6ee0690>,
#   <matplotlib.axis.XTick at 0x2d6ee2710>,
#   <matplotlib.axis.XTick at 0x2d6ee8710>,
#   <matplotlib.axis.XTick at 0x2d6ee1190>,
#   <matplotlib.axis.XTick at 0x2d6eeac50>,
#   <matplotlib.axis.XTick at 0x2d6ef09d0>,
#   <matplotlib.axis.XTick at 0x2d6ef2990>,
#   <matplotlib.axis.XTick at 0x2d6ef8a10>,
#   <matplotlib.axis.XTick at 0x2d6efab10>,
#   <matplotlib.axis.XTick at 0x2d6ef9950>,
#   <matplotlib.axis.XTick at 0x2d6efd090>,
#   <matplotlib.axis.XTick at 0x2d6eff110>,
#   <matplotlib.axis.XTick at 0x2d6f05190>,
#   <matplotlib.axis.XTick at 0x2d6f07190>,
#   <matplotlib.axis.XTick at 0x2d6efe890>,
#   <matplotlib.axis.XTick at 0x2d6f09710>,
#   <matplotlib.axis.XTick at 0x2d6f0b790>,
#   <matplotlib.axis.XTick at 0x2d6f11750>,
#   <matplotlib.axis.XTick at 0x2d6f13750>,
#   <matplotlib.axis.XTick at 0x2d6f1d750>,
#   <matplotlib.axis.XTick at 0x2d6f1c990>,
#   <matplotlib.axis.XTick at 0x2d6f1fa50>,
#   <matplotlib.axis.XTick at 0x2d6f25ad0>,
#   <matplotlib.axis.XTick at 0x2d6f27b10>,
#   <matplotlib.axis.XTick at 0x2d6f2db90>,
#   <matplotlib.axis.XTick at 0x2d6ef3190>,
#   <matplotlib.axis.XTick at 0x2d6f340d0>,
#   <matplotlib.axis.XTick at 0x2d6f361d0>,
#   <matplotlib.axis.XTick at 0x2d6f37fd0>,
#   <matplotlib.axis.XTick at 0x2d6f3e0d0>,
#   <matplotlib.axis.XTick at 0x2d6f36ed0>,
#   <matplotlib.axis.XTick at 0x2d6f40710>,
#   <matplotlib.axis.XTick at 0x2d6f42810>,
#   <matplotlib.axis.XTick at 0x2d6f48850>,
#   <matplotlib.axis.XTick at 0x2d6f4a8d0>,
#   <matplotlib.axis.XTick at 0x2d6f54a10>,
#   <matplotlib.axis.XTick at 0x2d6f34c90>,
#   <matplotlib.axis.XTick at 0x2d6f56fd0>,
#   <matplotlib.axis.XTick at 0x2d6f60f50>,
#   <matplotlib.axis.XTick at 0x2d6f63050>,
#   <matplotlib.axis.XTick at 0x2d6f65190>,
#   <matplotlib.axis.XTick at 0x2d6f57790>,
#   <matplotlib.axis.XTick at 0x2d6f677d0>,
#   <matplotlib.axis.XTick at 0x2d6f69810>,
#   <matplotlib.axis.XTick at 0x2d6f6b8d0>,
#   <matplotlib.axis.XTick at 0x2d6f71a90>,
#   <matplotlib.axis.XTick at 0x2d6f73a10>,
#   <matplotlib.axis.XTick at 0x2d6f71250>,
#   <matplotlib.axis.XTick at 0x2d6f79c10>,
#   <matplotlib.axis.XTick at 0x2d6f7bd90>,
#   <matplotlib.axis.XTick at 0x2d6f85d90>,
#   <matplotlib.axis.XTick at 0x2d6f87d90>,
#   <matplotlib.axis.XTick at 0x2d6f7a3d0>,
#   <matplotlib.axis.XTick at 0x2d6f8a310>,
#   <matplotlib.axis.XTick at 0x2d6f94450>,
#   <matplotlib.axis.XTick at 0x2d6f964d0>,
#   <matplotlib.axis.XTick at 0x2d6f98490>,
#   <matplotlib.axis.XTick at 0x2d6f952d0>,
#   <matplotlib.axis.XTick at 0x2d6ec3ad0>,
#   <matplotlib.axis.XTick at 0x2d6f9b550>,
#   <matplotlib.axis.XTick at 0x2d6fa5650>,
#   <matplotlib.axis.XTick at 0x2d6fa7690>,
#   <matplotlib.axis.XTick at 0x2d6fa9710>,
#   <matplotlib.axis.XTick at 0x2d6f8bc50>,
#   <matplotlib.axis.XTick at 0x2d6fabc50>,
#   <matplotlib.axis.XTick at 0x2d6fb1b10>,
#   <matplotlib.axis.XTick at 0x2d6fb3b50>,
#   <matplotlib.axis.XTick at 0x2d6fb5b50>,
#   <matplotlib.axis.XTick at 0x2d6fb22d0>,
#   <matplotlib.axis.XTick at 0x2d6fb7f90>,
#   <matplotlib.axis.XTick at 0x2d6fbe190>,
#   <matplotlib.axis.XTick at 0x2d6fc8110>,
#   <matplotlib.axis.XTick at 0x2d6fca190>,
#   <matplotlib.axis.XTick at 0x2d6fcc1d0>,
#   <matplotlib.axis.XTick at 0x2d6fab650>,
#   <matplotlib.axis.XTick at 0x2d6fce650>,
#   <matplotlib.axis.XTick at 0x2d6fd4710>,
#   <matplotlib.axis.XTick at 0x2d6fd6590>,
#   <matplotlib.axis.XTick at 0x2d6fdc690>,
#   <matplotlib.axis.XTick at 0x2d6f25490>,
#   <matplotlib.axis.XTick at 0x2d6fdec90>,
#   <matplotlib.axis.XTick at 0x2d6fe4cd0>,
#   <matplotlib.axis.XTick at 0x2d6fe6cd0>,
#   <matplotlib.axis.XTick at 0x2d6fecd10>,
#   <matplotlib.axis.XTick at 0x2d6feecd0>,
#   <matplotlib.axis.XTick at 0x2d6fee590>,
#   <matplotlib.axis.XTick at 0x2d6ff4e50>,
#   <matplotlib.axis.XTick at 0x2d6ff6e90>,
#   <matplotlib.axis.XTick at 0x2d6ff8e90>,
#   <matplotlib.axis.XTick at 0x2d6ffae90>,
#   <matplotlib.axis.XTick at 0x2d6ff5d10>,
#   <matplotlib.axis.XTick at 0x2d6ffd450>,
#   <matplotlib.axis.XTick at 0x2d6fff510>,
#   <matplotlib.axis.XTick at 0x2d7005610>,
#   <matplotlib.axis.XTick at 0x2d7007550>,
#   <matplotlib.axis.XTick at 0x2d7006150>,
#   <matplotlib.axis.XTick at 0x2d7011a90>,
#   <matplotlib.axis.XTick at 0x2d7013910>,
#   <matplotlib.axis.XTick at 0x2d7019950>,
#   <matplotlib.axis.XTick at 0x2d701ba50>,
#   <matplotlib.axis.XTick at 0x2d701da90>,
#   <matplotlib.axis.XTick at 0x2d701d3d0>,
#   <matplotlib.axis.XTick at 0x2d701ff90>,
#   <matplotlib.axis.XTick at 0x2d70260d0>,
#   <matplotlib.axis.XTick at 0x2d70281d0>,
#   <matplotlib.axis.XTick at 0x2d702a250>,
#   <matplotlib.axis.XTick at 0x2d701ef50>,
#   <matplotlib.axis.XTick at 0x2d7038990>,
#   <matplotlib.axis.XTick at 0x2d703a990>,
#   <matplotlib.axis.XTick at 0x2d7040b10>,
#   <matplotlib.axis.XTick at 0x2d7042b10>,
#   <matplotlib.axis.XTick at 0x2d7048c10>,
#   <matplotlib.axis.XTick at 0x2d7027b10>,
#   <matplotlib.axis.XTick at 0x2d704af10>,
#   <matplotlib.axis.XTick at 0x2d704ce90>,
#   <matplotlib.axis.XTick at 0x2d704ef50>,
#   <matplotlib.axis.XTick at 0x2d7050fd0>,
#   <matplotlib.axis.XTick at 0x2d704b690>,
#   <matplotlib.axis.XTick at 0x2d7053490>,
#   <matplotlib.axis.XTick at 0x2d7059550>,
#   <matplotlib.axis.XTick at 0x2d705b450>,
#   <matplotlib.axis.XTick at 0x2d7061490>,
#   <matplotlib.axis.XTick at 0x2d7058ed0>,
#   <matplotlib.axis.XTick at 0x2d6fcd490>,
#   <matplotlib.axis.XTick at 0x2d7068410>,
#   <matplotlib.axis.XTick at 0x2d706a550>,
#   <matplotlib.axis.XTick at 0x2d7070590>,
#   <matplotlib.axis.XTick at 0x2d7072750>,
#   <matplotlib.axis.XTick at 0x2d6b88950>,
#   <matplotlib.axis.XTick at 0x2d7060b10>,
#   <matplotlib.axis.XTick at 0x2d7076850>,
#   <matplotlib.axis.XTick at 0x2d7076510>,
#   <matplotlib.axis.XTick at 0x2d707e710>,
#   <matplotlib.axis.XTick at 0x2d6da7e90>,
#   <matplotlib.axis.XTick at 0x2d706bc10>,
#   <matplotlib.axis.XTick at 0x2d70757d0>,
#   <matplotlib.axis.XTick at 0x2d7091d10>,
#   <matplotlib.axis.XTick at 0x2d7096510>,
#   <matplotlib.axis.XTick at 0x2d7095b90>,
#   <matplotlib.axis.XTick at 0x2d7095d10>,
#   <matplotlib.axis.XTick at 0x2d7097310>,
#   <matplotlib.axis.XTick at 0x2d709dcd0>,
#   <matplotlib.axis.XTick at 0x2d70a2610>,
#   <matplotlib.axis.XTick at 0x2d70a18d0>,
#   <matplotlib.axis.XTick at 0x2d70a33d0>,
#   <matplotlib.axis.XTick at 0x2d7095750>,
#   <matplotlib.axis.XTick at 0x2d709f810>,
#   <matplotlib.axis.XTick at 0x2d70ab3d0>,
#   <matplotlib.axis.XTick at 0x2d70ad8d0>,
#   <matplotlib.axis.XTick at 0x2d70adb10>,
#   <matplotlib.axis.XTick at 0x2d70ae950>,
#   <matplotlib.axis.XTick at 0x2d70af8d0>,
#   <matplotlib.axis.XTick at 0x2d70b5110>,
#   <matplotlib.axis.XTick at 0x2d70c16d0>,
#   <matplotlib.axis.XTick at 0x2d70c3bd0>,
#   <matplotlib.axis.XTick at 0x2d70c7e90>,
#   <matplotlib.axis.XTick at 0x2d70c7a10>,
#   <matplotlib.axis.XTick at 0x2d70c3990>,
#   <matplotlib.axis.XTick at 0x2d70cd9d0>,
#   <matplotlib.axis.XTick at 0x2d70cf8d0>,
#   <matplotlib.axis.XTick at 0x2d70d55d0>,
#   <matplotlib.axis.XTick at 0x2d70d7dd0>,
#   <matplotlib.axis.XTick at 0x2d70c4790>,
#   <matplotlib.axis.XTick at 0x2d70cd850>,
#   <matplotlib.axis.XTick at 0x2d70dbc10>,
#   <matplotlib.axis.XTick at 0x2d70e7d50>,
#   <matplotlib.axis.XTick at 0x2d70e7510>,
#   <matplotlib.axis.XTick at 0x2d70e5950>,
#   <matplotlib.axis.XTick at 0x2d70e7810>,
#   <matplotlib.axis.XTick at 0x2d70ed210>,
#   <matplotlib.axis.XTick at 0x2d70fb990>,
#   <matplotlib.axis.XTick at 0x2d70fb490>,
#   <matplotlib.axis.XTick at 0x2d70ff790>,
#   <matplotlib.axis.XTick at 0x2d70fe190>,
#   <matplotlib.axis.XTick at 0x2d70fa9d0>,
#   <matplotlib.axis.XTick at 0x2d71038d0>,
#   <matplotlib.axis.XTick at 0x2d7103590>,
#   <matplotlib.axis.XTick at 0x2d710b790>,
#   <matplotlib.axis.XTick at 0x2d710b290>,
#   <matplotlib.axis.XTick at 0x2d70fd2d0>,
#   <matplotlib.axis.XTick at 0x2d707f390>,
#   <matplotlib.axis.XTick at 0x2d71134d0>,
#   <matplotlib.axis.XTick at 0x2d711b650>,
#   <matplotlib.axis.XTick at 0x2d711b090>,
#   <matplotlib.axis.XTick at 0x2d6fe4750>,
#   <matplotlib.axis.XTick at 0x2d711a590>,
#   <matplotlib.axis.XTick at 0x2d71233d0>,
#   <matplotlib.axis.XTick at 0x2d7127410>,
#   <matplotlib.axis.XTick at 0x2d7127090>,
#   <matplotlib.axis.XTick at 0x2d712b1d0>,
#   <matplotlib.axis.XTick at 0x2d7121f90>,
#   <matplotlib.axis.XTick at 0x2d7122b50>,
#   <matplotlib.axis.XTick at 0x2d7128590>,
#   <matplotlib.axis.XTick at 0x2d713f950>,
#   <matplotlib.axis.XTick at 0x2d713f490>,
#   <matplotlib.axis.XTick at 0x2d7143990>,
#   <matplotlib.axis.XTick at 0x2d70d7b10>,
#   <matplotlib.axis.XTick at 0x2d707f5d0>,
#   <matplotlib.axis.XTick at 0x2d714ba90>,
#   <matplotlib.axis.XTick at 0x2d714b750>,
#   <matplotlib.axis.XTick at 0x2d714f890>,
#   <matplotlib.axis.XTick at 0x2d714d0d0>,
#   <matplotlib.axis.XTick at 0x2d714ff50>,
#   <matplotlib.axis.XTick at 0x2d7153b10>,
#   <matplotlib.axis.XTick at 0x2d7153810>,
#   <matplotlib.axis.XTick at 0x2d715b810>,
#   <matplotlib.axis.XTick at 0x2d71592d0>,
#   <matplotlib.axis.XTick at 0x2d71503d0>,
#   <matplotlib.axis.XTick at 0x2d7153390>,
#   <matplotlib.axis.XTick at 0x2d71675d0>,
#   <matplotlib.axis.XTick at 0x2d7177990>,
#   <matplotlib.axis.XTick at 0x2d7177690>,
#   <matplotlib.axis.XTick at 0x2d717b6d0>,
#   <matplotlib.axis.XTick at 0x2d717ae10>,
#   <matplotlib.axis.XTick at 0x2d7178450>,
#   <matplotlib.axis.XTick at 0x2d717f5d0>,
#   <matplotlib.axis.XTick at 0x2d717f090>,
#   <matplotlib.axis.XTick at 0x2d7187410>,
#   <matplotlib.axis.XTick at 0x2d7184f50>,
#   <matplotlib.axis.XTick at 0x2d7186b50>,
#   <matplotlib.axis.XTick at 0x2d718f290>,
#   <matplotlib.axis.XTick at 0x2d718e9d0>,
#   <matplotlib.axis.XTick at 0x2d719afd0>,
#   <matplotlib.axis.XTick at 0x2d719a750>,
#   <matplotlib.axis.XTick at 0x2d718de90>,
#   <matplotlib.axis.XTick at 0x2d718ec50>,
#   <matplotlib.axis.XTick at 0x2d719e6d0>,
#   <matplotlib.axis.XTick at 0x2d71a32d0>,
#   <matplotlib.axis.XTick at 0x2d71a2550>,
#   <matplotlib.axis.XTick at 0x2d71ab110>,
#   <matplotlib.axis.XTick at 0x2d71aa850>,
#   <matplotlib.axis.XTick at 0x2d71a0b50>,
#   <matplotlib.axis.XTick at 0x2d71b3090>,
#   <matplotlib.axis.XTick at 0x2d71b2b90>,
#   <matplotlib.axis.XTick at 0x2d71baf10>,
#   <matplotlib.axis.XTick at 0x2d71ba310>,
#   <matplotlib.axis.XTick at 0x2d71ba190>,
#   <matplotlib.axis.XTick at 0x2d71bef90>,
#   <matplotlib.axis.XTick at 0x2d71be610>,
#   <matplotlib.axis.XTick at 0x2d71caf50>,
#   <matplotlib.axis.XTick at 0x2d71ca290>,
#   <matplotlib.axis.XTick at 0x2d71bc710>,
#   <matplotlib.axis.XTick at 0x2d71bf8d0>,
#   <matplotlib.axis.XTick at 0x2d71d6f90>,
#   <matplotlib.axis.XTick at 0x2d71db0d0>,
#   <matplotlib.axis.XTick at 0x2d71dacd0>,
#   <matplotlib.axis.XTick at 0x2d71e2e10>,
#   <matplotlib.axis.XTick at 0x2d71e2890>,
#   <matplotlib.axis.XTick at 0x2d71d79d0>,
#   <matplotlib.axis.XTick at 0x2d71eac90>,
#   <matplotlib.axis.XTick at 0x2d71ea0d0>,
#   <matplotlib.axis.XTick at 0x2d71eead0>,
#   <matplotlib.axis.XTick at 0x2d71b9f90>,
#   <matplotlib.axis.XTick at 0x2d71ed310>,
#   <matplotlib.axis.XTick at 0x2d71fab90>,
#   <matplotlib.axis.XTick at 0x2d71fa2d0>,
#   <matplotlib.axis.XTick at 0x2d71fe9d0>,
#   <matplotlib.axis.XTick at 0x2d71fe510>,
#   <matplotlib.axis.XTick at 0x2d71fa390>,
#   <matplotlib.axis.XTick at 0x2d70e4990>,
#   <matplotlib.axis.XTick at 0x2d718ca90>,
#   <matplotlib.axis.XTick at 0x2d7202e10>,
#   <matplotlib.axis.XTick at 0x2d720ef10>,
#   <matplotlib.axis.XTick at 0x2d720ec10>,
#   <matplotlib.axis.XTick at 0x2d71f81d0>,
#   <matplotlib.axis.XTick at 0x2d71d8950>,
#   <matplotlib.axis.XTick at 0x2d721abd0>,
#   <matplotlib.axis.XTick at 0x2d721ec10>,
#   <matplotlib.axis.XTick at 0x2d721e6d0>,
#   <matplotlib.axis.XTick at 0x2d721db90>,
#   <matplotlib.axis.XTick at 0x2d721c290>,
#   <matplotlib.axis.XTick at 0x2d72226d0>,
#   <matplotlib.axis.XTick at 0x2d722ac90>,
#   <matplotlib.axis.XTick at 0x2d722a9d0>,
#   <matplotlib.axis.XTick at 0x2d722eb90>,
#   <matplotlib.axis.XTick at 0x2d7222850>,
#   <matplotlib.axis.XTick at 0x2d7223dd0>,
#   <matplotlib.axis.XTick at 0x2d723ad10>,
#   <matplotlib.axis.XTick at 0x2d723a110>,
#   <matplotlib.axis.XTick at 0x2d723ebd0>,
#   <matplotlib.axis.XTick at 0x2d723e290>,
#   <matplotlib.axis.XTick at 0x2d7228750>,
#   <matplotlib.axis.XTick at 0x2d722fe10>,
#   <matplotlib.axis.XTick at 0x2d724a310>,
#   <matplotlib.axis.XTick at 0x2d724ea90>,
#   <matplotlib.axis.XTick at 0x2d724e790>,
#   <matplotlib.axis.XTick at 0x2d724c550>,
#   <matplotlib.axis.XTick at 0x2d724db10>,
#   <matplotlib.axis.XTick at 0x2d7256510>,
#   <matplotlib.axis.XTick at 0x2d7262890>,
#   <matplotlib.axis.XTick at 0x2d72623d0>,
#   <matplotlib.axis.XTick at 0x2d726e6d0>,
#   <matplotlib.axis.XTick at 0x2d7165250>,
#   <matplotlib.axis.XTick at 0x2d7263290>,
#   <matplotlib.axis.XTick at 0x2d727a8d0>,
#   <matplotlib.axis.XTick at 0x2d727a390>,
#   <matplotlib.axis.XTick at 0x2d727e710>,
#   <matplotlib.axis.XTick at 0x2d727ddd0>,
#   <matplotlib.axis.XTick at 0x2d7103fd0>,
#   <matplotlib.axis.XTick at 0x2d727bd50>,
#   <matplotlib.axis.XTick at 0x2d7282190>,
#   <matplotlib.axis.XTick at 0x2d728e550>,
#   <matplotlib.axis.XTick at 0x2d728dc10>,
#   <matplotlib.axis.XTick at 0x2d728c0d0>,
#   <matplotlib.axis.XTick at 0x2d728ebd0>,
#   <matplotlib.axis.XTick at 0x2d72904d0>,
#   <matplotlib.axis.XTick at 0x2d729a550>,
#   <matplotlib.axis.XTick at 0x2d7299f90>,
#   <matplotlib.axis.XTick at 0x2d729e310>,
#   <matplotlib.axis.XTick at 0x2d7291e90>,
#   <matplotlib.axis.XTick at 0x2d7293450>,
#   <matplotlib.axis.XTick at 0x2d72a6590>,
#   <matplotlib.axis.XTick at 0x2d72a4650>,
#   <matplotlib.axis.XTick at 0x2d72ae550>,
#   <matplotlib.axis.XTick at 0x2d72adc50>,
#   <matplotlib.axis.XTick at 0x2d72ad750>,
#   <matplotlib.axis.XTick at 0x2d72a5ed0>,
#   <matplotlib.axis.XTick at 0x2d72bcd10>,
#   <matplotlib.axis.XTick at 0x2d72bf150>,
#   <matplotlib.axis.XTick at 0x2d72c5950>,
#   <matplotlib.axis.XTick at 0x2d72c4e50>,
#   <matplotlib.axis.XTick at 0x2d72c7a90>,
#   <matplotlib.axis.XTick at 0x2d72c9a10>,
#   <matplotlib.axis.XTick at 0x2d72cbf90>,
#   <matplotlib.axis.XTick at 0x2d72d5950>,
#   <matplotlib.axis.XTick at 0x2d72d5b90>,
#   <matplotlib.axis.XTick at 0x2d72cae10>,
#   <matplotlib.axis.XTick at 0x2d7222250>,
#   <matplotlib.axis.XTick at 0x2d722fa50>,
#   <matplotlib.axis.XTick at 0x2d7198210>,
#   <matplotlib.axis.XTick at 0x2d72e1790>,
#   <matplotlib.axis.XTick at 0x2d72e3710>,
#   <matplotlib.axis.XTick at 0x2d72d59d0>,
#   <matplotlib.axis.XTick at 0x2d72c9b90>,
#   <matplotlib.axis.XTick at 0x2d72e7fd0>,
#   <matplotlib.axis.XTick at 0x2d72edad0>,
#   <matplotlib.axis.XTick at 0x2d72ef610>,
#   <matplotlib.axis.XTick at 0x2d72eee10>,
#   <matplotlib.axis.XTick at 0x2d72d54d0>,
#   <matplotlib.axis.XTick at 0x2d72f7fd0>,
#   <matplotlib.axis.XTick at 0x2d72fdd90>,
#   <matplotlib.axis.XTick at 0x2d72fff10>,
#   <matplotlib.axis.XTick at 0x2d7307fd0>,
#   <matplotlib.axis.XTick at 0x2d7307b10>,
#   <matplotlib.axis.XTick at 0x2d72ff9d0>,
#   <matplotlib.axis.XTick at 0x2d730d910>,
#   <matplotlib.axis.XTick at 0x2d730fb90>,
#   <matplotlib.axis.XTick at 0x2d7313ed0>,
#   <matplotlib.axis.XTick at 0x2d7313590>,
#   <matplotlib.axis.XTick at 0x2d7307890>,
#   <matplotlib.axis.XTick at 0x2d730dc50>,
#   <matplotlib.axis.XTick at 0x2d731f710>,
#   <matplotlib.axis.XTick at 0x2d73277d0>,
#   <matplotlib.axis.XTick at 0x2d7326e50>,
#   <matplotlib.axis.XTick at 0x2d7325050>,
#   <matplotlib.axis.XTick at 0x2d7326690>,
#   <matplotlib.axis.XTick at 0x2d732b1d0>,
#   <matplotlib.axis.XTick at 0x2d7333490>,
#   <matplotlib.axis.XTick at 0x2d7332810>,
#   <matplotlib.axis.XTick at 0x2d7337290>,
#   <matplotlib.axis.XTick at 0x2d7336e10>,
#   <matplotlib.axis.XTick at 0x2d7332250>,
#   <matplotlib.axis.XTick at 0x2d7343690>,
#   <matplotlib.axis.XTick at 0x2d7343150>,
#   <matplotlib.axis.XTick at 0x2d73474d0>,
#   <matplotlib.axis.XTick at 0x2d7347250>,
#   <matplotlib.axis.XTick at 0x2d7340750>,
#   <matplotlib.axis.XTick at 0x2d7342b10>,
#   <matplotlib.axis.XTick at 0x2d7356850>,
#   <matplotlib.axis.XTick at 0x2d735b390>,
#   <matplotlib.axis.XTick at 0x2d735a690>,
#   <matplotlib.axis.XTick at 0x2d72d4350>,
#   <matplotlib.axis.XTick at 0x2d7359dd0>,
#   <matplotlib.axis.XTick at 0x2d7362f90>,
#   <matplotlib.axis.XTick at 0x2d736b010>,
#   <matplotlib.axis.XTick at 0x2d736ad10>,
#   <matplotlib.axis.XTick at 0x2d7372e10>,
#   <matplotlib.axis.XTick at 0x2d7344f90>,
#   <matplotlib.axis.XTick at 0x2d7363010>,
#   <matplotlib.axis.XTick at 0x2d737ef90>,
#   <matplotlib.axis.XTick at 0x2d737c9d0>,
#   <matplotlib.axis.XTick at 0x2d7382e10>,
#   <matplotlib.axis.XTick at 0x2d7380790>,
#   <matplotlib.axis.XTick at 0x2d7369f10>,
#   <matplotlib.axis.XTick at 0x2d730cbd0>,
#   <matplotlib.axis.XTick at 0x2d7386b50>,
#   <matplotlib.axis.XTick at 0x2d738ebd0>,
#   <matplotlib.axis.XTick at 0x2d738da10>,
#   <matplotlib.axis.XTick at 0x2d7373890>,
#   <matplotlib.axis.XTick at 0x2d738e610>,
#   <matplotlib.axis.XTick at 0x2d7395b90>,
#   <matplotlib.axis.XTick at 0x2d739ea50>,
#   <matplotlib.axis.XTick at 0x2d739e190>,
#   <matplotlib.axis.XTick at 0x2d73aa810>,
#   <matplotlib.axis.XTick at 0x2d7394290>,
#   <matplotlib.axis.XTick at 0x2d739e410>,
#   <matplotlib.axis.XTick at 0x2d73379d0>,
#   <matplotlib.axis.XTick at 0x2d73b2d50>,
#   <matplotlib.axis.XTick at 0x2d73b07d0>,
#   <matplotlib.axis.XTick at 0x2d73bab10>,
#   <matplotlib.axis.XTick at 0x2d739d290>,
#   <matplotlib.axis.XTick at 0x2d737d7d0>,
#   <matplotlib.axis.XTick at 0x2d73bea50>,
#   <matplotlib.axis.XTick at 0x2d73be750>,
#   <matplotlib.axis.XTick at 0x2d73c6810>,
#   <matplotlib.axis.XTick at 0x2d73c57d0>,
#   <matplotlib.axis.XTick at 0x2d73c7290>,
#   <matplotlib.axis.XTick at 0x2d73d2910>,
#   <matplotlib.axis.XTick at 0x2d73d2610>,
#   <matplotlib.axis.XTick at 0x2d73da710>,
#   <matplotlib.axis.XTick at 0x2d73d9a50>,
#   <matplotlib.axis.XTick at 0x2d73d3350>,
#   <matplotlib.axis.XTick at 0x2d73d9e50>,
#   <matplotlib.axis.XTick at 0x2d73de790>,
#   <matplotlib.axis.XTick at 0x2d73e27d0>,
#   <matplotlib.axis.XTick at 0x2d73e1e90>,
#   <matplotlib.axis.XTick at 0x2d73e6550>,
#   <matplotlib.axis.XTick at 0x2d73e5ed0>,
#   <matplotlib.axis.XTick at 0x2d73d9e10>,
#   <matplotlib.axis.XTick at 0x2d73fa5d0>,
#   <matplotlib.axis.XTick at 0x2d73f9e90>,
#   <matplotlib.axis.XTick at 0x2d73fb7d0>,
#   <matplotlib.axis.XTick at 0x2d73f9090>,
#   <matplotlib.axis.XTick at 0x2d73faf10>,
#   <matplotlib.axis.XTick at 0x2d73ff310>,
#   <matplotlib.axis.XTick at 0x2d7401ad0>,
#   <matplotlib.axis.XTick at 0x2d7403e10>,
#   <matplotlib.axis.XTick at 0x2d7409950>,
#   <matplotlib.axis.XTick at 0x2d7409ad0>,
#   <matplotlib.axis.XTick at 0x2d7403a90>,
#   <matplotlib.axis.XTick at 0x2d7411dd0>,
#   <matplotlib.axis.XTick at 0x2d7413d50>,
#   <matplotlib.axis.XTick at 0x2d7419e50>,
#   <matplotlib.axis.XTick at 0x2d741b490>,
#   <matplotlib.axis.XTick at 0x2d7425190>,
#   <matplotlib.axis.XTick at 0x2d730d990>,
#   <matplotlib.axis.XTick at 0x2d7427ed0>,
#   <matplotlib.axis.XTick at 0x2d7429890>,
#   <matplotlib.axis.XTick at 0x2d742bbd0>,
#   <matplotlib.axis.XTick at 0x2d7382b10>,
#   <matplotlib.axis.XTick at 0x2d742b2d0>,
#   <matplotlib.axis.XTick at 0x2d742cb90>,
#   <matplotlib.axis.XTick at 0x2d7433fd0>,
#   <matplotlib.axis.XTick at 0x2d7433110>,
#   <matplotlib.axis.XTick at 0x2d743bc90>,
#   <matplotlib.axis.XTick at 0x2d743b790>,
#   <matplotlib.axis.XTick at 0x2d7431690>,
#   <matplotlib.axis.XTick at 0x2d744bd50>,
#   <matplotlib.axis.XTick at 0x2d744b890>,
#   <matplotlib.axis.XTick at 0x2d744fd50>,
#   <matplotlib.axis.XTick at 0x2d744f850>,
#   <matplotlib.axis.XTick at 0x2d743b590>,
#   <matplotlib.axis.XTick at 0x2d742d5d0>,
#   <matplotlib.axis.XTick at 0x2d7457a90>,
#   <matplotlib.axis.XTick at 0x2d745bb50>,
#   <matplotlib.axis.XTick at 0x2d745aed0>,
#   <matplotlib.axis.XTick at 0x2d7458490>,
#   <matplotlib.axis.XTick at 0x2d745a310>,
#   <matplotlib.axis.XTick at 0x2d7467710>,
#   <matplotlib.axis.XTick at 0x2d746f890>,
#   <matplotlib.axis.XTick at 0x2d746da10>,
#   <matplotlib.axis.XTick at 0x2d7477650>,
#   <matplotlib.axis.XTick at 0x2d74769d0>,
#   <matplotlib.axis.XTick at 0x2d7313090>,
#   <matplotlib.axis.XTick at 0x2d7412f90>,
#   <matplotlib.axis.XTick at 0x2d747fa10>,
#   <matplotlib.axis.XTick at 0x2d747f190>,
#   <matplotlib.axis.XTick at 0x2d7487810>,
#   <matplotlib.axis.XTick at 0x2d74872d0>,
#   <matplotlib.axis.XTick at 0x2d747e990>,
#   <matplotlib.axis.XTick at 0x2d748f750>,
#   <matplotlib.axis.XTick at 0x2d748c990>,
#   <matplotlib.axis.XTick at 0x2d749b750>,
#   <matplotlib.axis.XTick at 0x2d7499190>,
#   <matplotlib.axis.XTick at 0x2d7499110>,
#   <matplotlib.axis.XTick at 0x2d749f750>,
#   <matplotlib.axis.XTick at 0x2d749f590>,
#   <matplotlib.axis.XTick at 0x2d74a7610>,
#   <matplotlib.axis.XTick at 0x2d74a7210>,
#   <matplotlib.axis.XTick at 0x2d749e050>,
#   <matplotlib.axis.XTick at 0x2d749f210>,
#   <matplotlib.axis.XTick at 0x2d74ab650>,
#   <matplotlib.axis.XTick at 0x2d74b3750>,
#   <matplotlib.axis.XTick at 0x2d74b2a10>,
#   <matplotlib.axis.XTick at 0x2d74bb4d0>,
#   <matplotlib.axis.XTick at 0x2d74bae90>,
#   <matplotlib.axis.XTick at 0x2d74a4490>,
#   <matplotlib.axis.XTick at 0x2d74c3450>,
#   <matplotlib.axis.XTick at 0x2d74c2750>,
#   <matplotlib.axis.XTick at 0x2d74cb110>,
#   <matplotlib.axis.XTick at 0x2d7293050>,
#   <matplotlib.axis.XTick at 0x2d74c9f50>,
#   <matplotlib.axis.XTick at 0x2d74cf190>,
#   <matplotlib.axis.XTick at 0x2d74ce910>,
#   <matplotlib.axis.XTick at 0x2d74db150>,
#   <matplotlib.axis.XTick at 0x2d74da450>,
#   <matplotlib.axis.XTick at 0x2d74ce990>,
#   <matplotlib.axis.XTick at 0x2d749e690>,
#   <matplotlib.axis.XTick at 0x2d74e2950>,
#   <matplotlib.axis.XTick at 0x2d74eb090>,
#   <matplotlib.axis.XTick at 0x2d74e8a10>,
#   <matplotlib.axis.XTick at 0x2d74eeed0>,
#   <matplotlib.axis.XTick at 0x2d74ee7d0>,
#   <matplotlib.axis.XTick at 0x2d74e2c90>,
#   <matplotlib.axis.XTick at 0x2d74feed0>,
#   <matplotlib.axis.XTick at 0x2d74fe210>,
#   <matplotlib.axis.XTick at 0x2d7502c10>,
#   <matplotlib.axis.XTick at 0x2d7500690>,
#   <matplotlib.axis.XTick at 0x2d7503f10>,
#   <matplotlib.axis.XTick at 0x2d7506d10>,
#   <matplotlib.axis.XTick at 0x2d7505a10>,
#   <matplotlib.axis.XTick at 0x2d750aa90>,
#   <matplotlib.axis.XTick at 0x2d750a190>,
#   <matplotlib.axis.XTick at 0x2d75064d0>,
#   <matplotlib.axis.XTick at 0x2d7506650>,
#   <matplotlib.axis.XTick at 0x2d7515fd0>,
#   <matplotlib.axis.XTick at 0x2d751ea90>,
#   <matplotlib.axis.XTick at 0x2d751e810>,
#   <matplotlib.axis.XTick at 0x2d7526890>,
#   <matplotlib.axis.XTick at 0x2d7525b10>,
#   <matplotlib.axis.XTick at 0x2d7508550>,
#   <matplotlib.axis.XTick at 0x2d752a850>,
#   <matplotlib.axis.XTick at 0x2d752a390>,
#   <matplotlib.axis.XTick at 0x2d752ba90>,
#   <matplotlib.axis.XTick at 0x2d74a4390>,
#   <matplotlib.axis.XTick at 0x2d7532d50>,
#   <matplotlib.axis.XTick at 0x2d7536810>,
#   <matplotlib.axis.XTick at 0x2d7536650>,
#   <matplotlib.axis.XTick at 0x2d7542650>,
#   <matplotlib.axis.XTick at 0x2d7542290>,
#   <matplotlib.axis.XTick at 0x2d7534fd0>,
#   <matplotlib.axis.XTick at 0x2d748c850>,
#   <matplotlib.axis.XTick at 0x2d7543e90>,
#   <matplotlib.axis.XTick at 0x2d7549850>,
#   <matplotlib.axis.XTick at 0x2d75529d0>,
#   <matplotlib.axis.XTick at 0x2d7552590>,
#   <matplotlib.axis.XTick at 0x2d7536590>,
#   <matplotlib.axis.XTick at 0x2d75498d0>,
#   <matplotlib.axis.XTick at 0x2d7555cd0>,
#   <matplotlib.axis.XTick at 0x2d7562850>,
#   <matplotlib.axis.XTick at 0x2d75622d0>,
#   <matplotlib.axis.XTick at 0x2d7561810>,
#   <matplotlib.axis.XTick at 0x2d7561150>,
#   <matplotlib.axis.XTick at 0x2d756a150>,
#   <matplotlib.axis.XTick at 0x2d7572690>,
#   <matplotlib.axis.XTick at 0x2d75719d0>,
#   <matplotlib.axis.XTick at 0x2d757a4d0>,
#   <matplotlib.axis.XTick at 0x2d7551bd0>,
#   <matplotlib.axis.XTick at 0x2d7573f50>,
#   <matplotlib.axis.XTick at 0x2d758a690>,
#   <matplotlib.axis.XTick at 0x2d7589a10>,
#   <matplotlib.axis.XTick at 0x2d7592550>,
#   <matplotlib.axis.XTick at 0x2d7591910>,
#   <matplotlib.axis.XTick at 0x2d7593e50>,
#   <matplotlib.axis.XTick at 0x2d757bc90>,
#   <matplotlib.axis.XTick at 0x2d7599fd0>,
#   <matplotlib.axis.XTick at 0x2d759e3d0>,
#   <matplotlib.axis.XTick at 0x2d759c3d0>,
#   <matplotlib.axis.XTick at 0x2d73bf2d0>,
#   <matplotlib.axis.XTick at 0x2d759ecd0>,
#   <matplotlib.axis.XTick at 0x2d75a1e90>,
#   <matplotlib.axis.XTick at 0x2d75a3610>,
#   <matplotlib.axis.XTick at 0x2d75a9d90>,
#   <matplotlib.axis.XTick at 0x2d75abc90>,
#   <matplotlib.axis.XTick at 0x2d75a1dd0>,
#   <matplotlib.axis.XTick at 0x2d75a39d0>,
#   <matplotlib.axis.XTick at 0x2d75b3f90>,
#   <matplotlib.axis.XTick at 0x2d75b9150>,
#   <matplotlib.axis.XTick at 0x2d75bb5d0>,
#   <matplotlib.axis.XTick at 0x2d75bd950>,
#   <matplotlib.axis.XTick at 0x2d75bf810>,
#   <matplotlib.axis.XTick at 0x2d75b3d50>,
#   <matplotlib.axis.XTick at 0x2d75c1f90>,
#   <matplotlib.axis.XTick at 0x2d75c3e50>,
#   <matplotlib.axis.XTick at 0x2d75cffd0>,
#   <matplotlib.axis.XTick at 0x2d75cc850>,
#   <matplotlib.axis.XTick at 0x2d75cf1d0>,
#   <matplotlib.axis.XTick at 0x2d75dd190>,
#   <matplotlib.axis.XTick at 0x2d75dff50>,
#   <matplotlib.axis.XTick at 0x2d75e5e90>,
#   <matplotlib.axis.XTick at 0x2d75e7c10>,
#   <matplotlib.axis.XTick at 0x2d75ddcd0>,
#   <matplotlib.axis.XTick at 0x2d75df110>,
#   <matplotlib.axis.XTick at 0x2d75efc10>,
#   <matplotlib.axis.XTick at 0x2d75f3fd0>,
#   <matplotlib.axis.XTick at 0x2d75f3ad0>,
#   <matplotlib.axis.XTick at 0x2d75f7e90>,
#   <matplotlib.axis.XTick at 0x2d75b1950>,
#   <matplotlib.axis.XTick at 0x2d75ef2d0>,
#   <matplotlib.axis.XTick at 0x2d7603f90>,
#   <matplotlib.axis.XTick at 0x2d7603c90>,
#   <matplotlib.axis.XTick at 0x2d7607d90>,
#   <matplotlib.axis.XTick at 0x2d76078d0>,
#   <matplotlib.axis.XTick at 0x2d7605910>,
#   <matplotlib.axis.XTick at 0x2d760fed0>,
#   <matplotlib.axis.XTick at 0x2d760f550>,
#   <matplotlib.axis.XTick at 0x2d7613cd0>,
#   <matplotlib.axis.XTick at 0x2d7613010>,
#   <matplotlib.axis.XTick at 0x2d760f790>,
#   <matplotlib.axis.XTick at 0x2d7555690>,
#   <matplotlib.axis.XTick at 0x2d7550590>,
#   <matplotlib.axis.XTick at 0x2d7617910>,
#   <matplotlib.axis.XTick at 0x2d76258d0>,
#   <matplotlib.axis.XTick at 0x2d7625a50>,
#   <matplotlib.axis.XTick at 0x2d75f2b10>,
#   <matplotlib.axis.XTick at 0x2d760d950>,
#   <matplotlib.axis.XTick at 0x2d762fa10>,
#   <matplotlib.axis.XTick at 0x2d7637b10>,
#   <matplotlib.axis.XTick at 0x2d7637710>,
#   <matplotlib.axis.XTick at 0x2d7636690>,
#   <matplotlib.axis.XTick at 0x2d7637490>,
#   <matplotlib.axis.XTick at 0x2d76391d0>,
#   <matplotlib.axis.XTick at 0x2d7643990>,
#   <matplotlib.axis.XTick at 0x2d7643490>,
#   <matplotlib.axis.XTick at 0x2d7647750>,
#   <matplotlib.axis.XTick at 0x2d7646bd0>,
#   <matplotlib.axis.XTick at 0x2d7647210>,
#   <matplotlib.axis.XTick at 0x2d7653750>,
#   <matplotlib.axis.XTick at 0x2d7651250>,
#   <matplotlib.axis.XTick at 0x2d765f690>,
#   <matplotlib.axis.XTick at 0x2d765f190>,
#   <matplotlib.axis.XTick at 0x2d76453d0>,
#   <matplotlib.axis.XTick at 0x2d7652a50>,
#   <matplotlib.axis.XTick at 0x2d7663390>,
#   <matplotlib.axis.XTick at 0x2d766b2d0>,
#   <matplotlib.axis.XTick at 0x2d766a650>,
#   <matplotlib.axis.XTick at 0x2d7668b90>,
#   <matplotlib.axis.XTick at 0x2d7669f10>,
#   <matplotlib.axis.XTick at 0x2d7670ed0>,
#   <matplotlib.axis.XTick at 0x2d7677050>,
#   <matplotlib.axis.XTick at 0x2d7676b10>,
#   <matplotlib.axis.XTick at 0x2d7682d50>,
#   <matplotlib.axis.XTick at 0x2d7670d10>,
#   <matplotlib.axis.XTick at 0x2d7677dd0>,
#   <matplotlib.axis.XTick at 0x2d768ef50>,
#   <matplotlib.axis.XTick at 0x2d768ed90>,
#   <matplotlib.axis.XTick at 0x2d7696d90>,
#   <matplotlib.axis.XTick at 0x2d7696a90>,
#   <matplotlib.axis.XTick at 0x2d76757d0>,
#   <matplotlib.axis.XTick at 0x2d7681890>,
#   <matplotlib.axis.XTick at 0x2d769a910>,
#   <matplotlib.axis.XTick at 0x2d769e990>,
#   <matplotlib.axis.XTick at 0x2d769e010>,
#   <matplotlib.axis.XTick at 0x2d769c210>,
#   <matplotlib.axis.XTick at 0x2d769d9d0>,
#   <matplotlib.axis.XTick at 0x2d76a0090>,
#   <matplotlib.axis.XTick at 0x2d76ae850>,
#   <matplotlib.axis.XTick at 0x2d76ae5d0>,
#   <matplotlib.axis.XTick at 0x2d76b67d0>,
#   <matplotlib.axis.XTick at 0x2d769e1d0>,
#   <matplotlib.axis.XTick at 0x2d76a3690>,
#   <matplotlib.axis.XTick at 0x2d76be950>,
#   <matplotlib.axis.XTick at 0x2d76be690>,
#   <matplotlib.axis.XTick at 0x2d76c6810>,
#   <matplotlib.axis.XTick at 0x2d76c5f90>,
#   <matplotlib.axis.XTick at 0x2d762d290>,
#   <matplotlib.axis.XTick at 0x2d76995d0>,
#   <matplotlib.axis.XTick at 0x2d76ca250>,
#   <matplotlib.axis.XTick at 0x2d76d6650>,
#   <matplotlib.axis.XTick at 0x2d76d5d10>,
#   <matplotlib.axis.XTick at 0x2d76d7150>,
#   <matplotlib.axis.XTick at 0x2d76d5f50>,
#   <matplotlib.axis.XTick at 0x2d76e5d50>,
#   <matplotlib.axis.XTick at 0x2d76e7790>,
#   <matplotlib.axis.XTick at 0x2d76e9e90>,
#   <matplotlib.axis.XTick at 0x2d76eb6d0>,
#   <matplotlib.axis.XTick at 0x2d76e6cd0>,
#   <matplotlib.axis.XTick at 0x2d762d5d0>,
#   <matplotlib.axis.XTick at 0x2d7647290>,
#   <matplotlib.axis.XTick at 0x2d76efd10>,
#   <matplotlib.axis.XTick at 0x2d76f1ad0>,
#   <matplotlib.axis.XTick at 0x2d76fa6d0>,
#   <matplotlib.axis.XTick at 0x2d76e8b50>,
#   <matplotlib.axis.XTick at 0x2d76ef590>,
#   <matplotlib.axis.XTick at 0x2d76fb810>,
#   <matplotlib.axis.XTick at 0x2d7705790>,
#   <matplotlib.axis.XTick at 0x2d7707f50>,
#   <matplotlib.axis.XTick at 0x2d7706e90>,
#   <matplotlib.axis.XTick at 0x2d76ebb90>,
#   <matplotlib.axis.XTick at 0x2d770bfd0>,
#   <matplotlib.axis.XTick at 0x2d7711950>,
#   <matplotlib.axis.XTick at 0x2d7713dd0>,
#   <matplotlib.axis.XTick at 0x2d7715110>,
#   <matplotlib.axis.XTick at 0x2d7717790>,
#   <matplotlib.axis.XTick at 0x2d7713190>,
#   <matplotlib.axis.XTick at 0x2d771e0d0>,
#   ...],
#  [Text(0, 0, 'AUT'),
#   Text(1, 0, 'AUT'),
#   Text(2, 0, 'AUT'),
#   Text(3, 0, 'AUT'),
#   Text(4, 0, 'AUT'),
#   Text(5, 0, 'AUT'),
#   Text(6, 0, 'AUT'),
#   Text(7, 0, 'AUT'),
#   Text(8, 0, 'AUT'),
#   Text(9, 0, 'AUT'),
#   Text(10, 0, 'AUT'),
#   Text(11, 0, 'AUT'),
#   Text(12, 0, 'AUT'),
#   Text(13, 0, 'AUT'),
#   Text(14, 0, 'AUT'),
#   Text(15, 0, 'AUT'),
#   Text(16, 0, 'AUT'),
#   Text(17, 0, 'AUT'),
#   Text(18, 0, 'AUT'),
#   Text(19, 0, 'AUT'),
#   Text(20, 0, 'AUT'),
#   Text(21, 0, 'AUT'),
#   Text(22, 0, 'AUT'),
#   Text(23, 0, 'AUT'),
#   Text(24, 0, 'AUT'),
#   Text(25, 0, 'AUT'),
#   Text(26, 0, 'AUT'),
#   Text(27, 0, 'AUT'),
#   Text(28, 0, 'AUT'),
#   Text(29, 0, 'AUT'),
#   Text(30, 0, 'AUT'),
#   Text(31, 0, 'AUT'),
#   Text(32, 0, 'AUT'),
#   Text(33, 0, 'BEL'),
#   Text(34, 0, 'BEL'),
#   Text(35, 0, 'BEL'),
#   Text(36, 0, 'BEL'),
#   Text(37, 0, 'BEL'),
#   Text(38, 0, 'BEL'),
#   Text(39, 0, 'BRA'),
#   Text(40, 0, 'BRA'),
#   Text(41, 0, 'BRA'),
#   Text(42, 0, 'BRA'),
#   Text(43, 0, 'BRA'),
#   Text(44, 0, 'BRA'),
#   Text(45, 0, 'BRA'),
#   Text(46, 0, 'BRA'),
#   Text(47, 0, 'BRA'),
#   Text(48, 0, 'BRA'),
#   Text(49, 0, 'BRA'),
#   Text(50, 0, 'BRA'),
#   Text(51, 0, 'BRA'),
#   Text(52, 0, 'BRA'),
#   Text(53, 0, 'BRA'),
#   Text(54, 0, 'BRA'),
#   Text(55, 0, 'BRA'),
#   Text(56, 0, 'BRA'),
#   Text(57, 0, 'BRA'),
#   Text(58, 0, 'BRA'),
#   Text(59, 0, 'BRA'),
#   Text(60, 0, 'CAN'),
#   Text(61, 0, 'CAN'),
#   Text(62, 0, 'CAN'),
#   Text(63, 0, 'CAN'),
#   Text(64, 0, 'CAN'),
#   Text(65, 0, 'CAN'),
#   Text(66, 0, 'CAN'),
#   Text(67, 0, 'CAN'),
#   Text(68, 0, 'CAN'),
#   Text(69, 0, 'CAN'),
#   Text(70, 0, 'CAN'),
#   Text(71, 0, 'CAN'),
#   Text(72, 0, 'CAN'),
#   Text(73, 0, 'CAN'),
#   Text(74, 0, 'CAN'),
#   Text(75, 0, 'CAN'),
#   Text(76, 0, 'CAN'),
#   Text(77, 0, 'CAN'),
#   Text(78, 0, 'CAN'),
#   Text(79, 0, 'CAN'),
#   Text(80, 0, 'CAN'),
#   Text(81, 0, 'CAN'),
#   Text(82, 0, 'CAN'),
#   Text(83, 0, 'CAN'),
#   Text(84, 0, 'CAN'),
#   Text(85, 0, 'CAN'),
#   Text(86, 0, 'CAN'),
#   Text(87, 0, 'CAN'),
#   Text(88, 0, 'CAN'),
#   Text(89, 0, 'CAN'),
#   Text(90, 0, 'CAN'),
#   Text(91, 0, 'CAN'),
#   Text(92, 0, 'CAN'),
#   Text(93, 0, 'CAN'),
#   Text(94, 0, 'CAN'),
#   Text(95, 0, 'CAN'),
#   Text(96, 0, 'CHE'),
#   Text(97, 0, 'CHE'),
#   Text(98, 0, 'CHE'),
#   Text(99, 0, 'CHE'),
#   Text(100, 0, 'CHE'),
#   Text(101, 0, 'CHE'),
#   Text(102, 0, 'CHE'),
#   Text(103, 0, 'CHE'),
#   Text(104, 0, 'CHE'),
#   Text(105, 0, 'CHE'),
#   Text(106, 0, 'CHE'),
#   Text(107, 0, 'CHE'),
#   Text(108, 0, 'CHE'),
#   Text(109, 0, 'CHE'),
#   Text(110, 0, 'CHE'),
#   Text(111, 0, 'CHE'),
#   Text(112, 0, 'CHE'),
#   Text(113, 0, 'CHE'),
#   Text(114, 0, 'CHE'),
#   Text(115, 0, 'CHE'),
#   Text(116, 0, 'CHE'),
#   Text(117, 0, 'CHL'),
#   Text(118, 0, 'CHL'),
#   Text(119, 0, 'CHL'),
#   Text(120, 0, 'CHL'),
#   Text(121, 0, 'CHL'),
#   Text(122, 0, 'CHL'),
#   Text(123, 0, 'CHL'),
#   Text(124, 0, 'CHL'),
#   Text(125, 0, 'CHL'),
#   Text(126, 0, 'CHL'),
#   Text(127, 0, 'CHL'),
#   Text(128, 0, 'CHL'),
#   Text(129, 0, 'CHL'),
#   Text(130, 0, 'CHL'),
#   Text(131, 0, 'CHL'),
#   Text(132, 0, 'CHL'),
#   Text(133, 0, 'CHL'),
#   Text(134, 0, 'CHL'),
#   Text(135, 0, 'CHL'),
#   Text(136, 0, 'CHL'),
#   Text(137, 0, 'CHL'),
#   Text(138, 0, 'CHL'),
#   Text(139, 0, 'CHL'),
#   Text(140, 0, 'CHL'),
#   Text(141, 0, 'CHL'),
#   Text(142, 0, 'CHL'),
#   Text(143, 0, 'CHL'),
#   Text(144, 0, 'CHL'),
#   Text(145, 0, 'CHL'),
#   Text(146, 0, 'CHL'),
#   Text(147, 0, 'CHL'),
#   Text(148, 0, 'CHL'),
#   Text(149, 0, 'CHL'),
#   Text(150, 0, 'CHL'),
#   Text(151, 0, 'CHL'),
#   Text(152, 0, 'CHL'),
#   Text(153, 0, 'COL'),
#   Text(154, 0, 'COL'),
#   Text(155, 0, 'COL'),
#   Text(156, 0, 'COL'),
#   Text(157, 0, 'COL'),
#   Text(158, 0, 'COL'),
#   Text(159, 0, 'COL'),
#   Text(160, 0, 'COL'),
#   Text(161, 0, 'COL'),
#   Text(162, 0, 'COL'),
#   Text(163, 0, 'COL'),
#   Text(164, 0, 'COL'),
#   Text(165, 0, 'COL'),
#   Text(166, 0, 'COL'),
#   Text(167, 0, 'COL'),
#   Text(168, 0, 'COL'),
#   Text(169, 0, 'COL'),
#   Text(170, 0, 'COL'),
#   Text(171, 0, 'CRI'),
#   Text(172, 0, 'CRI'),
#   Text(173, 0, 'CRI'),
#   Text(174, 0, 'CRI'),
#   Text(175, 0, 'CRI'),
#   Text(176, 0, 'CZE'),
#   Text(177, 0, 'CZE'),
#   Text(178, 0, 'CZE'),
#   Text(179, 0, 'CZE'),
#   Text(180, 0, 'CZE'),
#   Text(181, 0, 'CZE'),
#   Text(182, 0, 'CZE'),
#   Text(183, 0, 'CZE'),
#   Text(184, 0, 'CZE'),
#   Text(185, 0, 'CZE'),
#   Text(186, 0, 'CZE'),
#   Text(187, 0, 'CZE'),
#   Text(188, 0, 'CZE'),
#   Text(189, 0, 'CZE'),
#   Text(190, 0, 'CZE'),
#   Text(191, 0, 'CZE'),
#   Text(192, 0, 'CZE'),
#   Text(193, 0, 'CZE'),
#   Text(194, 0, 'CZE'),
#   Text(195, 0, 'CZE'),
#   Text(196, 0, 'CZE'),
#   Text(197, 0, 'CZE'),
#   Text(198, 0, 'CZE'),
#   Text(199, 0, 'CZE'),
#   Text(200, 0, 'DEU'),
#   Text(201, 0, 'DEU'),
#   Text(202, 0, 'DEU'),
#   Text(203, 0, 'DEU'),
#   Text(204, 0, 'DEU'),
#   Text(205, 0, 'DEU'),
#   Text(206, 0, 'DEU'),
#   Text(207, 0, 'DEU'),
#   Text(208, 0, 'DEU'),
#   Text(209, 0, 'DEU'),
#   Text(210, 0, 'DEU'),
#   Text(211, 0, 'DEU'),
#   Text(212, 0, 'DEU'),
#   Text(213, 0, 'DEU'),
#   Text(214, 0, 'DEU'),
#   Text(215, 0, 'DEU'),
#   Text(216, 0, 'DEU'),
#   Text(217, 0, 'DEU'),
#   Text(218, 0, 'DNK'),
#   Text(219, 0, 'DNK'),
#   Text(220, 0, 'DNK'),
#   Text(221, 0, 'DNK'),
#   Text(222, 0, 'DNK'),
#   Text(223, 0, 'DNK'),
#   Text(224, 0, 'DNK'),
#   Text(225, 0, 'DNK'),
#   Text(226, 0, 'DNK'),
#   Text(227, 0, 'DNK'),
#   Text(228, 0, 'DNK'),
#   Text(229, 0, 'DNK'),
#   Text(230, 0, 'DNK'),
#   Text(231, 0, 'DNK'),
#   Text(232, 0, 'DNK'),
#   Text(233, 0, 'DNK'),
#   Text(234, 0, 'DNK'),
#   Text(235, 0, 'DNK'),
#   Text(236, 0, 'DNK'),
#   Text(237, 0, 'DNK'),
#   Text(238, 0, 'DNK'),
#   Text(239, 0, 'DNK'),
#   Text(240, 0, 'DNK'),
#   Text(241, 0, 'DNK'),
#   Text(242, 0, 'DNK'),
#   Text(243, 0, 'DNK'),
#   Text(244, 0, 'DNK'),
#   Text(245, 0, 'DNK'),
#   Text(246, 0, 'DNK'),
#   Text(247, 0, 'DNK'),
#   Text(248, 0, 'DNK'),
#   Text(249, 0, 'DNK'),
#   Text(250, 0, 'DNK'),
#   Text(251, 0, 'DNK'),
#   Text(252, 0, 'DNK'),
#   Text(253, 0, 'DNK'),
#   Text(254, 0, 'ESP'),
#   Text(255, 0, 'ESP'),
#   Text(256, 0, 'ESP'),
#   Text(257, 0, 'ESP'),
#   Text(258, 0, 'ESP'),
#   Text(259, 0, 'ESP'),
#   Text(260, 0, 'ESP'),
#   Text(261, 0, 'ESP'),
#   Text(262, 0, 'ESP'),
#   Text(263, 0, 'ESP'),
#   Text(264, 0, 'ESP'),
# ...
#   Text(306, 0, 'FIN'),
#   Text(307, 0, 'FIN'),
#   Text(308, 0, 'FIN'),
#   Text(309, 0, 'FIN'),
#   Text(310, 0, 'FIN'),
#   Text(311, 0, 'FIN'),
#   Text(312, 0, 'FIN'),
#   Text(313, 0, 'FIN'),
#   Text(314, 0, 'FIN'),
#   Text(315, 0, 'FIN'),
#   Text(316, 0, 'FIN'),
#   Text(317, 0, 'FIN'),
#   Text(318, 0, 'FIN'),
#   Text(319, 0, 'FIN'),
#   Text(320, 0, 'FIN'),
#   Text(321, 0, 'FIN'),
#   Text(322, 0, 'FIN'),
#   Text(323, 0, 'FIN'),
#   Text(324, 0, 'FIN'),
#   Text(325, 0, 'FIN'),
#   Text(326, 0, 'FIN'),
#   Text(327, 0, 'FIN'),
#   Text(328, 0, 'FIN'),
#   Text(329, 0, 'FIN'),
#   Text(330, 0, 'FIN'),
#   Text(331, 0, 'FIN'),
#   Text(332, 0, 'FIN'),
#   Text(333, 0, 'FIN'),
#   Text(334, 0, 'FIN'),
#   Text(335, 0, 'FIN'),
#   Text(336, 0, 'FIN'),
#   Text(337, 0, 'FIN'),
#   Text(338, 0, 'FIN'),
#   Text(339, 0, 'FIN'),
#   Text(340, 0, 'GBR'),
#   Text(341, 0, 'GBR'),
#   Text(342, 0, 'GBR'),
#   Text(343, 0, 'GBR'),
#   Text(344, 0, 'GBR'),
#   Text(345, 0, 'GBR'),
#   Text(346, 0, 'GBR'),
#   Text(347, 0, 'GBR'),
#   Text(348, 0, 'GBR'),
#   Text(349, 0, 'GBR'),
#   Text(350, 0, 'GBR'),
#   Text(351, 0, 'GBR'),
#   Text(352, 0, 'GBR'),
#   Text(353, 0, 'GBR'),
#   Text(354, 0, 'GBR'),
#   Text(355, 0, 'GRC'),
#   Text(356, 0, 'GRC'),
#   Text(357, 0, 'GRC'),
#   Text(358, 0, 'GRC'),
#   Text(359, 0, 'GRC'),
#   Text(360, 0, 'GRC'),
#   Text(361, 0, 'GRC'),
#   Text(362, 0, 'GRC'),
#   Text(363, 0, 'GRC'),
#   Text(364, 0, 'GRC'),
#   Text(365, 0, 'GRC'),
#   Text(366, 0, 'GRC'),
#   Text(367, 0, 'GRC'),
#   Text(368, 0, 'GRC'),
#   Text(369, 0, 'GRC'),
#   Text(370, 0, 'GRC'),
#   Text(371, 0, 'GRC'),
#   Text(372, 0, 'GRC'),
#   Text(373, 0, 'GRC'),
#   Text(374, 0, 'GRC'),
#   Text(375, 0, 'GRC'),
#   Text(376, 0, 'HUN'),
#   Text(377, 0, 'HUN'),
#   Text(378, 0, 'HUN'),
#   Text(379, 0, 'HUN'),
#   Text(380, 0, 'HUN'),
#   Text(381, 0, 'HUN'),
#   Text(382, 0, 'HUN'),
#   Text(383, 0, 'HUN'),
#   Text(384, 0, 'HUN'),
#   Text(385, 0, 'HUN'),
#   Text(386, 0, 'HUN'),
#   Text(387, 0, 'HUN'),
#   Text(388, 0, 'HUN'),
#   Text(389, 0, 'HUN'),
#   Text(390, 0, 'HUN'),
#   Text(391, 0, 'HUN'),
#   Text(392, 0, 'HUN'),
#   Text(393, 0, 'HUN'),
#   Text(394, 0, 'HUN'),
#   Text(395, 0, 'HUN'),
#   Text(396, 0, 'HUN'),
#   Text(397, 0, 'HUN'),
#   Text(398, 0, 'HUN'),
#   Text(399, 0, 'HUN'),
#   Text(400, 0, 'HUN'),
#   Text(401, 0, 'HUN'),
#   Text(402, 0, 'HUN'),
#   Text(403, 0, 'HUN'),
#   Text(404, 0, 'HUN'),
#   Text(405, 0, 'HUN'),
#   Text(406, 0, 'HUN'),
#   Text(407, 0, 'HUN'),
#   Text(408, 0, 'HUN'),
#   Text(409, 0, 'HUN'),
#   Text(410, 0, 'HUN'),
#   Text(411, 0, 'HUN'),
#   Text(412, 0, 'IRL'),
#   Text(413, 0, 'IRL'),
#   Text(414, 0, 'IRL'),
#   Text(415, 0, 'IRL'),
#   Text(416, 0, 'IRL'),
#   Text(417, 0, 'IRL'),
#   Text(418, 0, 'IRL'),
#   Text(419, 0, 'IRL'),
#   Text(420, 0, 'IRL'),
#   Text(421, 0, 'IRL'),
#   Text(422, 0, 'IRL'),
#   Text(423, 0, 'IRL'),
#   Text(424, 0, 'IRL'),
#   Text(425, 0, 'IRL'),
#   Text(426, 0, 'IRL'),
#   Text(427, 0, 'IRL'),
#   Text(428, 0, 'IRL'),
#   Text(429, 0, 'IRL'),
#   Text(430, 0, 'ISL'),
#   Text(431, 0, 'ISL'),
#   Text(432, 0, 'ISL'),
#   Text(433, 0, 'ISL'),
#   Text(434, 0, 'ISL'),
#   Text(435, 0, 'ISL'),
#   Text(436, 0, 'ISL'),
#   Text(437, 0, 'ISL'),
#   Text(438, 0, 'ISL'),
#   Text(439, 0, 'ISL'),
#   Text(440, 0, 'ISL'),
#   Text(441, 0, 'ISL'),
#   Text(442, 0, 'ISL'),
#   Text(443, 0, 'ISL'),
#   Text(444, 0, 'ISL'),
#   Text(445, 0, 'ISL'),
#   Text(446, 0, 'ISL'),
#   Text(447, 0, 'ISL'),
#   Text(448, 0, 'ISL'),
#   Text(449, 0, 'ISL'),
#   Text(450, 0, 'ISL'),
#   Text(451, 0, 'ISL'),
#   Text(452, 0, 'ISL'),
#   Text(453, 0, 'ISL'),
#   Text(454, 0, 'ISR'),
#   Text(455, 0, 'ISR'),
#   Text(456, 0, 'ISR'),
#   Text(457, 0, 'ISR'),
#   Text(458, 0, 'ISR'),
#   Text(459, 0, 'ISR'),
#   Text(460, 0, 'ISR'),
#   Text(461, 0, 'ISR'),
#   Text(462, 0, 'ISR'),
#   Text(463, 0, 'ISR'),
#   Text(464, 0, 'ISR'),
#   Text(465, 0, 'ISR'),
#   Text(466, 0, 'ISR'),
#   Text(467, 0, 'ISR'),
#   Text(468, 0, 'ISR'),
#   Text(469, 0, 'ISR'),
#   Text(470, 0, 'ISR'),
#   Text(471, 0, 'ISR'),
#   Text(472, 0, 'ISR'),
#   Text(473, 0, 'ISR'),
#   Text(474, 0, 'ISR'),
#   Text(475, 0, 'ISR'),
#   Text(476, 0, 'ISR'),
#   Text(477, 0, 'ISR'),
#   Text(478, 0, 'ISR'),
#   Text(479, 0, 'ISR'),
#   Text(480, 0, 'ISR'),
#   Text(481, 0, 'ISR'),
#   Text(482, 0, 'ISR'),
#   Text(483, 0, 'ISR'),
#   Text(484, 0, 'ISR'),
#   Text(485, 0, 'ISR'),
#   Text(486, 0, 'ISR'),
#   Text(487, 0, 'ISR'),
#   Text(488, 0, 'ISR'),
#   Text(489, 0, 'ISR'),
#   Text(490, 0, 'ITA'),
#   Text(491, 0, 'ITA'),
#   Text(492, 0, 'ITA'),
#   Text(493, 0, 'ITA'),
#   Text(494, 0, 'ITA'),
#   Text(495, 0, 'ITA'),
#   Text(496, 0, 'ITA'),
#   Text(497, 0, 'ITA'),
#   Text(498, 0, 'ITA'),
#   Text(499, 0, 'ITA'),
#   Text(500, 0, 'KOR'),
#   Text(501, 0, 'KOR'),
#   Text(502, 0, 'KOR'),
#   Text(503, 0, 'KOR'),
#   Text(504, 0, 'KOR'),
#   Text(505, 0, 'KOR'),
#   Text(506, 0, 'KOR'),
#   Text(507, 0, 'KOR'),
#   Text(508, 0, 'KOR'),
#   Text(509, 0, 'KOR'),
#   Text(510, 0, 'KOR'),
#   Text(511, 0, 'KOR'),
#   Text(512, 0, 'KOR'),
#   Text(513, 0, 'KOR'),
#   Text(514, 0, 'KOR'),
#   Text(515, 0, 'KOR'),
#   Text(516, 0, 'KOR'),
#   Text(517, 0, 'KOR'),
#   Text(518, 0, 'LTU'),
#   Text(519, 0, 'LTU'),
#   Text(520, 0, 'LTU'),
#   Text(521, 0, 'LTU'),
#   Text(522, 0, 'LTU'),
#   Text(523, 0, 'LTU'),
#   Text(524, 0, 'LTU'),
#   Text(525, 0, 'LTU'),
#   Text(526, 0, 'LTU'),
#   Text(527, 0, 'LTU'),
#   Text(528, 0, 'LTU'),
#   Text(529, 0, 'LTU'),
#   Text(530, 0, 'LTU'),
#   Text(531, 0, 'LTU'),
#   Text(532, 0, 'LTU'),
#   Text(533, 0, 'LTU'),
#   Text(534, 0, 'LTU'),
#   Text(535, 0, 'LTU'),
#   Text(536, 0, 'LTU'),
#   Text(537, 0, 'LTU'),
#   Text(538, 0, 'LTU'),
#   Text(539, 0, 'LTU'),
#   Text(540, 0, 'LTU'),
#   Text(541, 0, 'LTU'),
#   Text(542, 0, 'LTU'),
#   Text(543, 0, 'LTU'),
#   Text(544, 0, 'LTU'),
#   Text(545, 0, 'LTU'),
#   Text(546, 0, 'LTU'),
#   Text(547, 0, 'LTU'),
#   Text(548, 0, 'LTU'),
#   Text(549, 0, 'LTU'),
#   Text(550, 0, 'LTU'),
#   Text(551, 0, 'LTU'),
#   Text(552, 0, 'LTU'),
#   Text(553, 0, 'LTU'),
#   Text(554, 0, 'LUX'),
#   Text(555, 0, 'LUX'),
#   Text(556, 0, 'LUX'),
#   Text(557, 0, 'LUX'),
#   Text(558, 0, 'LUX'),
#   Text(559, 0, 'LUX'),
#   Text(560, 0, 'LUX'),
#   Text(561, 0, 'LUX'),
#   Text(562, 0, 'LUX'),
#   Text(563, 0, 'LUX'),
#   Text(564, 0, 'LUX'),
#   Text(565, 0, 'LUX'),
#   Text(566, 0, 'LUX'),
#   Text(567, 0, 'LUX'),
#   Text(568, 0, 'LUX'),
#   Text(569, 0, 'LUX'),
#   Text(570, 0, 'LUX'),
#   Text(571, 0, 'LUX'),
#   Text(572, 0, 'LUX'),
#   Text(573, 0, 'LUX'),
#   Text(574, 0, 'LUX'),
#   Text(575, 0, 'LUX'),
#   Text(576, 0, 'LUX'),
#   Text(577, 0, 'LUX'),
#   Text(578, 0, 'LUX'),
#   Text(579, 0, 'LUX'),
#   Text(580, 0, 'LUX'),
#   Text(581, 0, 'LUX'),
#   Text(582, 0, 'LUX'),
#   Text(583, 0, 'LUX'),
#   Text(584, 0, 'LUX'),
#   Text(585, 0, 'LUX'),
#   Text(586, 0, 'LUX'),
#   Text(587, 0, 'LUX'),
#   Text(588, 0, 'LUX'),
#   Text(589, 0, 'LUX'),
#   Text(590, 0, 'LVA'),
#   Text(591, 0, 'LVA'),
#   Text(592, 0, 'LVA'),
#   Text(593, 0, 'LVA'),
#   Text(594, 0, 'LVA'),
#   Text(595, 0, 'LVA'),
#   Text(596, 0, 'LVA'),
#   Text(597, 0, 'LVA'),
#   Text(598, 0, 'LVA'),
#   Text(599, 0, 'LVA'),
#   Text(600, 0, 'LVA'),
#   Text(601, 0, 'LVA'),
#   Text(602, 0, 'LVA'),
#   Text(603, 0, 'LVA'),
#   Text(604, 0, 'LVA'),
#   Text(605, 0, 'LVA'),
#   Text(606, 0, 'LVA'),
#   Text(607, 0, 'LVA'),
#   Text(608, 0, 'LVA'),
#   Text(609, 0, 'LVA'),
#   Text(610, 0, 'LVA'),
#   Text(611, 0, 'LVA'),
#   Text(612, 0, 'LVA'),
#   Text(613, 0, 'LVA'),
#   Text(614, 0, 'LVA'),
#   Text(615, 0, 'LVA'),
#   Text(616, 0, 'LVA'),
#   Text(617, 0, 'LVA'),
#   Text(618, 0, 'LVA'),
#   Text(619, 0, 'LVA'),
#   Text(620, 0, 'LVA'),
#   Text(621, 0, 'LVA'),
#   Text(622, 0, 'LVA'),
#   Text(623, 0, 'MEX'),
#   Text(624, 0, 'MEX'),
#   Text(625, 0, 'MEX'),
#   Text(626, 0, 'MEX'),
#   Text(627, 0, 'MEX'),
#   Text(628, 0, 'MEX'),
#   Text(629, 0, 'MEX'),
#   Text(630, 0, 'MEX'),
#   Text(631, 0, 'MEX'),
#   Text(632, 0, 'MEX'),
#   Text(633, 0, 'MEX'),
#   Text(634, 0, 'MEX'),
#   Text(635, 0, 'MEX'),
#   Text(636, 0, 'MEX'),
#   Text(637, 0, 'MEX'),
#   Text(638, 0, 'MEX'),
#   Text(639, 0, 'MEX'),
#   Text(640, 0, 'MEX'),
#   Text(641, 0, 'MEX'),
#   Text(642, 0, 'MEX'),
#   Text(643, 0, 'MEX'),
#   Text(644, 0, 'NLD'),
#   Text(645, 0, 'NLD'),
#   Text(646, 0, 'NLD'),
#   Text(647, 0, 'NLD'),
#   Text(648, 0, 'NLD'),
#   Text(649, 0, 'NLD'),
#   Text(650, 0, 'NLD'),
#   Text(651, 0, 'NLD'),
#   Text(652, 0, 'NLD'),
#   Text(653, 0, 'NLD'),
#   Text(654, 0, 'NLD'),
#   Text(655, 0, 'NLD'),
#   Text(656, 0, 'NLD'),
#   Text(657, 0, 'NLD'),
#   Text(658, 0, 'NLD'),
#   Text(659, 0, 'NLD'),
#   Text(660, 0, 'NLD'),
#   Text(661, 0, 'NLD'),
#   Text(662, 0, 'NLD'),
#   Text(663, 0, 'NLD'),
#   Text(664, 0, 'NLD'),
#   Text(665, 0, 'NLD'),
#   Text(666, 0, 'NLD'),
#   Text(667, 0, 'NLD'),
#   Text(668, 0, 'NLD'),
#   Text(669, 0, 'NLD'),
#   Text(670, 0, 'NLD'),
#   Text(671, 0, 'NOR'),
#   Text(672, 0, 'NOR'),
#   Text(673, 0, 'NOR'),
#   Text(674, 0, 'NOR'),
#   Text(675, 0, 'NOR'),
#   Text(676, 0, 'NOR'),
#   Text(677, 0, 'NOR'),
#   Text(678, 0, 'NOR'),
#   Text(679, 0, 'NOR'),
#   Text(680, 0, 'NOR'),
#   Text(681, 0, 'NOR'),
#   Text(682, 0, 'NOR'),
#   Text(683, 0, 'NOR'),
#   Text(684, 0, 'NOR'),
#   Text(685, 0, 'NOR'),
#   Text(686, 0, 'NOR'),
#   Text(687, 0, 'NOR'),
#   Text(688, 0, 'NOR'),
#   Text(689, 0, 'NOR'),
#   Text(690, 0, 'NOR'),
#   Text(691, 0, 'NOR'),
#   Text(692, 0, 'NOR'),
#   Text(693, 0, 'NOR'),
#   Text(694, 0, 'NOR'),
#   Text(695, 0, 'NOR'),
#   Text(696, 0, 'NOR'),
#   Text(697, 0, 'NOR'),
#   Text(698, 0, 'NOR'),
#   Text(699, 0, 'NOR'),
#   Text(700, 0, 'NOR'),
#   Text(701, 0, 'NOR'),
#   Text(702, 0, 'NOR'),
#   Text(703, 0, 'NOR'),
#   Text(704, 0, 'NOR'),
#   Text(705, 0, 'NOR'),
#   Text(706, 0, 'NOR'),
#   Text(707, 0, 'NZL'),
#   Text(708, 0, 'NZL'),
#   Text(709, 0, 'NZL'),
#   Text(710, 0, 'NZL'),
#   Text(711, 0, 'NZL'),
#   Text(712, 0, 'NZL'),
#   Text(713, 0, 'NZL'),
#   Text(714, 0, 'NZL'),
#   Text(715, 0, 'NZL'),
#   Text(716, 0, 'NZL'),
#   Text(717, 0, 'NZL'),
#   Text(718, 0, 'NZL'),
#   Text(719, 0, 'NZL'),
#   Text(720, 0, 'NZL'),
#   Text(721, 0, 'NZL'),
#   Text(722, 0, 'NZL'),
#   Text(723, 0, 'NZL'),
#   Text(724, 0, 'NZL'),
#   Text(725, 0, 'NZL'),
#   Text(726, 0, 'NZL'),
#   Text(727, 0, 'NZL'),
#   Text(728, 0, 'NZL'),
#   Text(729, 0, 'NZL'),
#   Text(730, 0, 'NZL'),
#   Text(731, 0, 'NZL'),
#   Text(732, 0, 'NZL'),
#   Text(733, 0, 'NZL'),
#   Text(734, 0, 'NZL'),
#   Text(735, 0, 'NZL'),
#   Text(736, 0, 'NZL'),
#   Text(737, 0, 'NZL'),
#   Text(738, 0, 'NZL'),
#   Text(739, 0, 'NZL'),
#   Text(740, 0, 'NZL'),
#   Text(741, 0, 'NZL'),
#   Text(742, 0, 'NZL'),
#   Text(743, 0, 'OAVG'),
#   Text(744, 0, 'OAVG'),
#   Text(745, 0, 'OAVG'),
#   Text(746, 0, 'OAVG'),
#   Text(747, 0, 'OAVG'),
#   Text(748, 0, 'OAVG'),
#   Text(749, 0, 'OAVG'),
#   Text(750, 0, 'OAVG'),
#   Text(751, 0, 'OAVG'),
#   Text(752, 0, 'OAVG'),
#   Text(753, 0, 'OAVG'),
#   Text(754, 0, 'OAVG'),
#   Text(755, 0, 'OAVG'),
#   Text(756, 0, 'OAVG'),
#   Text(757, 0, 'OAVG'),
#   Text(758, 0, 'OAVG'),
#   Text(759, 0, 'OAVG'),
#   Text(760, 0, 'OAVG'),
#   Text(761, 0, 'OAVG'),
#   Text(762, 0, 'OAVG'),
#   Text(763, 0, 'OAVG'),
#   Text(764, 0, 'OAVG'),
#   Text(765, 0, 'OAVG'),
#   Text(766, 0, 'OAVG'),
#   Text(767, 0, 'OAVG'),
#   Text(768, 0, 'OAVG'),
#   Text(769, 0, 'OAVG'),
#   Text(770, 0, 'POL'),
#   Text(771, 0, 'POL'),
#   Text(772, 0, 'POL'),
#   Text(773, 0, 'POL'),
#   Text(774, 0, 'POL'),
#   Text(775, 0, 'POL'),
#   Text(776, 0, 'POL'),
#   Text(777, 0, 'POL'),
#   Text(778, 0, 'POL'),
#   Text(779, 0, 'POL'),
#   Text(780, 0, 'POL'),
#   Text(781, 0, 'POL'),
#   Text(782, 0, 'POL'),
#   Text(783, 0, 'POL'),
#   Text(784, 0, 'POL'),
#   Text(785, 0, 'POL'),
#   Text(786, 0, 'POL'),
#   Text(787, 0, 'POL'),
#   Text(788, 0, 'POL'),
#   Text(789, 0, 'POL'),
#   Text(790, 0, 'POL'),
#   Text(791, 0, 'POL'),
#   Text(792, 0, 'POL'),
#   Text(793, 0, 'POL'),
#   Text(794, 0, 'POL'),
#   Text(795, 0, 'POL'),
#   Text(796, 0, 'POL'),
#   Text(797, 0, 'POL'),
#   Text(798, 0, 'POL'),
#   Text(799, 0, 'POL'),
#   Text(800, 0, 'POL'),
#   Text(801, 0, 'POL'),
#   Text(802, 0, 'POL'),
#   Text(803, 0, 'POL'),
#   Text(804, 0, 'POL'),
#   Text(805, 0, 'POL'),
#   Text(806, 0, 'PRT'),
#   Text(807, 0, 'PRT'),
#   Text(808, 0, 'PRT'),
#   Text(809, 0, 'PRT'),
#   Text(810, 0, 'PRT'),
#   Text(811, 0, 'PRT'),
#   Text(812, 0, 'PRT'),
#   Text(813, 0, 'PRT'),
#   Text(814, 0, 'PRT'),
#   Text(815, 0, 'PRT'),
#   Text(816, 0, 'PRT'),
#   Text(817, 0, 'PRT'),
#   Text(818, 0, 'PRT'),
#   Text(819, 0, 'PRT'),
#   Text(820, 0, 'PRT'),
#   Text(821, 0, 'PRT'),
#   Text(822, 0, 'PRT'),
#   Text(823, 0, 'PRT'),
#   Text(824, 0, 'PRT'),
#   Text(825, 0, 'PRT'),
#   Text(826, 0, 'PRT'),
#   Text(827, 0, 'PRT'),
#   Text(828, 0, 'PRT'),
#   Text(829, 0, 'PRT'),
#   Text(830, 0, 'PRT'),
#   Text(831, 0, 'PRT'),
#   Text(832, 0, 'PRT'),
#   Text(833, 0, 'PRT'),
#   Text(834, 0, 'PRT'),
#   Text(835, 0, 'PRT'),
#   Text(836, 0, 'PRT'),
#   Text(837, 0, 'PRT'),
#   Text(838, 0, 'PRT'),
#   Text(839, 0, 'PRT'),
#   Text(840, 0, 'SVK'),
#   Text(841, 0, 'SVK'),
#   Text(842, 0, 'SVK'),
#   Text(843, 0, 'SVK'),
#   Text(844, 0, 'SVK'),
#   Text(845, 0, 'SVK'),
#   Text(846, 0, 'SVK'),
#   Text(847, 0, 'SVK'),
#   Text(848, 0, 'SVK'),
#   Text(849, 0, 'SVK'),
#   Text(850, 0, 'SVK'),
#   Text(851, 0, 'SVK'),
#   Text(852, 0, 'SVK'),
#   Text(853, 0, 'SVK'),
#   Text(854, 0, 'SVK'),
#   Text(855, 0, 'SVK'),
#   Text(856, 0, 'SVK'),
#   Text(857, 0, 'SVK'),
#   Text(858, 0, 'SVK'),
#   Text(859, 0, 'SVK'),
#   Text(860, 0, 'SVK'),
#   Text(861, 0, 'SVK'),
#   Text(862, 0, 'SVK'),
#   Text(863, 0, 'SVK'),
#   Text(864, 0, 'SVK'),
#   Text(865, 0, 'SVK'),
#   Text(866, 0, 'SVK'),
#   Text(867, 0, 'SVK'),
#   Text(868, 0, 'SVK'),
#   Text(869, 0, 'SVK'),
#   Text(870, 0, 'SVK'),
#   Text(871, 0, 'SVK'),
#   Text(872, 0, 'SVK'),
#   Text(873, 0, 'SVK'),
#   Text(874, 0, 'SVK'),
#   Text(875, 0, 'SVK'),
#   Text(876, 0, 'SVN'),
#   Text(877, 0, 'SVN'),
#   Text(878, 0, 'SVN'),
#   Text(879, 0, 'SVN'),
#   Text(880, 0, 'SVN'),
#   Text(881, 0, 'SVN'),
#   Text(882, 0, 'SVN'),
#   Text(883, 0, 'SVN'),
#   Text(884, 0, 'SVN'),
#   Text(885, 0, 'SVN'),
#   Text(886, 0, 'SVN'),
#   Text(887, 0, 'SVN'),
#   Text(888, 0, 'SVN'),
#   Text(889, 0, 'SVN'),
#   Text(890, 0, 'SVN'),
#   Text(891, 0, 'SVN'),
#   Text(892, 0, 'SVN'),
#   Text(893, 0, 'SVN'),
#   Text(894, 0, 'SVN'),
#   Text(895, 0, 'SVN'),
#   Text(896, 0, 'SVN'),
#   Text(897, 0, 'SVN'),
#   Text(898, 0, 'SWE'),
#   Text(899, 0, 'SWE'),
#   Text(900, 0, 'SWE'),
#   Text(901, 0, 'SWE'),
#   Text(902, 0, 'SWE'),
#   Text(903, 0, 'SWE'),
#   Text(904, 0, 'SWE'),
#   Text(905, 0, 'SWE'),
#   Text(906, 0, 'SWE'),
#   Text(907, 0, 'SWE'),
#   Text(908, 0, 'SWE'),
#   Text(909, 0, 'SWE'),
#   Text(910, 0, 'SWE'),
#   Text(911, 0, 'SWE'),
#   Text(912, 0, 'SWE'),
#   Text(913, 0, 'SWE'),
#   Text(914, 0, 'SWE'),
#   Text(915, 0, 'SWE'),
#   Text(916, 0, 'SWE'),
#   Text(917, 0, 'SWE'),
#   Text(918, 0, 'SWE'),
#   Text(919, 0, 'SWE'),
#   Text(920, 0, 'SWE'),
#   Text(921, 0, 'SWE'),
#   Text(922, 0, 'SWE'),
#   Text(923, 0, 'SWE'),
#   Text(924, 0, 'SWE'),
#   Text(925, 0, 'SWE'),
#   Text(926, 0, 'SWE'),
#   Text(927, 0, 'SWE'),
#   Text(928, 0, 'SWE'),
#   Text(929, 0, 'SWE'),
#   Text(930, 0, 'SWE'),
#   Text(931, 0, 'SWE'),
#   Text(932, 0, 'SWE'),
#   Text(933, 0, 'SWE'),
#   Text(934, 0, 'TUR'),
#   Text(935, 0, 'TUR'),
#   Text(936, 0, 'TUR'),
#   Text(937, 0, 'TUR'),
#   Text(938, 0, 'TUR'),
#   Text(939, 0, 'TUR'),
#   Text(940, 0, 'TUR'),
#   Text(941, 0, 'TUR'),
#   Text(942, 0, 'TUR'),
#   Text(943, 0, 'TUR'),
#   Text(944, 0, 'TUR'),
#   Text(945, 0, 'TUR'),
#   Text(946, 0, 'TUR'),
#   Text(947, 0, 'TUR'),
#   Text(948, 0, 'TUR'),
#   Text(949, 0, 'TUR'),
#   Text(950, 0, 'TUR'),
#   Text(951, 0, 'TUR'),
#   Text(952, 0, 'TUR'),
#   Text(953, 0, 'TUR'),
#   Text(954, 0, 'TUR'),
#   Text(955, 0, 'TUR'),
#   Text(956, 0, 'TUR'),
#   Text(957, 0, 'TUR'),
#   Text(958, 0, 'TUR'),
#   Text(959, 0, 'TUR'),
#   Text(960, 0, 'TUR'),
#   Text(961, 0, 'TUR'),
#   Text(962, 0, 'TUR'),
#   Text(963, 0, 'TUR'),
#   Text(964, 0, 'TUR'),
#   Text(965, 0, 'TUR'),
#   Text(966, 0, 'TUR'),
#   Text(967, 0, 'TUR'),
#   Text(968, 0, 'USA'),
#   Text(969, 0, 'USA'),
#   Text(970, 0, 'USA'),
#   Text(971, 0, 'USA'),
#   Text(972, 0, 'USA'),
#   Text(973, 0, 'USA'),
#   Text(974, 0, 'USA'),
#   Text(975, 0, 'USA'),
#   Text(976, 0, 'USA'),
#   Text(977, 0, 'USA'),
#   Text(978, 0, 'USA'),
#   Text(979, 0, 'USA'),
#   Text(980, 0, 'USA'),
#   Text(981, 0, 'USA'),
#   Text(982, 0, 'USA'),
#   Text(983, 0, 'USA'),
#   Text(984, 0, 'USA'),
#   Text(985, 0, 'USA'),
#   Text(986, 0, 'USA'),
#   Text(987, 0, 'USA'),
#   Text(988, 0, 'USA'),
#   Text(989, 0, 'USA'),
#   Text(990, 0, 'USA'),
#   Text(991, 0, 'USA'),
#   Text(992, 0, 'USA'),
#   Text(993, 0, 'USA'),
#   Text(994, 0, 'USA'),
#   Text(995, 0, 'USA'),
#   Text(996, 0, 'USA'),
#   Text(997, 0, 'USA'),
#   Text(998, 0, 'USA'),
#   Text(999, 0, 'USA'),
#   ...])

# %%
# plt.figure(figsize=(10, 6))
# Secondary_completion_rates[Secondary_completion_rates=="UPPSRY_WOMEN"].plot()
# filtered_Secondary_completion_rates = Secondary_completion_rates[Secondary_completion_rates['SUBJECT'] == 'UPPSRY_WOMEN']
# plt.title('Graduation Rates of WOMEN by Location')
# plt.xlabel('Year')
# plt.ylabel('Graduation Rate (%)')
# plt.xticks(filtered_Secondary_completion_rates['LOCATION'])
# plt.grid(True)
# plt.show()

filtered_Secondary_completion_rates = Secondary_completion_rates[Secondary_completion_rates['SUBJECT'] == 'UPPSRY_WOMEN']
plt.figure(figsize=(10, 6))
plt.bar(filtered_Secondary_completion_rates['LOCATION'], filtered_Secondary_completion_rates['Value'])
plt.title('Graduation Rates of WOMEN by Location')
plt.xlabel('Location')
plt.ylabel('Graduation Rate (%)')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
