# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
from datetime import datetime

# %%
# %matplotlib inline

# %%
plt.rcParams["figure.figsize"] = (10, 5)

# %%
saved_style_state = matplotlib.rcParams.copy()

# %%
Secondary_completion_rates = pd.read_csv("Secondary completion rates.csv", skiprows=1)
print("done")
# Out:
# done

# %%
Secondary_completion_rates.head()
# Out:
#   LOCATION INDICATOR SUBJECT MEASURE FREQUENCY  TIME   Value  Flag Codes
# 0      AUT  GRADRATE  UPPSRY      PC         A  2010  84.210         NaN
# 1      AUT  GRADRATE  UPPSRY      PC         A  2011  83.621         NaN
# 2      AUT  GRADRATE  UPPSRY      PC         A  2012  84.955         NaN
# 3      AUT  GRADRATE  UPPSRY      PC         A  2013  83.765         NaN
# 4      AUT  GRADRATE  UPPSRY      PC         A  2014  83.544         NaN

# %%
Secondary_completion_rates.sample(5)
# Out:
#      LOCATION INDICATOR         SUBJECT MEASURE FREQUENCY  TIME   Value  \
# 768       USA  GRADRATE      UPPSRY_MEN      PC         A  2019  83.964
# 1553      COL  GRADRATE  P_SRY_NTRY_MEN      PC         A  2016   0.228
# 679       CHE  GRADRATE          UPPSRY      PC         A  2019  83.669
# 910       LVA  GRADRATE          UPPSRY      PC         A  2012  89.638
# 383       MEX  GRADRATE    UPPSRY_WOMEN      PC         A  2005  41.696
#
#       Flag Codes
# 768          NaN
# 1553         NaN
# 679          NaN
# 910          NaN
# 383          NaN

# %%
Secondary_completion_rates.columns
# Out:
# Index(['LOCATION', 'INDICATOR', 'SUBJECT', 'MEASURE', 'FREQUENCY', 'TIME',
#        'Value', 'Flag Codes'],
#       dtype='object')

# %%
row_one = Secondary_completion_rates.iloc[1]
row_one
# Out:
# LOCATION           AUT
# INDICATOR     GRADRATE
# SUBJECT         UPPSRY
# MEASURE             PC
# FREQUENCY            A
# TIME              2011
# Value           83.621
# Flag Codes         NaN
# Name: 1, dtype: object

# %%
row_one = ["Value"]

# %%
Secondary_completion_rates.Value
# Out:
# 0       84.210
# 1       83.621
# 2       84.955
# 3       83.765
# 4       83.544
#          ...
# 1757    81.416
# 1758    82.614
# 1759    83.794
# 1760    83.810
# 1761    85.871
# Name: Value, Length: 1762, dtype: float64

# %%
# Secondary_completion_rates["Value"].plot()
# Secondary_completion_rates["Value"].plot(x="TIME", y="Value")
Secondary_completion_rates_sorted = Secondary_completion_rates.sort_values(by='LOCATION')
Secondary_completion_rates.plot(x='LOCATION', y='Value')
plt.xlabel("LOCATION")
plt.ylabel("Value")
plt.show()

# %%
# Secondary_completion_rates.Value.hist()
# Secondary_completion_rates.plot(x="LOCATION", y="Value", kind='hist')
Secondary_completion_rates_sorted = Secondary_completion_rates.sort_values(by='LOCATION')
plt.bar(range(len(Secondary_completion_rates_sorted['LOCATION'])), Secondary_completion_rates_sorted['Value'])
step =40
plt.xticks(range(0, len(Secondary_completion_rates_sorted['LOCATION']), step), 
        Secondary_completion_rates_sorted['LOCATION'][::step], rotation=90)
# plt.hist(Secondary_completion_rates_sorted['Value'])
plt.xlabel("LOCATION")
plt.ylabel("Value")
# Out:
# Text(0, 0.5, 'Value')

# %%
Secondary_completion_rates_sorted = Secondary_completion_rates.sort_values(by='LOCATION')
plt.bar(range(len(Secondary_completion_rates_sorted['LOCATION'])), Secondary_completion_rates_sorted['Value'])
step =40
plt.xticks(range(0, len(Secondary_completion_rates_sorted['LOCATION']), step), 
        Secondary_completion_rates_sorted['LOCATION'][::step], rotation=90)
filtered_data = Secondary_completion_rates[Secondary_completion_rates['Value'] >= 50]
filtered_data_sorted = filtered_data.sort_values(by='LOCATION')
plt.bar(range(len(filtered_data_sorted['LOCATION'])), filtered_data_sorted['Value'])
plt.xlabel("LOCATION")
plt.ylabel("Value")
plt.xticks(range(len(filtered_data_sorted['LOCATION'])), filtered_data_sorted['LOCATION'], rotation=90)
# Out:
# ([<matplotlib.axis.XTick at 0x344a8a110>,
#   <matplotlib.axis.XTick at 0x344aa51d0>,
#   <matplotlib.axis.XTick at 0x344a7bb10>,
#   <matplotlib.axis.XTick at 0x346008910>,
#   <matplotlib.axis.XTick at 0x34600ad10>,
#   <matplotlib.axis.XTick at 0x346010590>,
#   <matplotlib.axis.XTick at 0x346012890>,
#   <matplotlib.axis.XTick at 0x34601ca10>,
#   <matplotlib.axis.XTick at 0x34601edd0>,
#   <matplotlib.axis.XTick at 0x3460250d0>,
#   <matplotlib.axis.XTick at 0x34601d910>,
#   <matplotlib.axis.XTick at 0x346027990>,
#   <matplotlib.axis.XTick at 0x346029ad0>,
#   <matplotlib.axis.XTick at 0x34602be50>,
#   <matplotlib.axis.XTick at 0x3460321d0>,
#   <matplotlib.axis.XTick at 0x34603c350>,
#   <matplotlib.axis.XTick at 0x346012fd0>,
#   <matplotlib.axis.XTick at 0x34603ebd0>,
#   <matplotlib.axis.XTick at 0x346048e50>,
#   <matplotlib.axis.XTick at 0x34604ae90>,
#   <matplotlib.axis.XTick at 0x3460510d0>,
#   <matplotlib.axis.XTick at 0x34603f490>,
#   <matplotlib.axis.XTick at 0x346053950>,
#   <matplotlib.axis.XTick at 0x3460599d0>,
#   <matplotlib.axis.XTick at 0x34605bc10>,
#   <matplotlib.axis.XTick at 0x34605dd90>,
#   <matplotlib.axis.XTick at 0x34605ff50>,
#   <matplotlib.axis.XTick at 0x34604b790>,
#   <matplotlib.axis.XTick at 0x3460624d0>,
#   <matplotlib.axis.XTick at 0x3460645d0>,
#   <matplotlib.axis.XTick at 0x346066850>,
#   <matplotlib.axis.XTick at 0x346070990>,
#   <matplotlib.axis.XTick at 0x346061890>,
#   <matplotlib.axis.XTick at 0x3460726d0>,
#   <matplotlib.axis.XTick at 0x346074810>,
#   <matplotlib.axis.XTick at 0x346076950>,
#   <matplotlib.axis.XTick at 0x34607c990>,
#   <matplotlib.axis.XTick at 0x34607eb10>,
#   <matplotlib.axis.XTick at 0x34607c310>,
#   <matplotlib.axis.XTick at 0x346080f90>,
#   <matplotlib.axis.XTick at 0x346082fd0>,
#   <matplotlib.axis.XTick at 0x346085190>,
#   <matplotlib.axis.XTick at 0x346087290>,
#   <matplotlib.axis.XTick at 0x344ad4210>,
#   <matplotlib.axis.XTick at 0x346091990>,
#   <matplotlib.axis.XTick at 0x34179b650>,
#   <matplotlib.axis.XTick at 0x346929210>,
#   <matplotlib.axis.XTick at 0x346929950>,
#   <matplotlib.axis.XTick at 0x34692cdd0>,
#   <matplotlib.axis.XTick at 0x34692ee50>,
#   <matplotlib.axis.XTick at 0x346931050>,
#   <matplotlib.axis.XTick at 0x346933150>,
#   <matplotlib.axis.XTick at 0x34692e450>,
#   <matplotlib.axis.XTick at 0x346939e10>,
#   <matplotlib.axis.XTick at 0x34693bf10>,
#   <matplotlib.axis.XTick at 0x34693df90>,
#   <matplotlib.axis.XTick at 0x346948150>,
#   <matplotlib.axis.XTick at 0x34693ca10>,
#   <matplotlib.axis.XTick at 0x34694ac50>,
#   <matplotlib.axis.XTick at 0x346950e90>,
#   <matplotlib.axis.XTick at 0x346952f90>,
#   <matplotlib.axis.XTick at 0x34695d190>,
#   <matplotlib.axis.XTick at 0x346952850>,
#   <matplotlib.axis.XTick at 0x34695fa90>,
#   <matplotlib.axis.XTick at 0x346961b50>,
#   <matplotlib.axis.XTick at 0x346963cd0>,
#   <matplotlib.axis.XTick at 0x346969d50>,
#   <matplotlib.axis.XTick at 0x34696bf10>,
#   <matplotlib.axis.XTick at 0x34693ed90>,
#   <matplotlib.axis.XTick at 0x34696e4d0>,
#   <matplotlib.axis.XTick at 0x3469785d0>,
#   <matplotlib.axis.XTick at 0x34697a850>,
#   <matplotlib.axis.XTick at 0x346980950>,
#   <matplotlib.axis.XTick at 0x34696f390>,
#   <matplotlib.axis.XTick at 0x346983090>,
#   <matplotlib.axis.XTick at 0x346989150>,
#   <matplotlib.axis.XTick at 0x34698b1d0>,
#   <matplotlib.axis.XTick at 0x34698d390>,
#   <matplotlib.axis.XTick at 0x34698f590>,
#   <matplotlib.axis.XTick at 0x34698da90>,
#   <matplotlib.axis.XTick at 0x346991810>,
#   <matplotlib.axis.XTick at 0x346993850>,
#   <matplotlib.axis.XTick at 0x346999990>,
#   <matplotlib.axis.XTick at 0x34699bb50>,
#   <matplotlib.axis.XTick at 0x346991f90>,
#   <matplotlib.axis.XTick at 0x3469a6250>,
#   <matplotlib.axis.XTick at 0x3469a8390>,
#   <matplotlib.axis.XTick at 0x3469aa510>,
#   <matplotlib.axis.XTick at 0x3469b0450>,
#   <matplotlib.axis.XTick at 0x3469a9590>,
#   <matplotlib.axis.XTick at 0x3469b29d0>,
#   <matplotlib.axis.XTick at 0x3469b8ad0>,
#   <matplotlib.axis.XTick at 0x3469baad0>,
#   <matplotlib.axis.XTick at 0x3469c0b90>,
#   <matplotlib.axis.XTick at 0x3469c2c10>,
#   <matplotlib.axis.XTick at 0x3469c1dd0>,
#   <matplotlib.axis.XTick at 0x3469c91d0>,
#   <matplotlib.axis.XTick at 0x3469cb310>,
#   <matplotlib.axis.XTick at 0x3469d53d0>,
#   <matplotlib.axis.XTick at 0x3469d7310>,
#   <matplotlib.axis.XTick at 0x3469c8310>,
#   <matplotlib.axis.XTick at 0x346949a50>,
#   <matplotlib.axis.XTick at 0x3469da110>,
#   <matplotlib.axis.XTick at 0x3469e42d0>,
#   <matplotlib.axis.XTick at 0x3469e6310>,
#   <matplotlib.axis.XTick at 0x3469f03d0>,
#   <matplotlib.axis.XTick at 0x3469b1390>,
#   <matplotlib.axis.XTick at 0x3469f2790>,
#   <matplotlib.axis.XTick at 0x3469f48d0>,
#   <matplotlib.axis.XTick at 0x3469f69d0>,
#   <matplotlib.axis.XTick at 0x3469f8ad0>,
#   <matplotlib.axis.XTick at 0x3469f35d0>,
#   <matplotlib.axis.XTick at 0x3469faf90>,
#   <matplotlib.axis.XTick at 0x346a01110>,
#   <matplotlib.axis.XTick at 0x346a03190>,
#   <matplotlib.axis.XTick at 0x346a09210>,
#   <matplotlib.axis.XTick at 0x346a0b290>,
#   <matplotlib.axis.XTick at 0x346a0a110>,
#   <matplotlib.axis.XTick at 0x346a15650>,
#   <matplotlib.axis.XTick at 0x346a17690>,
#   <matplotlib.axis.XTick at 0x346a1d850>,
#   <matplotlib.axis.XTick at 0x346a1f990>,
#   <matplotlib.axis.XTick at 0x346a14c50>,
#   <matplotlib.axis.XTick at 0x346a21ed0>,
#   <matplotlib.axis.XTick at 0x346a23fd0>,
#   <matplotlib.axis.XTick at 0x346a2a110>,
#   <matplotlib.axis.XTick at 0x346a30250>,
#   <matplotlib.axis.XTick at 0x3469499d0>,
#   <matplotlib.axis.XTick at 0x346a32650>,
#   <matplotlib.axis.XTick at 0x346a38790>,
#   <matplotlib.axis.XTick at 0x346a3a7d0>,
#   <matplotlib.axis.XTick at 0x346a407d0>,
#   <matplotlib.axis.XTick at 0x346a42910>,
#   <matplotlib.axis.XTick at 0x346a1fbd0>,
#   <matplotlib.axis.XTick at 0x346a44ed0>,
#   <matplotlib.axis.XTick at 0x346a46e10>,
#   <matplotlib.axis.XTick at 0x346a48f10>,
#   <matplotlib.axis.XTick at 0x346a4afd0>,
#   <matplotlib.axis.XTick at 0x346a496d0>,
#   <matplotlib.axis.XTick at 0x346a51610>,
#   <matplotlib.axis.XTick at 0x346a53610>,
#   <matplotlib.axis.XTick at 0x346a5d690>,
#   <matplotlib.axis.XTick at 0x346a5f6d0>,
#   <matplotlib.axis.XTick at 0x346a61810>,
#   <matplotlib.axis.XTick at 0x346a61010>,
#   <matplotlib.axis.XTick at 0x346a63d90>,
#   <matplotlib.axis.XTick at 0x346a69d90>,
#   <matplotlib.axis.XTick at 0x346a6bf10>,
#   <matplotlib.axis.XTick at 0x346a75f90>,
#   <matplotlib.axis.XTick at 0x346a63690>,
#   <matplotlib.axis.XTick at 0x346a78610>,
#   <matplotlib.axis.XTick at 0x346a7a790>,
#   <matplotlib.axis.XTick at 0x346a84810>,
#   <matplotlib.axis.XTick at 0x346a868d0>,
#   <matplotlib.axis.XTick at 0x346a88910>,
#   <matplotlib.axis.XTick at 0x346a6b710>,
#   <matplotlib.axis.XTick at 0x346a8ab50>,
#   <matplotlib.axis.XTick at 0x346a8cc90>,
#   <matplotlib.axis.XTick at 0x346a8ec50>,
#   <matplotlib.axis.XTick at 0x346a98d10>,
#   <matplotlib.axis.XTick at 0x346a89690>,
#   <matplotlib.axis.XTick at 0x346a9b310>,
#   <matplotlib.axis.XTick at 0x346a9d490>,
#   <matplotlib.axis.XTick at 0x346a9f4d0>,
#   <matplotlib.axis.XTick at 0x346aa9490>,
#   <matplotlib.axis.XTick at 0x346a9df10>,
#   <matplotlib.axis.XTick at 0x346a20550>,
#   <matplotlib.axis.XTick at 0x346aac650>,
#   <matplotlib.axis.XTick at 0x346aae790>,
#   <matplotlib.axis.XTick at 0x346ab0810>,
#   <matplotlib.axis.XTick at 0x346ab2890>,
#   <matplotlib.axis.XTick at 0x346a8d5d0>,
#   <matplotlib.axis.XTick at 0x346ab4d90>,
#   <matplotlib.axis.XTick at 0x346ab6e50>,
#   <matplotlib.axis.XTick at 0x346abcfd0>,
#   <matplotlib.axis.XTick at 0x346abef50>,
#   <matplotlib.axis.XTick at 0x346ab6790>,
#   <matplotlib.axis.XTick at 0x346acd590>,
#   <matplotlib.axis.XTick at 0x346acf550>,
#   <matplotlib.axis.XTick at 0x346ad5690>,
#   <matplotlib.axis.XTick at 0x346ad76d0>,
#   <matplotlib.axis.XTick at 0x346ad9410>,
#   <matplotlib.axis.XTick at 0x346ad8c90>,
#   <matplotlib.axis.XTick at 0x346adb8d0>,
#   <matplotlib.axis.XTick at 0x346ae1950>,
#   <matplotlib.axis.XTick at 0x346ae3990>,
#   <matplotlib.axis.XTick at 0x346ae5b10>,
#   <matplotlib.axis.XTick at 0x346abe990>,
#   <matplotlib.axis.XTick at 0x346ae7fd0>,
#   <matplotlib.axis.XTick at 0x346af2050>,
#   <matplotlib.axis.XTick at 0x346afc150>,
#   <matplotlib.axis.XTick at 0x346afe0d0>,
#   <matplotlib.axis.XTick at 0x346b001d0>,
#   <matplotlib.axis.XTick at 0x346ae2a90>,
#   <matplotlib.axis.XTick at 0x346b024d0>,
#   <matplotlib.axis.XTick at 0x346b04490>,
#   <matplotlib.axis.XTick at 0x346b06490>,
#   <matplotlib.axis.XTick at 0x346b0c550>,
#   <matplotlib.axis.XTick at 0x346b01d50>,
#   <matplotlib.axis.XTick at 0x346b0ea90>,
#   <matplotlib.axis.XTick at 0x346b14a50>,
#   <matplotlib.axis.XTick at 0x346b16ad0>,
#   <matplotlib.axis.XTick at 0x346b24b10>,
#   <matplotlib.axis.XTick at 0x346b15890>,
#   <matplotlib.axis.XTick at 0x346b27090>,
#   <matplotlib.axis.XTick at 0x346b2d090>,
#   <matplotlib.axis.XTick at 0x346b2f150>,
#   <matplotlib.axis.XTick at 0x346b310d0>,
#   <matplotlib.axis.XTick at 0x346b331d0>,
#   <matplotlib.axis.XTick at 0x346b32850>,
#   <matplotlib.axis.XTick at 0x346b35690>,
#   <matplotlib.axis.XTick at 0x346b37810>,
#   <matplotlib.axis.XTick at 0x346b39890>,
#   <matplotlib.axis.XTick at 0x346b3b8d0>,
#   <matplotlib.axis.XTick at 0x346b370d0>,
#   <matplotlib.axis.XTick at 0x346b41e90>,
#   <matplotlib.axis.XTick at 0x346b43f90>,
#   <matplotlib.axis.XTick at 0x346b4a050>,
#   <matplotlib.axis.XTick at 0x346b50150>,
#   <matplotlib.axis.XTick at 0x346b52050>,
#   <matplotlib.axis.XTick at 0x346b517d0>,
#   <matplotlib.axis.XTick at 0x346b543d0>,
#   <matplotlib.axis.XTick at 0x346b563d0>,
#   <matplotlib.axis.XTick at 0x346b58410>,
#   <matplotlib.axis.XTick at 0x346b5a590>,
#   <matplotlib.axis.XTick at 0x346b52a90>,
#   <matplotlib.axis.XTick at 0x346b68990>,
#   <matplotlib.axis.XTick at 0x346b6a950>,
#   <matplotlib.axis.XTick at 0x346b708d0>,
#   <matplotlib.axis.XTick at 0x346b728d0>,
#   <matplotlib.axis.XTick at 0x346b71450>,
#   <matplotlib.axis.XTick at 0x346b25a50>,
#   <matplotlib.axis.XTick at 0x346b796d0>,
#   <matplotlib.axis.XTick at 0x346b7b810>,
#   <matplotlib.axis.XTick at 0x346b85810>,
#   <matplotlib.axis.XTick at 0x346b87910>,
#   <matplotlib.axis.XTick at 0x346a997d0>,
#   <matplotlib.axis.XTick at 0x346b89e50>,
#   <matplotlib.axis.XTick at 0x346b8bf10>,
#   <matplotlib.axis.XTick at 0x346b91ed0>,
#   <matplotlib.axis.XTick at 0x346b93f90>,
#   <matplotlib.axis.XTick at 0x346b92690>,
#   <matplotlib.axis.XTick at 0x346b965d0>,
#   <matplotlib.axis.XTick at 0x346b986d0>,
#   <matplotlib.axis.XTick at 0x346b9a750>,
#   <matplotlib.axis.XTick at 0x346ba4850>,
#   <matplotlib.axis.XTick at 0x346ba6950>,
#   <matplotlib.axis.XTick at 0x346ba6210>,
#   <matplotlib.axis.XTick at 0x346baced0>,
#   <matplotlib.axis.XTick at 0x346baf090>,
#   <matplotlib.axis.XTick at 0x346bb0dd0>,
#   <matplotlib.axis.XTick at 0x346bb2d90>,
#   <matplotlib.axis.XTick at 0x346badd90>,
#   <matplotlib.axis.XTick at 0x346bb9310>,
#   <matplotlib.axis.XTick at 0x346bbb390>,
#   <matplotlib.axis.XTick at 0x346bbd4d0>,
#   <matplotlib.axis.XTick at 0x346bbf5d0>,
#   <matplotlib.axis.XTick at 0x346bc95d0>,
#   <matplotlib.axis.XTick at 0x346bc8650>,
#   <matplotlib.axis.XTick at 0x346bcb850>,
#   <matplotlib.axis.XTick at 0x346bd1910>,
#   <matplotlib.axis.XTick at 0x346bd3910>,
#   <matplotlib.axis.XTick at 0x346bd9a10>,
#   <matplotlib.axis.XTick at 0x346bca010>,
#   <matplotlib.axis.XTick at 0x346bdbfd0>,
#   <matplotlib.axis.XTick at 0x346bde090>,
#   <matplotlib.axis.XTick at 0x346bdffd0>,
#   <matplotlib.axis.XTick at 0x346be6010>,
#   <matplotlib.axis.XTick at 0x346bdef50>,
#   <matplotlib.axis.XTick at 0x346be8610>,
#   <matplotlib.axis.XTick at 0x346bea790>,
#   <matplotlib.axis.XTick at 0x346bf0710>,
#   <matplotlib.axis.XTick at 0x346bf27d0>,
#   <matplotlib.axis.XTick at 0x346c00490>,
#   <matplotlib.axis.XTick at 0x346bdb790>,
#   <matplotlib.axis.XTick at 0x346c02990>,
#   <matplotlib.axis.XTick at 0x346c08a90>,
#   <matplotlib.axis.XTick at 0x346c0aa90>,
#   <matplotlib.axis.XTick at 0x346c10ad0>,
#   <matplotlib.axis.XTick at 0x346c03450>,
#   <matplotlib.axis.XTick at 0x346c13210>,
#   <matplotlib.axis.XTick at 0x346c15310>,
#   <matplotlib.axis.XTick at 0x346c17310>,
#   <matplotlib.axis.XTick at 0x346c19390>,
#   <matplotlib.axis.XTick at 0x346c1b450>,
#   <matplotlib.axis.XTick at 0x346c19f10>,
#   <matplotlib.axis.XTick at 0x346c29690>,
#   <matplotlib.axis.XTick at 0x346c2b6d0>,
#   <matplotlib.axis.XTick at 0x346c31790>,
#   <matplotlib.axis.XTick at 0x346c33890>,
#   <matplotlib.axis.XTick at 0x346c2a1d0>,
#   <matplotlib.axis.XTick at 0x346c35d90>,
#   <matplotlib.axis.XTick at 0x346c37e10>,
#   <matplotlib.axis.XTick at 0x346c39d50>,
#   <matplotlib.axis.XTick at 0x346c3be10>,
#   <matplotlib.axis.XTick at 0x346c39750>,
#   <matplotlib.axis.XTick at 0x346bda150>,
#   <matplotlib.axis.XTick at 0x346c3ed50>,
#   <matplotlib.axis.XTick at 0x346c48dd0>,
#   <matplotlib.axis.XTick at 0x346c4ad10>,
#   <matplotlib.axis.XTick at 0x346c4cd90>,
#   <matplotlib.axis.XTick at 0x346c11650>,
#   <matplotlib.axis.XTick at 0x346c4f390>,
#   <matplotlib.axis.XTick at 0x346c592d0>,
#   <matplotlib.axis.XTick at 0x346c5b310>,
#   <matplotlib.axis.XTick at 0x346c5d550>,
#   <matplotlib.axis.XTick at 0x346c59dd0>,
#   <matplotlib.axis.XTick at 0x346c5fb10>,
#   <matplotlib.axis.XTick at 0x346c61bd0>,
#   <matplotlib.axis.XTick at 0x346c63c90>,
#   <matplotlib.axis.XTick at 0x346c6dc50>,
#   <matplotlib.axis.XTick at 0x346c6fd50>,
#   <matplotlib.axis.XTick at 0x346c3e810>,
#   <matplotlib.axis.XTick at 0x346c7a110>,
#   <matplotlib.axis.XTick at 0x346c80250>,
#   <matplotlib.axis.XTick at 0x346c82250>,
#   <matplotlib.axis.XTick at 0x346c882d0>,
#   <matplotlib.axis.XTick at 0x346c01050>,
#   <matplotlib.axis.XTick at 0x346c8a890>,
#   <matplotlib.axis.XTick at 0x346c8c890>,
#   <matplotlib.axis.XTick at 0x346c8e8d0>,
#   <matplotlib.axis.XTick at 0x346c94a10>,
#   <matplotlib.axis.XTick at 0x346c96a50>,
#   <matplotlib.axis.XTick at 0x346c95890>,
#   <matplotlib.axis.XTick at 0x346c9ced0>,
#   <matplotlib.axis.XTick at 0x346c9eed0>,
#   <matplotlib.axis.XTick at 0x346ca0e90>,
#   <matplotlib.axis.XTick at 0x346ca2f10>,
#   <matplotlib.axis.XTick at 0x346c9dd10>,
#   <matplotlib.axis.XTick at 0x346ca9390>,
#   <matplotlib.axis.XTick at 0x346cab490>,
#   <matplotlib.axis.XTick at 0x346cb1610>,
#   <matplotlib.axis.XTick at 0x346cb3710>,
#   <matplotlib.axis.XTick at 0x346cb2150>,
#   <matplotlib.axis.XTick at 0x346cb9bd0>,
#   <matplotlib.axis.XTick at 0x346cbbb10>,
#   <matplotlib.axis.XTick at 0x346cbdc50>,
#   <matplotlib.axis.XTick at 0x346cbfd10>,
#   <matplotlib.axis.XTick at 0x346cc5e10>,
#   <matplotlib.axis.XTick at 0x346cc57d0>,
#   <matplotlib.axis.XTick at 0x346cc8450>,
#   <matplotlib.axis.XTick at 0x346cca5d0>,
#   <matplotlib.axis.XTick at 0x346ccc450>,
#   <matplotlib.axis.XTick at 0x346cce390>,
#   <matplotlib.axis.XTick at 0x346cc7310>,
#   <matplotlib.axis.XTick at 0x346ce09d0>,
#   <matplotlib.axis.XTick at 0x346ce29d0>,
#   <matplotlib.axis.XTick at 0x346ce4ad0>,
#   <matplotlib.axis.XTick at 0x346ce6b50>,
#   <matplotlib.axis.XTick at 0x346ce8b90>,
#   <matplotlib.axis.XTick at 0x346ccb150>,
#   <matplotlib.axis.XTick at 0x346ceae90>,
#   <matplotlib.axis.XTick at 0x346cf4f50>,
#   <matplotlib.axis.XTick at 0x346cf7150>,
#   <matplotlib.axis.XTick at 0x346cfd090>,
#   <matplotlib.axis.XTick at 0x346ce9d50>,
#   <matplotlib.axis.XTick at 0x346cff690>,
#   <matplotlib.axis.XTick at 0x346d05790>,
#   <matplotlib.axis.XTick at 0x346d07850>,
#   <matplotlib.axis.XTick at 0x346d0d910>,
#   <matplotlib.axis.XTick at 0x346d06390>,
#   <matplotlib.axis.XTick at 0x346c88e10>,
#   <matplotlib.axis.XTick at 0x346d18990>,
#   <matplotlib.axis.XTick at 0x346d1a990>,
#   <matplotlib.axis.XTick at 0x346d20a10>,
#   <matplotlib.axis.XTick at 0x346d229d0>,
#   <matplotlib.axis.XTick at 0x346ce0410>,
#   <matplotlib.axis.XTick at 0x346d24f90>,
#   <matplotlib.axis.XTick at 0x346d27090>,
#   <matplotlib.axis.XTick at 0x346d2d050>,
#   <matplotlib.axis.XTick at 0x346d2f150>,
#   <matplotlib.axis.XTick at 0x346d2c990>,
#   <matplotlib.axis.XTick at 0x346d31650>,
#   <matplotlib.axis.XTick at 0x346d33810>,
#   <matplotlib.axis.XTick at 0x346d39810>,
#   <matplotlib.axis.XTick at 0x346d3b890>,
#   <matplotlib.axis.XTick at 0x346d41910>,
#   <matplotlib.axis.XTick at 0x346d42110>,
#   <matplotlib.axis.XTick at 0x346d43e10>,
#   <matplotlib.axis.XTick at 0x346d49e50>,
#   <matplotlib.axis.XTick at 0x346d4bed0>,
#   <matplotlib.axis.XTick at 0x346d55e90>,
#   <matplotlib.axis.XTick at 0x346d26950>,
#   <matplotlib.axis.XTick at 0x346d58610>,
#   <matplotlib.axis.XTick at 0x346d5a750>,
#   <matplotlib.axis.XTick at 0x346d60650>,
#   <matplotlib.axis.XTick at 0x346d62750>,
#   <matplotlib.axis.XTick at 0x346d68710>,
#   <matplotlib.axis.XTick at 0x346b95790>,
#   <matplotlib.axis.XTick at 0x346d6a950>,
#   <matplotlib.axis.XTick at 0x346d6c9d0>,
#   <matplotlib.axis.XTick at 0x346d6ea10>,
#   <matplotlib.axis.XTick at 0x346d78ad0>,
#   <matplotlib.axis.XTick at 0x346d69fd0>,
#   <matplotlib.axis.XTick at 0x346d7afd0>,
#   <matplotlib.axis.XTick at 0x346d81010>,
#   <matplotlib.axis.XTick at 0x346d83010>,
#   <matplotlib.axis.XTick at 0x346d85150>,
#   <matplotlib.axis.XTick at 0x346d81a50>,
#   <matplotlib.axis.XTick at 0x346d87710>,
#   <matplotlib.axis.XTick at 0x346d89850>,
#   <matplotlib.axis.XTick at 0x346d8b8d0>,
#   <matplotlib.axis.XTick at 0x346d91890>,
#   <matplotlib.axis.XTick at 0x346d93910>,
#   <matplotlib.axis.XTick at 0x346d68250>,
#   <matplotlib.axis.XTick at 0x346d99d90>,
#   <matplotlib.axis.XTick at 0x346d9bd50>,
#   <matplotlib.axis.XTick at 0x346da9d10>,
#   <matplotlib.axis.XTick at 0x346dabd90>,
#   <matplotlib.axis.XTick at 0x346d84a50>,
#   <matplotlib.axis.XTick at 0x346dae290>,
#   <matplotlib.axis.XTick at 0x346db0190>,
#   <matplotlib.axis.XTick at 0x346db2050>,
#   <matplotlib.axis.XTick at 0x346db80d0>,
#   <matplotlib.axis.XTick at 0x346dba010>,
#   <matplotlib.axis.XTick at 0x346db9a10>,
#   <matplotlib.axis.XTick at 0x346dc02d0>,
#   <matplotlib.axis.XTick at 0x346dc21d0>,
#   <matplotlib.axis.XTick at 0x346dcc2d0>,
#   <matplotlib.axis.XTick at 0x346dce210>,
#   <matplotlib.axis.XTick at 0x346dba950>,
#   <matplotlib.axis.XTick at 0x346dd06d0>,
#   <matplotlib.axis.XTick at 0x346dd27d0>,
#   <matplotlib.axis.XTick at 0x346dd4810>,
#   <matplotlib.axis.XTick at 0x346dd67d0>,
#   <matplotlib.axis.XTick at 0x346dd56d0>,
#   <matplotlib.axis.XTick at 0x346d79610>,
#   <matplotlib.axis.XTick at 0x346dd9690>,
#   <matplotlib.axis.XTick at 0x346ddb690>,
#   <matplotlib.axis.XTick at 0x346de96d0>,
#   <matplotlib.axis.XTick at 0x346deb710>,
#   <matplotlib.axis.XTick at 0x346d8acd0>,
#   <matplotlib.axis.XTick at 0x346df1bd0>,
#   <matplotlib.axis.XTick at 0x346df3d10>,
#   <matplotlib.axis.XTick at 0x346df9b90>,
#   <matplotlib.axis.XTick at 0x346dfbcd0>,
#   <matplotlib.axis.XTick at 0x346df2310>,
#   <matplotlib.axis.XTick at 0x346dfe190>,
#   <matplotlib.axis.XTick at 0x346e04210>,
#   <matplotlib.axis.XTick at 0x346e06350>,
#   <matplotlib.axis.XTick at 0x346e0c290>,
#   <matplotlib.axis.XTick at 0x346e0e390>,
#   <matplotlib.axis.XTick at 0x3469284d0>,
#   <matplotlib.axis.XTick at 0x346dd9f50>,
#   <matplotlib.axis.XTick at 0x346e16650>,
#   <matplotlib.axis.XTick at 0x346e16310>,
#   <matplotlib.axis.XTick at 0x346e22490>,
#   <matplotlib.axis.XTick at 0x346e15ad0>,
#   <matplotlib.axis.XTick at 0x346e17f10>,
#   <matplotlib.axis.XTick at 0x346e26550>,
#   <matplotlib.axis.XTick at 0x346e26250>,
#   <matplotlib.axis.XTick at 0x346e25e10>,
#   <matplotlib.axis.XTick at 0x346e29a10>,
#   <matplotlib.axis.XTick at 0x346e2bcd0>,
#   <matplotlib.axis.XTick at 0x346e26f90>,
#   <matplotlib.axis.XTick at 0x346e322d0>,
#   <matplotlib.axis.XTick at 0x346e33b10>,
#   <matplotlib.axis.XTick at 0x346e39d10>,
#   <matplotlib.axis.XTick at 0x346e3bb50>,
#   <matplotlib.axis.XTick at 0x346e29ad0>,
#   <matplotlib.axis.XTick at 0x346e38a50>,
#   <matplotlib.axis.XTick at 0x346e4bb50>,
#   <matplotlib.axis.XTick at 0x346e53c90>,
#   <matplotlib.axis.XTick at 0x346e515d0>,
#   <matplotlib.axis.XTick at 0x346e50c90>,
#   <matplotlib.axis.XTick at 0x346e52c10>,
#   <matplotlib.axis.XTick at 0x346e56f90>,
#   <matplotlib.axis.XTick at 0x346e5fcd0>,
#   <matplotlib.axis.XTick at 0x346e5ed90>,
#   <matplotlib.axis.XTick at 0x346e63b90>,
#   <matplotlib.axis.XTick at 0x346e62f10>,
#   <matplotlib.axis.XTick at 0x346e5cd90>,
#   <matplotlib.axis.XTick at 0x346e67d90>,
#   <matplotlib.axis.XTick at 0x346e67110>,
#   <matplotlib.axis.XTick at 0x346e73d10>,
#   <matplotlib.axis.XTick at 0x346e72f90>,
#   <matplotlib.axis.XTick at 0x346e60ed0>,
#   <matplotlib.axis.XTick at 0x346e52a90>,
#   <matplotlib.axis.XTick at 0x346e77690>,
#   <matplotlib.axis.XTick at 0x346e7f950>,
#   <matplotlib.axis.XTick at 0x346e7ed10>,
#   <matplotlib.axis.XTick at 0x346df8d10>,
#   <matplotlib.axis.XTick at 0x346e7e550>,
#   <matplotlib.axis.XTick at 0x346e842d0>,
#   <matplotlib.axis.XTick at 0x346e8b5d0>,
#   <matplotlib.axis.XTick at 0x346e88fd0>,
#   <matplotlib.axis.XTick at 0x346e9f390>,
#   <matplotlib.axis.XTick at 0x346e9f050>,
#   <matplotlib.axis.XTick at 0x346e89e90>,
#   <matplotlib.axis.XTick at 0x346ea3410>,
#   <matplotlib.axis.XTick at 0x346ea3090>,
#   <matplotlib.axis.XTick at 0x346eab250>,
#   <matplotlib.axis.XTick at 0x346eaa590>,
#   <matplotlib.axis.XTick at 0x346d86e50>,
#   <matplotlib.axis.XTick at 0x346e9c610>,
#   <matplotlib.axis.XTick at 0x346eb3490>,
#   <matplotlib.axis.XTick at 0x346eb32d0>,
#   <matplotlib.axis.XTick at 0x346eb7450>,
#   <matplotlib.axis.XTick at 0x346eb4a10>,
#   <matplotlib.axis.XTick at 0x346eb6d10>,
#   <matplotlib.axis.XTick at 0x346ebf350>,
#   <matplotlib.axis.XTick at 0x346ebe710>,
#   <matplotlib.axis.XTick at 0x346ecb110>,
#   <matplotlib.axis.XTick at 0x346eca450>,
#   <matplotlib.axis.XTick at 0x346ebdf10>,
#   <matplotlib.axis.XTick at 0x346ebe4d0>,
#   <matplotlib.axis.XTick at 0x346ece610>,
#   <matplotlib.axis.XTick at 0x346ed2d50>,
#   <matplotlib.axis.XTick at 0x346ed21d0>,
#   <matplotlib.axis.XTick at 0x346edabd0>,
#   <matplotlib.axis.XTick at 0x346ed9dd0>,
#   <matplotlib.axis.XTick at 0x346ec8190>,
#   <matplotlib.axis.XTick at 0x346ee6b10>,
#   <matplotlib.axis.XTick at 0x346ee66d0>,
#   <matplotlib.axis.XTick at 0x346ef2950>,
#   <matplotlib.axis.XTick at 0x346ec8350>,
#   <matplotlib.axis.XTick at 0x346ef3050>,
#   <matplotlib.axis.XTick at 0x346ef6b50>,
#   <matplotlib.axis.XTick at 0x346ef6610>,
#   <matplotlib.axis.XTick at 0x346efa950>,
#   <matplotlib.axis.XTick at 0x346efa390>,
#   <matplotlib.axis.XTick at 0x346e85390>,
#   <matplotlib.axis.XTick at 0x346ef7990>,
#   <matplotlib.axis.XTick at 0x346f02910>,
#   <matplotlib.axis.XTick at 0x346f06b90>,
#   <matplotlib.axis.XTick at 0x346f06290>,
#   <matplotlib.axis.XTick at 0x346f12810>,
#   <matplotlib.axis.XTick at 0x346ef9b90>,
#   <matplotlib.axis.XTick at 0x346f03dd0>,
#   <matplotlib.axis.XTick at 0x346f1a610>,
#   <matplotlib.axis.XTick at 0x346f19950>,
#   <matplotlib.axis.XTick at 0x346f1e450>,
#   <matplotlib.axis.XTick at 0x346f191d0>,
#   <matplotlib.axis.XTick at 0x346f1a010>,
#   <matplotlib.axis.XTick at 0x346f2a610>,
#   <matplotlib.axis.XTick at 0x346f298d0>,
#   <matplotlib.axis.XTick at 0x346f2e350>,
#   <matplotlib.axis.XTick at 0x346f2e050>,
#   <matplotlib.axis.XTick at 0x346f2fdd0>,
#   <matplotlib.axis.XTick at 0x346f29750>,
#   <matplotlib.axis.XTick at 0x346f41fd0>,
#   <matplotlib.axis.XTick at 0x346f43f90>,
#   <matplotlib.axis.XTick at 0x346f45d90>,
#   <matplotlib.axis.XTick at 0x346f47210>,
#   <matplotlib.axis.XTick at 0x346f4e650>,
#   <matplotlib.axis.XTick at 0x346f2cc10>,
#   <matplotlib.axis.XTick at 0x346f4f890>,
#   <matplotlib.axis.XTick at 0x346f53fd0>,
#   <matplotlib.axis.XTick at 0x346f53d10>,
#   <matplotlib.axis.XTick at 0x346ecc990>,
#   <matplotlib.axis.XTick at 0x346f51bd0>,
#   <matplotlib.axis.XTick at 0x346f54ed0>,
#   <matplotlib.axis.XTick at 0x346f63d90>,
#   <matplotlib.axis.XTick at 0x346f63450>,
#   <matplotlib.axis.XTick at 0x346f67c90>,
#   <matplotlib.axis.XTick at 0x346f65610>,
#   <matplotlib.axis.XTick at 0x346f63750>,
#   <matplotlib.axis.XTick at 0x346f6be90>,
#   <matplotlib.axis.XTick at 0x346f6ba10>,
#   <matplotlib.axis.XTick at 0x346f73e50>,
#   <matplotlib.axis.XTick at 0x346f734d0>,
#   <matplotlib.axis.XTick at 0x346e56c10>,
#   <matplotlib.axis.XTick at 0x346f697d0>,
#   <matplotlib.axis.XTick at 0x346f74d10>,
#   <matplotlib.axis.XTick at 0x346f77e90>,
#   <matplotlib.axis.XTick at 0x346f84e50>,
#   <matplotlib.axis.XTick at 0x346f85410>,
#   <matplotlib.axis.XTick at 0x346f87910>,
#   <matplotlib.axis.XTick at 0x346f8df90>,
#   <matplotlib.axis.XTick at 0x346f8d590>,
#   <matplotlib.axis.XTick at 0x346f97ed0>,
#   <matplotlib.axis.XTick at 0x346f97a50>,
#   <matplotlib.axis.XTick at 0x346f72b50>,
#   <matplotlib.axis.XTick at 0x346f8cf90>,
#   <matplotlib.axis.XTick at 0x346f9f750>,
#   <matplotlib.axis.XTick at 0x346fabf90>,
#   <matplotlib.axis.XTick at 0x346fabc50>,
#   <matplotlib.axis.XTick at 0x346fafd90>,
#   <matplotlib.axis.XTick at 0x346faf110>,
#   <matplotlib.axis.XTick at 0x346fab690>,
#   <matplotlib.axis.XTick at 0x346fb7d90>,
#   <matplotlib.axis.XTick at 0x346fb5690>,
#   <matplotlib.axis.XTick at 0x346fbbc10>,
#   <matplotlib.axis.XTick at 0x346fb9410>,
#   <matplotlib.axis.XTick at 0x346fbac50>,
#   <matplotlib.axis.XTick at 0x346fbfd10>,
#   <matplotlib.axis.XTick at 0x346fbf8d0>,
#   <matplotlib.axis.XTick at 0x346fcbb90>,
#   <matplotlib.axis.XTick at 0x346fcb610>,
#   <matplotlib.axis.XTick at 0x346fad710>,
#   <matplotlib.axis.XTick at 0x346fbe490>,
#   <matplotlib.axis.XTick at 0x346fd3a10>,
#   <matplotlib.axis.XTick at 0x346fdbc10>,
#   <matplotlib.axis.XTick at 0x346fdaf90>,
#   <matplotlib.axis.XTick at 0x346fdf850>,
#   <matplotlib.axis.XTick at 0x346fdf010>,
#   <matplotlib.axis.XTick at 0x346fc9710>,
#   <matplotlib.axis.XTick at 0x346fe3650>,
#   <matplotlib.axis.XTick at 0x346fe2950>,
#   <matplotlib.axis.XTick at 0x346feb350>,
#   <matplotlib.axis.XTick at 0x346fe8c10>,
#   <matplotlib.axis.XTick at 0x346fead10>,
#   <matplotlib.axis.XTick at 0x346ff7150>,
#   <matplotlib.axis.XTick at 0x346ff6890>,
#   <matplotlib.axis.XTick at 0x346ffaf90>,
#   <matplotlib.axis.XTick at 0x346ffab10>,
#   <matplotlib.axis.XTick at 0x346ff6b10>,
#   <matplotlib.axis.XTick at 0x346ff9b90>,
#   <matplotlib.axis.XTick at 0x347802b50>,
#   <matplotlib.axis.XTick at 0x347812ed0>,
#   <matplotlib.axis.XTick at 0x3478125d0>,
#   <matplotlib.axis.XTick at 0x347816d50>,
#   <matplotlib.axis.XTick at 0x347816590>,
#   <matplotlib.axis.XTick at 0x347803710>,
#   <matplotlib.axis.XTick at 0x34781ecd0>,
#   <matplotlib.axis.XTick at 0x34781e7d0>,
#   <matplotlib.axis.XTick at 0x347814810>,
#   <matplotlib.axis.XTick at 0x347822550>,
#   <matplotlib.axis.XTick at 0x347823d50>,
#   <matplotlib.axis.XTick at 0x347836c50>,
#   <matplotlib.axis.XTick at 0x3478347d0>,
#   <matplotlib.axis.XTick at 0x34783eb10>,
#   <matplotlib.axis.XTick at 0x34783e290>,
#   <matplotlib.axis.XTick at 0x347835850>,
#   <matplotlib.axis.XTick at 0x347837a90>,
#   <matplotlib.axis.XTick at 0x347842350>,
#   <matplotlib.axis.XTick at 0x34784a990>,
#   <matplotlib.axis.XTick at 0x347849d10>,
#   <matplotlib.axis.XTick at 0x3478527d0>,
#   <matplotlib.axis.XTick at 0x347813590>,
#   <matplotlib.axis.XTick at 0x347823950>,
#   <matplotlib.axis.XTick at 0x3478520d0>,
#   <matplotlib.axis.XTick at 0x34785ac10>,
#   <matplotlib.axis.XTick at 0x347859ed0>,
#   <matplotlib.axis.XTick at 0x347859350>,
#   <matplotlib.axis.XTick at 0x34785ba50>,
#   <matplotlib.axis.XTick at 0x347862810>,
#   <matplotlib.axis.XTick at 0x347866a50>,
#   <matplotlib.axis.XTick at 0x347866150>,
#   <matplotlib.axis.XTick at 0x34786a910>,
#   <matplotlib.axis.XTick at 0x346ff9b50>,
#   <matplotlib.axis.XTick at 0x347863990>,
#   <matplotlib.axis.XTick at 0x34781c850>,
#   <matplotlib.axis.XTick at 0x347876790>,
#   <matplotlib.axis.XTick at 0x34787a8d0>,
#   <matplotlib.axis.XTick at 0x34787a510>,
#   <matplotlib.axis.XTick at 0x346fe94d0>,
#   <matplotlib.axis.XTick at 0x34786bb50>,
#   <matplotlib.axis.XTick at 0x3478865d0>,
#   <matplotlib.axis.XTick at 0x347892790>,
#   <matplotlib.axis.XTick at 0x347891a90>,
#   <matplotlib.axis.XTick at 0x347892050>,
#   <matplotlib.axis.XTick at 0x347893690>,
#   <matplotlib.axis.XTick at 0x347896390>,
#   <matplotlib.axis.XTick at 0x34789a650>,
#   <matplotlib.axis.XTick at 0x34789a0d0>,
#   <matplotlib.axis.XTick at 0x3478a6550>,
#   <matplotlib.axis.XTick at 0x347894310>,
#   <matplotlib.axis.XTick at 0x347897d50>,
#   <matplotlib.axis.XTick at 0x3478b2890>,
#   <matplotlib.axis.XTick at 0x3478b01d0>,
#   <matplotlib.axis.XTick at 0x3478b66d0>,
#   <matplotlib.axis.XTick at 0x3478b5a10>,
#   <matplotlib.axis.XTick at 0x3478a5010>,
#   <matplotlib.axis.XTick at 0x3478b7850>,
#   <matplotlib.axis.XTick at 0x3478ba110>,
#   <matplotlib.axis.XTick at 0x3478bb6d0>,
#   <matplotlib.axis.XTick at 0x3478bdb50>,
#   <matplotlib.axis.XTick at 0x3478bcb90>,
#   <matplotlib.axis.XTick at 0x3478bf3d0>,
#   <matplotlib.axis.XTick at 0x3478c4b90>,
#   <matplotlib.axis.XTick at 0x3478c7f90>,
#   <matplotlib.axis.XTick at 0x3478d2090>,
#   <matplotlib.axis.XTick at 0x3478d3d90>,
#   <matplotlib.axis.XTick at 0x3478c6010>,
#   <matplotlib.axis.XTick at 0x3478c7b90>,
#   <matplotlib.axis.XTick at 0x3478de490>,
#   <matplotlib.axis.XTick at 0x3478de290>,
#   <matplotlib.axis.XTick at 0x3478dfed0>,
#   <matplotlib.axis.XTick at 0x3478e1fd0>,
#   <matplotlib.axis.XTick at 0x3478e35d0>,
#   <matplotlib.axis.XTick at 0x3478dff50>,
#   <matplotlib.axis.XTick at 0x3478ea090>,
#   <matplotlib.axis.XTick at 0x3478eb010>,
#   <matplotlib.axis.XTick at 0x3478f1890>,
#   <matplotlib.axis.XTick at 0x34785a7d0>,
#   <matplotlib.axis.XTick at 0x3478f3010>,
#   <matplotlib.axis.XTick at 0x3478fdad0>,
#   <matplotlib.axis.XTick at 0x3478ffd50>,
#   <matplotlib.axis.XTick at 0x347907e90>,
#   <matplotlib.axis.XTick at 0x347907610>,
#   <matplotlib.axis.XTick at 0x3478fddd0>,
#   <matplotlib.axis.XTick at 0x3478fed50>,
#   <matplotlib.axis.XTick at 0x34790b110>,
#   <matplotlib.axis.XTick at 0x34791bf90>,
#   <matplotlib.axis.XTick at 0x34791ba90>,
#   <matplotlib.axis.XTick at 0x34791fe50>,
#   <matplotlib.axis.XTick at 0x34791f1d0>,
#   <matplotlib.axis.XTick at 0x34790bb10>,
#   <matplotlib.axis.XTick at 0x347861c50>,
#   <matplotlib.axis.XTick at 0x347929b50>,
#   <matplotlib.axis.XTick at 0x34792bdd0>,
#   <matplotlib.axis.XTick at 0x34792ab50>,
#   <matplotlib.axis.XTick at 0x34792b050>,
#   <matplotlib.axis.XTick at 0x347933fd0>,
#   <matplotlib.axis.XTick at 0x347935bd0>,
#   <matplotlib.axis.XTick at 0x347937ed0>,
#   <matplotlib.axis.XTick at 0x34793dd10>,
#   <matplotlib.axis.XTick at 0x34793fc10>,
#   <matplotlib.axis.XTick at 0x347937b10>,
#   <matplotlib.axis.XTick at 0x347941ed0>,
#   <matplotlib.axis.XTick at 0x347941c90>,
#   <matplotlib.axis.XTick at 0x34794bf90>,
#   <matplotlib.axis.XTick at 0x34794bc90>,
#   <matplotlib.axis.XTick at 0x34793dc50>,
#   <matplotlib.axis.XTick at 0x347948850>,
#   <matplotlib.axis.XTick at 0x347952c10>,
#   <matplotlib.axis.XTick at 0x347957e10>,
#   <matplotlib.axis.XTick at 0x347957550>,
#   <matplotlib.axis.XTick at 0x347954ad0>,
#   <matplotlib.axis.XTick at 0x347956990>,
#   <matplotlib.axis.XTick at 0x34795d650>,
#   <matplotlib.axis.XTick at 0x34796bbd0>,
#   <matplotlib.axis.XTick at 0x34796b690>,
#   <matplotlib.axis.XTick at 0x34796f990>,
#   <matplotlib.axis.XTick at 0x34796ed90>,
#   <matplotlib.axis.XTick at 0x34796a2d0>,
#   <matplotlib.axis.XTick at 0x34797bb90>,
#   <matplotlib.axis.XTick at 0x34797aed0>,
#   <matplotlib.axis.XTick at 0x347983890>,
#   <matplotlib.axis.XTick at 0x347983390>,
#   <matplotlib.axis.XTick at 0x34796c690>,
#   <matplotlib.axis.XTick at 0x34796ca90>,
#   <matplotlib.axis.XTick at 0x34798af10>,
#   <matplotlib.axis.XTick at 0x3479933d0>,
#   <matplotlib.axis.XTick at 0x347993090>,
#   <matplotlib.axis.XTick at 0x347990d90>,
#   <matplotlib.axis.XTick at 0x347992410>,
#   <matplotlib.axis.XTick at 0x347996f90>,
#   <matplotlib.axis.XTick at 0x34799f110>,
#   <matplotlib.axis.XTick at 0x34799ee90>,
#   <matplotlib.axis.XTick at 0x3479aaf90>,
#   <matplotlib.axis.XTick at 0x347979410>,
#   <matplotlib.axis.XTick at 0x34799c9d0>,
#   <matplotlib.axis.XTick at 0x3479af090>,
#   <matplotlib.axis.XTick at 0x3479ae810>,
#   <matplotlib.axis.XTick at 0x3479b6dd0>,
#   <matplotlib.axis.XTick at 0x3479b6190>,
#   <matplotlib.axis.XTick at 0x34799ccd0>,
#   <matplotlib.axis.XTick at 0x3479b4850>,
#   <matplotlib.axis.XTick at 0x3479be750>,
#   <matplotlib.axis.XTick at 0x3479c2a50>,
#   <matplotlib.axis.XTick at 0x3479c21d0>,
#   <matplotlib.axis.XTick at 0x347943c90>,
#   <matplotlib.axis.XTick at 0x3479c1d10>,
#   <matplotlib.axis.XTick at 0x3479ce710>,
#   <matplotlib.axis.XTick at 0x3479d69d0>,
#   <matplotlib.axis.XTick at 0x3479d64d0>,
#   <matplotlib.axis.XTick at 0x3479de7d0>,
#   <matplotlib.axis.XTick at 0x3479ce350>,
#   <matplotlib.axis.XTick at 0x3479cf290>,
#   <matplotlib.axis.XTick at 0x3479e2a50>,
#   <matplotlib.axis.XTick at 0x3479e2750>,
#   <matplotlib.axis.XTick at 0x3479e6850>,
#   <matplotlib.axis.XTick at 0x3479e6550>,
#   <matplotlib.axis.XTick at 0x3479dee50>,
#   <matplotlib.axis.XTick at 0x3479de050>,
#   <matplotlib.axis.XTick at 0x347933990>,
#   <matplotlib.axis.XTick at 0x3479f2690>,
#   <matplotlib.axis.XTick at 0x3479faa50>,
#   <matplotlib.axis.XTick at 0x3479f8550>,
#   <matplotlib.axis.XTick at 0x3479fbfd0>,
#   <matplotlib.axis.XTick at 0x3479fe9d0>,
#   <matplotlib.axis.XTick at 0x3479fe550>,
#   <matplotlib.axis.XTick at 0x347a06850>,
#   <matplotlib.axis.XTick at 0x347a06450>,
#   <matplotlib.axis.XTick at 0x3479d61d0>,
#   <matplotlib.axis.XTick at 0x3479fdf90>,
#   <matplotlib.axis.XTick at 0x347a12390>,
#   <matplotlib.axis.XTick at 0x347a1e7d0>,
#   <matplotlib.axis.XTick at 0x347a1da10>,
#   <matplotlib.axis.XTick at 0x347a22690>,
#   <matplotlib.axis.XTick at 0x347a07250>,
#   <matplotlib.axis.XTick at 0x347a04290>,
#   <matplotlib.axis.XTick at 0x347a13090>,
#   <matplotlib.axis.XTick at 0x347a2a0d0>,
#   <matplotlib.axis.XTick at 0x347a2e410>,
#   <matplotlib.axis.XTick at 0x347a297d0>,
#   <matplotlib.axis.XTick at 0x347a2bc50>,
#   <matplotlib.axis.XTick at 0x347a3a510>,
#   <matplotlib.axis.XTick at 0x347a39790>,
#   <matplotlib.axis.XTick at 0x347a3ba90>,
#   <matplotlib.axis.XTick at 0x347a3d750>,
#   <matplotlib.axis.XTick at 0x347a3db90>,
#   <matplotlib.axis.XTick at 0x3478ff2d0>,
#   <matplotlib.axis.XTick at 0x347a45b50>,
#   <matplotlib.axis.XTick at 0x347a47a50>,
#   <matplotlib.axis.XTick at 0x347a49950>,
#   <matplotlib.axis.XTick at 0x347a4b5d0>,
#   <matplotlib.axis.XTick at 0x347a3dd50>,
#   <matplotlib.axis.XTick at 0x347a47cd0>,
#   <matplotlib.axis.XTick at 0x347a5b710>,
#   <matplotlib.axis.XTick at 0x347a67c10>,
#   <matplotlib.axis.XTick at 0x347a658d0>,
#   <matplotlib.axis.XTick at 0x347a64b10>,
#   <matplotlib.axis.XTick at 0x347a65810>,
#   <matplotlib.axis.XTick at 0x347a69310>,
#   <matplotlib.axis.XTick at 0x347a73a90>,
#   <matplotlib.axis.XTick at 0x347a72e10>,
#   <matplotlib.axis.XTick at 0x347a77810>,
#   <matplotlib.axis.XTick at 0x347a77250>,
#   <matplotlib.axis.XTick at 0x347a71550>,
#   <matplotlib.axis.XTick at 0x347a7bc90>,
#   <matplotlib.axis.XTick at 0x347a7b6d0>,
#   <matplotlib.axis.XTick at 0x347a87890>,
#   <matplotlib.axis.XTick at 0x347a85310>,
#   <matplotlib.axis.XTick at 0x347a745d0>,
#   <matplotlib.axis.XTick at 0x347a7ae10>,
#   <matplotlib.axis.XTick at 0x347a8b3d0>,
#   <matplotlib.axis.XTick at 0x347a97650>,
#   <matplotlib.axis.XTick at 0x347a97210>,
#   <matplotlib.axis.XTick at 0x347a94290>,
#   <matplotlib.axis.XTick at 0x347a95e50>,
#   <matplotlib.axis.XTick at 0x347a9add0>,
#   <matplotlib.axis.XTick at 0x347aa3650>,
#   <matplotlib.axis.XTick at 0x347aa3150>,
#   <matplotlib.axis.XTick at 0x347aaf490>,
#   <matplotlib.axis.XTick at 0x3479e7e90>,
#   <matplotlib.axis.XTick at 0x347aa0610>,
#   <matplotlib.axis.XTick at 0x347ab3650>,
#   <matplotlib.axis.XTick at 0x347ab29d0>,
#   <matplotlib.axis.XTick at 0x347ab75d0>,
#   <matplotlib.axis.XTick at 0x347ab7410>,
#   <matplotlib.axis.XTick at 0x347aafb90>,
#   <matplotlib.axis.XTick at 0x347ab2210>,
#   <matplotlib.axis.XTick at 0x347abb990>,
#   <matplotlib.axis.XTick at 0x347abb690>,
#   <matplotlib.axis.XTick at 0x347acb7d0>,
#   <matplotlib.axis.XTick at 0x347ac9290>,
#   <matplotlib.axis.XTick at 0x347acb210>,
#   <matplotlib.axis.XTick at 0x347ad36d0>,
#   <matplotlib.axis.XTick at 0x347ad2dd0>,
#   <matplotlib.axis.XTick at 0x347adb590>,
#   <matplotlib.axis.XTick at 0x347ada910>,
#   <matplotlib.axis.XTick at 0x347ad1250>,
#   <matplotlib.axis.XTick at 0x347ad0590>,
#   <matplotlib.axis.XTick at 0x347adf510>,
#   <matplotlib.axis.XTick at 0x347ae7510>,
#   <matplotlib.axis.XTick at 0x347ae6d90>,
#   <matplotlib.axis.XTick at 0x347af3410>,
#   <matplotlib.axis.XTick at 0x347af2f90>,
#   <matplotlib.axis.XTick at 0x347a5bb50>,
#   <matplotlib.axis.XTick at 0x347af7290>,
#   <matplotlib.axis.XTick at 0x347af7090>,
#   <matplotlib.axis.XTick at 0x347afb150>,
#   <matplotlib.axis.XTick at 0x347af8350>,
#   <matplotlib.axis.XTick at 0x347afa850>,
#   <matplotlib.axis.XTick at 0x347b03190>,
#   <matplotlib.axis.XTick at 0x347b02f10>,
#   <matplotlib.axis.XTick at 0x347b0ae90>,
#   <matplotlib.axis.XTick at 0x347b0a310>,
#   <matplotlib.axis.XTick at 0x347b01a50>,
#   <matplotlib.axis.XTick at 0x347b03c10>,
#   <matplotlib.axis.XTick at 0x347b16b50>,
#   <matplotlib.axis.XTick at 0x347b1ef90>,
#   <matplotlib.axis.XTick at 0x347b1ea90>,
#   <matplotlib.axis.XTick at 0x347b22c90>,
#   <matplotlib.axis.XTick at 0x347b224d0>,
#   <matplotlib.axis.XTick at 0x347b0bc90>,
#   <matplotlib.axis.XTick at 0x347b26c10>,
#   <matplotlib.axis.XTick at 0x347b26910>,
#   <matplotlib.axis.XTick at 0x347b2e910>,
#   <matplotlib.axis.XTick at 0x347b2d150>,
#   <matplotlib.axis.XTick at 0x347b2de90>,
#   <matplotlib.axis.XTick at 0x347b46990>,
#   <matplotlib.axis.XTick at 0x347b46050>,
#   <matplotlib.axis.XTick at 0x347b4e710>,
#   <matplotlib.axis.XTick at 0x347b4ddd0>,
#   <matplotlib.axis.XTick at 0x347b46590>,
#   <matplotlib.axis.XTick at 0x347b4c090>,
#   <matplotlib.axis.XTick at 0x347b52610>,
#   <matplotlib.axis.XTick at 0x347b566d0>,
#   <matplotlib.axis.XTick at 0x347b55a10>,
#   <matplotlib.axis.XTick at 0x347b5e5d0>,
#   <matplotlib.axis.XTick at 0x347b4d910>,
#   <matplotlib.axis.XTick at 0x347b53f10>,
#   <matplotlib.axis.XTick at 0x347b6a5d0>,
#   <matplotlib.axis.XTick at 0x347b6a010>,
#   <matplotlib.axis.XTick at 0x347b6e410>,
#   <matplotlib.axis.XTick at 0x347b68c10>,
#   <matplotlib.axis.XTick at 0x347b6bbd0>,
#   <matplotlib.axis.XTick at 0x347b76450>,
#   <matplotlib.axis.XTick at 0x347b75b10>,
#   <matplotlib.axis.XTick at 0x347b77a90>,
#   <matplotlib.axis.XTick at 0x347b79950>,
#   <matplotlib.axis.XTick at 0x347b7b490>,
#   <matplotlib.axis.XTick at 0x347b77250>,
#   <matplotlib.axis.XTick at 0x347b7d790>,
#   <matplotlib.axis.XTick at 0x347b7dcd0>,
#   <matplotlib.axis.XTick at 0x347b8ff90>,
#   <matplotlib.axis.XTick at 0x347b8fad0>,
#   <matplotlib.axis.XTick at 0x347b4f6d0>,
#   <matplotlib.axis.XTick at 0x347b6edd0>,
#   <matplotlib.axis.XTick at 0x347af3ed0>,
#   <matplotlib.axis.XTick at 0x347b93f10>,
#   <matplotlib.axis.XTick at 0x347b9e010>,
#   <matplotlib.axis.XTick at 0x347b9d1d0>,
#   <matplotlib.axis.XTick at 0x347b9f390>,
#   <matplotlib.axis.XTick at 0x347ba1d10>,
#   <matplotlib.axis.XTick at 0x347ba3110>,
#   <matplotlib.axis.XTick at 0x347ba9fd0>,
#   <matplotlib.axis.XTick at 0x347bab990>,
#   <matplotlib.axis.XTick at 0x347ba2e90>,
#   <matplotlib.axis.XTick at 0x347ba99d0>,
#   <matplotlib.axis.XTick at 0x347bb3790>,
#   <matplotlib.axis.XTick at 0x347bbde90>,
#   <matplotlib.axis.XTick at 0x347bbf850>,
#   <matplotlib.axis.XTick at 0x347bc3ed0>,
#   <matplotlib.axis.XTick at 0x347bc19d0>,
#   <matplotlib.axis.XTick at 0x347b8dc50>,
#   <matplotlib.axis.XTick at 0x347bc7d50>,
#   <matplotlib.axis.XTick at 0x347bc7850>,
#   <matplotlib.axis.XTick at 0x347bd3ad0>,
#   <matplotlib.axis.XTick at 0x347bd1390>,
#   <matplotlib.axis.XTick at 0x347bd2a10>,
#   <matplotlib.axis.XTick at 0x347bd79d0>,
#   <matplotlib.axis.XTick at 0x347bd5b90>,
#   <matplotlib.axis.XTick at 0x347be7890>,
#   <matplotlib.axis.XTick at 0x347be7590>,
#   <matplotlib.axis.XTick at 0x347bd6950>,
#   <matplotlib.axis.XTick at 0x347be6090>,
#   <matplotlib.axis.XTick at 0x347beb150>,
#   <matplotlib.axis.XTick at 0x347bef850>,
#   <matplotlib.axis.XTick at 0x347beef90>,
#   <matplotlib.axis.XTick at 0x347bf7650>,
#   <matplotlib.axis.XTick at 0x347bd7450>,
#   <matplotlib.axis.XTick at 0x347be4b90>,
#   <matplotlib.axis.XTick at 0x347bfb6d0>,
#   <matplotlib.axis.XTick at 0x347bfa950>,
#   <matplotlib.axis.XTick at 0x347c036d0>,
#   <matplotlib.axis.XTick at 0x347b8dd10>,
#   <matplotlib.axis.XTick at 0x347c02150>,
#   <matplotlib.axis.XTick at 0x347c0b650>,
#   <matplotlib.axis.XTick at 0x347c0b110>,
#   <matplotlib.axis.XTick at 0x347c0f410>,
#   <matplotlib.axis.XTick at 0x347c0f190>,
#   <matplotlib.axis.XTick at 0x347c0a1d0>,
#   <matplotlib.axis.XTick at 0x347c0ed50>,
#   <matplotlib.axis.XTick at 0x347c1b050>,
#   <matplotlib.axis.XTick at 0x347c27450>,
#   <matplotlib.axis.XTick at 0x347c24d50>,
#   <matplotlib.axis.XTick at 0x347c2b2d0>,
#   <matplotlib.axis.XTick at 0x347c2a110>,
#   <matplotlib.axis.XTick at 0x347c2a790>,
#   <matplotlib.axis.XTick at 0x347c3b410>,
#   <matplotlib.axis.XTick at 0x347c3a6d0>,
#   <matplotlib.axis.XTick at 0x347c3f150>,
#   <matplotlib.axis.XTick at 0x347c0ffd0>,
#   <matplotlib.axis.XTick at 0x347c3ebd0>,
#   <matplotlib.axis.XTick at 0x347c4b2d0>,
#   <matplotlib.axis.XTick at 0x347c4ae50>,
#   <matplotlib.axis.XTick at 0x347c4f050>,
#   <matplotlib.axis.XTick at 0x347c4edd0>,
#   <matplotlib.axis.XTick at 0x347c49e10>,
#   <matplotlib.axis.XTick at 0x347c4b9d0>,
#   <matplotlib.axis.XTick at 0x347c52b90>,
#   <matplotlib.axis.XTick at 0x347c5af10>,
#   <matplotlib.axis.XTick at 0x347c5aa50>,
#   <matplotlib.axis.XTick at 0x347c62dd0>,
#   <matplotlib.axis.XTick at 0x347c19d90>,
#   <matplotlib.axis.XTick at 0x347c53f10>,
#   <matplotlib.axis.XTick at 0x347c62810>,
#   <matplotlib.axis.XTick at 0x347c6b210>,
#   <matplotlib.axis.XTick at 0x347c6a850>,
#   <matplotlib.axis.XTick at 0x347c69d10>,
#   <matplotlib.axis.XTick at 0x347c6bc90>,
#   <matplotlib.axis.XTick at 0x347c6c090>,
#   <matplotlib.axis.XTick at 0x347c73010>,
#   <matplotlib.axis.XTick at 0x347c70990>,
#   <matplotlib.axis.XTick at 0x347c82dd0>,
#   <matplotlib.axis.XTick at 0x347c6aa50>,
#   <matplotlib.axis.XTick at 0x347c6ec10>,
#   <matplotlib.axis.XTick at 0x347c8b0d0>,
#   <matplotlib.axis.XTick at 0x347c8a410>,
#   <matplotlib.axis.XTick at 0x347c92f50>,
#   <matplotlib.axis.XTick at 0x347c92310>,
#   <matplotlib.axis.XTick at 0x347b5c190>,
#   <matplotlib.axis.XTick at 0x347c89e90>,
#   <matplotlib.axis.XTick at 0x347c9a650>,
#   <matplotlib.axis.XTick at 0x347ca2d90>,
#   <matplotlib.axis.XTick at 0x347ca2a50>,
#   <matplotlib.axis.XTick at 0x347ca1d50>,
#   <matplotlib.axis.XTick at 0x347ca1f90>,
#   <matplotlib.axis.XTick at 0x347ca6290>,
#   <matplotlib.axis.XTick at 0x347cb2b50>,
#   <matplotlib.axis.XTick at 0x347cb2850>,
#   <matplotlib.axis.XTick at 0x347cba9d0>,
#   <matplotlib.axis.XTick at 0x347c60490>,
#   <matplotlib.axis.XTick at 0x347ca6610>,
#   <matplotlib.axis.XTick at 0x347cbec10>,
#   ...],
#  [Text(0, 0, 'AUT'),
#   Text(1, 0, 'AUT'),
#   Text(2, 0, 'AUT'),
#   Text(3, 0, 'AUT'),
#   Text(4, 0, 'AUT'),
#   Text(5, 0, 'AUT'),
#   Text(6, 0, 'AUT'),
#   Text(7, 0, 'AUT'),
#   Text(8, 0, 'AUT'),
#   Text(9, 0, 'AUT'),
#   Text(10, 0, 'AUT'),
#   Text(11, 0, 'AUT'),
#   Text(12, 0, 'AUT'),
#   Text(13, 0, 'AUT'),
#   Text(14, 0, 'AUT'),
#   Text(15, 0, 'AUT'),
#   Text(16, 0, 'AUT'),
#   Text(17, 0, 'AUT'),
#   Text(18, 0, 'AUT'),
#   Text(19, 0, 'AUT'),
#   Text(20, 0, 'AUT'),
#   Text(21, 0, 'AUT'),
#   Text(22, 0, 'AUT'),
#   Text(23, 0, 'AUT'),
#   Text(24, 0, 'AUT'),
#   Text(25, 0, 'AUT'),
#   Text(26, 0, 'AUT'),
#   Text(27, 0, 'AUT'),
#   Text(28, 0, 'AUT'),
#   Text(29, 0, 'AUT'),
#   Text(30, 0, 'AUT'),
#   Text(31, 0, 'AUT'),
#   Text(32, 0, 'AUT'),
#   Text(33, 0, 'BEL'),
#   Text(34, 0, 'BEL'),
#   Text(35, 0, 'BEL'),
#   Text(36, 0, 'BEL'),
#   Text(37, 0, 'BEL'),
#   Text(38, 0, 'BEL'),
#   Text(39, 0, 'BRA'),
#   Text(40, 0, 'BRA'),
#   Text(41, 0, 'BRA'),
#   Text(42, 0, 'BRA'),
#   Text(43, 0, 'BRA'),
#   Text(44, 0, 'BRA'),
#   Text(45, 0, 'BRA'),
#   Text(46, 0, 'BRA'),
#   Text(47, 0, 'BRA'),
#   Text(48, 0, 'BRA'),
#   Text(49, 0, 'BRA'),
#   Text(50, 0, 'BRA'),
#   Text(51, 0, 'BRA'),
#   Text(52, 0, 'BRA'),
#   Text(53, 0, 'BRA'),
#   Text(54, 0, 'BRA'),
#   Text(55, 0, 'BRA'),
#   Text(56, 0, 'BRA'),
#   Text(57, 0, 'BRA'),
#   Text(58, 0, 'BRA'),
#   Text(59, 0, 'BRA'),
#   Text(60, 0, 'CAN'),
#   Text(61, 0, 'CAN'),
#   Text(62, 0, 'CAN'),
#   Text(63, 0, 'CAN'),
#   Text(64, 0, 'CAN'),
#   Text(65, 0, 'CAN'),
#   Text(66, 0, 'CAN'),
#   Text(67, 0, 'CAN'),
#   Text(68, 0, 'CAN'),
#   Text(69, 0, 'CAN'),
#   Text(70, 0, 'CAN'),
#   Text(71, 0, 'CAN'),
#   Text(72, 0, 'CAN'),
#   Text(73, 0, 'CAN'),
#   Text(74, 0, 'CAN'),
#   Text(75, 0, 'CAN'),
#   Text(76, 0, 'CAN'),
#   Text(77, 0, 'CAN'),
#   Text(78, 0, 'CAN'),
#   Text(79, 0, 'CAN'),
#   Text(80, 0, 'CAN'),
#   Text(81, 0, 'CAN'),
#   Text(82, 0, 'CAN'),
#   Text(83, 0, 'CAN'),
#   Text(84, 0, 'CAN'),
#   Text(85, 0, 'CAN'),
#   Text(86, 0, 'CAN'),
#   Text(87, 0, 'CAN'),
#   Text(88, 0, 'CAN'),
#   Text(89, 0, 'CAN'),
#   Text(90, 0, 'CAN'),
#   Text(91, 0, 'CAN'),
#   Text(92, 0, 'CAN'),
#   Text(93, 0, 'CAN'),
#   Text(94, 0, 'CAN'),
#   Text(95, 0, 'CAN'),
#   Text(96, 0, 'CHE'),
#   Text(97, 0, 'CHE'),
#   Text(98, 0, 'CHE'),
#   Text(99, 0, 'CHE'),
#   Text(100, 0, 'CHE'),
#   Text(101, 0, 'CHE'),
#   Text(102, 0, 'CHE'),
#   Text(103, 0, 'CHE'),
#   Text(104, 0, 'CHE'),
#   Text(105, 0, 'CHE'),
#   Text(106, 0, 'CHE'),
#   Text(107, 0, 'CHE'),
#   Text(108, 0, 'CHE'),
#   Text(109, 0, 'CHE'),
#   Text(110, 0, 'CHE'),
#   Text(111, 0, 'CHE'),
#   Text(112, 0, 'CHE'),
#   Text(113, 0, 'CHE'),
#   Text(114, 0, 'CHE'),
#   Text(115, 0, 'CHE'),
#   Text(116, 0, 'CHE'),
#   Text(117, 0, 'CHL'),
#   Text(118, 0, 'CHL'),
#   Text(119, 0, 'CHL'),
#   Text(120, 0, 'CHL'),
#   Text(121, 0, 'CHL'),
#   Text(122, 0, 'CHL'),
#   Text(123, 0, 'CHL'),
#   Text(124, 0, 'CHL'),
#   Text(125, 0, 'CHL'),
#   Text(126, 0, 'CHL'),
#   Text(127, 0, 'CHL'),
#   Text(128, 0, 'CHL'),
#   Text(129, 0, 'CHL'),
#   Text(130, 0, 'CHL'),
#   Text(131, 0, 'CHL'),
#   Text(132, 0, 'CHL'),
#   Text(133, 0, 'CHL'),
#   Text(134, 0, 'CHL'),
#   Text(135, 0, 'CHL'),
#   Text(136, 0, 'CHL'),
#   Text(137, 0, 'CHL'),
#   Text(138, 0, 'CHL'),
#   Text(139, 0, 'CHL'),
#   Text(140, 0, 'CHL'),
#   Text(141, 0, 'CHL'),
#   Text(142, 0, 'CHL'),
#   Text(143, 0, 'CHL'),
#   Text(144, 0, 'CHL'),
#   Text(145, 0, 'CHL'),
#   Text(146, 0, 'CHL'),
#   Text(147, 0, 'CHL'),
#   Text(148, 0, 'CHL'),
#   Text(149, 0, 'CHL'),
#   Text(150, 0, 'CHL'),
#   Text(151, 0, 'CHL'),
#   Text(152, 0, 'CHL'),
#   Text(153, 0, 'COL'),
#   Text(154, 0, 'COL'),
#   Text(155, 0, 'COL'),
#   Text(156, 0, 'COL'),
#   Text(157, 0, 'COL'),
#   Text(158, 0, 'COL'),
#   Text(159, 0, 'COL'),
#   Text(160, 0, 'COL'),
#   Text(161, 0, 'COL'),
#   Text(162, 0, 'COL'),
#   Text(163, 0, 'COL'),
#   Text(164, 0, 'COL'),
#   Text(165, 0, 'COL'),
#   Text(166, 0, 'COL'),
#   Text(167, 0, 'COL'),
#   Text(168, 0, 'COL'),
#   Text(169, 0, 'COL'),
#   Text(170, 0, 'COL'),
#   Text(171, 0, 'CRI'),
#   Text(172, 0, 'CRI'),
#   Text(173, 0, 'CRI'),
#   Text(174, 0, 'CRI'),
#   Text(175, 0, 'CRI'),
#   Text(176, 0, 'CZE'),
#   Text(177, 0, 'CZE'),
#   Text(178, 0, 'CZE'),
#   Text(179, 0, 'CZE'),
#   Text(180, 0, 'CZE'),
#   Text(181, 0, 'CZE'),
#   Text(182, 0, 'CZE'),
#   Text(183, 0, 'CZE'),
#   Text(184, 0, 'CZE'),
#   Text(185, 0, 'CZE'),
#   Text(186, 0, 'CZE'),
#   Text(187, 0, 'CZE'),
#   Text(188, 0, 'CZE'),
#   Text(189, 0, 'CZE'),
#   Text(190, 0, 'CZE'),
#   Text(191, 0, 'CZE'),
#   Text(192, 0, 'CZE'),
#   Text(193, 0, 'CZE'),
#   Text(194, 0, 'CZE'),
#   Text(195, 0, 'CZE'),
#   Text(196, 0, 'CZE'),
#   Text(197, 0, 'CZE'),
#   Text(198, 0, 'CZE'),
#   Text(199, 0, 'CZE'),
#   Text(200, 0, 'DEU'),
#   Text(201, 0, 'DEU'),
#   Text(202, 0, 'DEU'),
#   Text(203, 0, 'DEU'),
#   Text(204, 0, 'DEU'),
#   Text(205, 0, 'DEU'),
#   Text(206, 0, 'DEU'),
#   Text(207, 0, 'DEU'),
#   Text(208, 0, 'DEU'),
#   Text(209, 0, 'DEU'),
#   Text(210, 0, 'DEU'),
#   Text(211, 0, 'DEU'),
#   Text(212, 0, 'DEU'),
#   Text(213, 0, 'DEU'),
#   Text(214, 0, 'DEU'),
#   Text(215, 0, 'DEU'),
#   Text(216, 0, 'DEU'),
#   Text(217, 0, 'DEU'),
#   Text(218, 0, 'DNK'),
#   Text(219, 0, 'DNK'),
#   Text(220, 0, 'DNK'),
#   Text(221, 0, 'DNK'),
#   Text(222, 0, 'DNK'),
#   Text(223, 0, 'DNK'),
#   Text(224, 0, 'DNK'),
#   Text(225, 0, 'DNK'),
#   Text(226, 0, 'DNK'),
#   Text(227, 0, 'DNK'),
#   Text(228, 0, 'DNK'),
#   Text(229, 0, 'DNK'),
#   Text(230, 0, 'DNK'),
#   Text(231, 0, 'DNK'),
#   Text(232, 0, 'DNK'),
#   Text(233, 0, 'DNK'),
#   Text(234, 0, 'DNK'),
#   Text(235, 0, 'DNK'),
#   Text(236, 0, 'DNK'),
#   Text(237, 0, 'DNK'),
#   Text(238, 0, 'DNK'),
#   Text(239, 0, 'DNK'),
#   Text(240, 0, 'DNK'),
#   Text(241, 0, 'DNK'),
#   Text(242, 0, 'DNK'),
#   Text(243, 0, 'DNK'),
#   Text(244, 0, 'DNK'),
#   Text(245, 0, 'DNK'),
#   Text(246, 0, 'DNK'),
#   Text(247, 0, 'DNK'),
#   Text(248, 0, 'DNK'),
#   Text(249, 0, 'DNK'),
#   Text(250, 0, 'DNK'),
#   Text(251, 0, 'DNK'),
#   Text(252, 0, 'DNK'),
#   Text(253, 0, 'DNK'),
#   Text(254, 0, 'ESP'),
#   Text(255, 0, 'ESP'),
#   Text(256, 0, 'ESP'),
#   Text(257, 0, 'ESP'),
#   Text(258, 0, 'ESP'),
#   Text(259, 0, 'ESP'),
#   Text(260, 0, 'ESP'),
#   Text(261, 0, 'ESP'),
#   Text(262, 0, 'ESP'),
#   Text(263, 0, 'ESP'),
#   Text(264, 0, 'ESP'),
# ...
#   Text(306, 0, 'FIN'),
#   Text(307, 0, 'FIN'),
#   Text(308, 0, 'FIN'),
#   Text(309, 0, 'FIN'),
#   Text(310, 0, 'FIN'),
#   Text(311, 0, 'FIN'),
#   Text(312, 0, 'FIN'),
#   Text(313, 0, 'FIN'),
#   Text(314, 0, 'FIN'),
#   Text(315, 0, 'FIN'),
#   Text(316, 0, 'FIN'),
#   Text(317, 0, 'FIN'),
#   Text(318, 0, 'FIN'),
#   Text(319, 0, 'FIN'),
#   Text(320, 0, 'FIN'),
#   Text(321, 0, 'FIN'),
#   Text(322, 0, 'FIN'),
#   Text(323, 0, 'FIN'),
#   Text(324, 0, 'FIN'),
#   Text(325, 0, 'FIN'),
#   Text(326, 0, 'FIN'),
#   Text(327, 0, 'FIN'),
#   Text(328, 0, 'FIN'),
#   Text(329, 0, 'FIN'),
#   Text(330, 0, 'FIN'),
#   Text(331, 0, 'FIN'),
#   Text(332, 0, 'FIN'),
#   Text(333, 0, 'FIN'),
#   Text(334, 0, 'FIN'),
#   Text(335, 0, 'FIN'),
#   Text(336, 0, 'FIN'),
#   Text(337, 0, 'FIN'),
#   Text(338, 0, 'FIN'),
#   Text(339, 0, 'FIN'),
#   Text(340, 0, 'GBR'),
#   Text(341, 0, 'GBR'),
#   Text(342, 0, 'GBR'),
#   Text(343, 0, 'GBR'),
#   Text(344, 0, 'GBR'),
#   Text(345, 0, 'GBR'),
#   Text(346, 0, 'GBR'),
#   Text(347, 0, 'GBR'),
#   Text(348, 0, 'GBR'),
#   Text(349, 0, 'GBR'),
#   Text(350, 0, 'GBR'),
#   Text(351, 0, 'GBR'),
#   Text(352, 0, 'GBR'),
#   Text(353, 0, 'GBR'),
#   Text(354, 0, 'GBR'),
#   Text(355, 0, 'GRC'),
#   Text(356, 0, 'GRC'),
#   Text(357, 0, 'GRC'),
#   Text(358, 0, 'GRC'),
#   Text(359, 0, 'GRC'),
#   Text(360, 0, 'GRC'),
#   Text(361, 0, 'GRC'),
#   Text(362, 0, 'GRC'),
#   Text(363, 0, 'GRC'),
#   Text(364, 0, 'GRC'),
#   Text(365, 0, 'GRC'),
#   Text(366, 0, 'GRC'),
#   Text(367, 0, 'GRC'),
#   Text(368, 0, 'GRC'),
#   Text(369, 0, 'GRC'),
#   Text(370, 0, 'GRC'),
#   Text(371, 0, 'GRC'),
#   Text(372, 0, 'GRC'),
#   Text(373, 0, 'GRC'),
#   Text(374, 0, 'GRC'),
#   Text(375, 0, 'GRC'),
#   Text(376, 0, 'HUN'),
#   Text(377, 0, 'HUN'),
#   Text(378, 0, 'HUN'),
#   Text(379, 0, 'HUN'),
#   Text(380, 0, 'HUN'),
#   Text(381, 0, 'HUN'),
#   Text(382, 0, 'HUN'),
#   Text(383, 0, 'HUN'),
#   Text(384, 0, 'HUN'),
#   Text(385, 0, 'HUN'),
#   Text(386, 0, 'HUN'),
#   Text(387, 0, 'HUN'),
#   Text(388, 0, 'HUN'),
#   Text(389, 0, 'HUN'),
#   Text(390, 0, 'HUN'),
#   Text(391, 0, 'HUN'),
#   Text(392, 0, 'HUN'),
#   Text(393, 0, 'HUN'),
#   Text(394, 0, 'HUN'),
#   Text(395, 0, 'HUN'),
#   Text(396, 0, 'HUN'),
#   Text(397, 0, 'HUN'),
#   Text(398, 0, 'HUN'),
#   Text(399, 0, 'HUN'),
#   Text(400, 0, 'HUN'),
#   Text(401, 0, 'HUN'),
#   Text(402, 0, 'HUN'),
#   Text(403, 0, 'HUN'),
#   Text(404, 0, 'HUN'),
#   Text(405, 0, 'HUN'),
#   Text(406, 0, 'HUN'),
#   Text(407, 0, 'HUN'),
#   Text(408, 0, 'HUN'),
#   Text(409, 0, 'HUN'),
#   Text(410, 0, 'HUN'),
#   Text(411, 0, 'HUN'),
#   Text(412, 0, 'IRL'),
#   Text(413, 0, 'IRL'),
#   Text(414, 0, 'IRL'),
#   Text(415, 0, 'IRL'),
#   Text(416, 0, 'IRL'),
#   Text(417, 0, 'IRL'),
#   Text(418, 0, 'IRL'),
#   Text(419, 0, 'IRL'),
#   Text(420, 0, 'IRL'),
#   Text(421, 0, 'IRL'),
#   Text(422, 0, 'IRL'),
#   Text(423, 0, 'IRL'),
#   Text(424, 0, 'IRL'),
#   Text(425, 0, 'IRL'),
#   Text(426, 0, 'IRL'),
#   Text(427, 0, 'IRL'),
#   Text(428, 0, 'IRL'),
#   Text(429, 0, 'IRL'),
#   Text(430, 0, 'ISL'),
#   Text(431, 0, 'ISL'),
#   Text(432, 0, 'ISL'),
#   Text(433, 0, 'ISL'),
#   Text(434, 0, 'ISL'),
#   Text(435, 0, 'ISL'),
#   Text(436, 0, 'ISL'),
#   Text(437, 0, 'ISL'),
#   Text(438, 0, 'ISL'),
#   Text(439, 0, 'ISL'),
#   Text(440, 0, 'ISL'),
#   Text(441, 0, 'ISL'),
#   Text(442, 0, 'ISL'),
#   Text(443, 0, 'ISL'),
#   Text(444, 0, 'ISL'),
#   Text(445, 0, 'ISL'),
#   Text(446, 0, 'ISL'),
#   Text(447, 0, 'ISL'),
#   Text(448, 0, 'ISL'),
#   Text(449, 0, 'ISL'),
#   Text(450, 0, 'ISL'),
#   Text(451, 0, 'ISL'),
#   Text(452, 0, 'ISL'),
#   Text(453, 0, 'ISL'),
#   Text(454, 0, 'ISR'),
#   Text(455, 0, 'ISR'),
#   Text(456, 0, 'ISR'),
#   Text(457, 0, 'ISR'),
#   Text(458, 0, 'ISR'),
#   Text(459, 0, 'ISR'),
#   Text(460, 0, 'ISR'),
#   Text(461, 0, 'ISR'),
#   Text(462, 0, 'ISR'),
#   Text(463, 0, 'ISR'),
#   Text(464, 0, 'ISR'),
#   Text(465, 0, 'ISR'),
#   Text(466, 0, 'ISR'),
#   Text(467, 0, 'ISR'),
#   Text(468, 0, 'ISR'),
#   Text(469, 0, 'ISR'),
#   Text(470, 0, 'ISR'),
#   Text(471, 0, 'ISR'),
#   Text(472, 0, 'ISR'),
#   Text(473, 0, 'ISR'),
#   Text(474, 0, 'ISR'),
#   Text(475, 0, 'ISR'),
#   Text(476, 0, 'ISR'),
#   Text(477, 0, 'ISR'),
#   Text(478, 0, 'ISR'),
#   Text(479, 0, 'ISR'),
#   Text(480, 0, 'ISR'),
#   Text(481, 0, 'ISR'),
#   Text(482, 0, 'ISR'),
#   Text(483, 0, 'ISR'),
#   Text(484, 0, 'ISR'),
#   Text(485, 0, 'ISR'),
#   Text(486, 0, 'ISR'),
#   Text(487, 0, 'ISR'),
#   Text(488, 0, 'ISR'),
#   Text(489, 0, 'ISR'),
#   Text(490, 0, 'ITA'),
#   Text(491, 0, 'ITA'),
#   Text(492, 0, 'ITA'),
#   Text(493, 0, 'ITA'),
#   Text(494, 0, 'ITA'),
#   Text(495, 0, 'ITA'),
#   Text(496, 0, 'ITA'),
#   Text(497, 0, 'ITA'),
#   Text(498, 0, 'ITA'),
#   Text(499, 0, 'ITA'),
#   Text(500, 0, 'KOR'),
#   Text(501, 0, 'KOR'),
#   Text(502, 0, 'KOR'),
#   Text(503, 0, 'KOR'),
#   Text(504, 0, 'KOR'),
#   Text(505, 0, 'KOR'),
#   Text(506, 0, 'KOR'),
#   Text(507, 0, 'KOR'),
#   Text(508, 0, 'KOR'),
#   Text(509, 0, 'KOR'),
#   Text(510, 0, 'KOR'),
#   Text(511, 0, 'KOR'),
#   Text(512, 0, 'KOR'),
#   Text(513, 0, 'KOR'),
#   Text(514, 0, 'KOR'),
#   Text(515, 0, 'KOR'),
#   Text(516, 0, 'KOR'),
#   Text(517, 0, 'KOR'),
#   Text(518, 0, 'LTU'),
#   Text(519, 0, 'LTU'),
#   Text(520, 0, 'LTU'),
#   Text(521, 0, 'LTU'),
#   Text(522, 0, 'LTU'),
#   Text(523, 0, 'LTU'),
#   Text(524, 0, 'LTU'),
#   Text(525, 0, 'LTU'),
#   Text(526, 0, 'LTU'),
#   Text(527, 0, 'LTU'),
#   Text(528, 0, 'LTU'),
#   Text(529, 0, 'LTU'),
#   Text(530, 0, 'LTU'),
#   Text(531, 0, 'LTU'),
#   Text(532, 0, 'LTU'),
#   Text(533, 0, 'LTU'),
#   Text(534, 0, 'LTU'),
#   Text(535, 0, 'LTU'),
#   Text(536, 0, 'LTU'),
#   Text(537, 0, 'LTU'),
#   Text(538, 0, 'LTU'),
#   Text(539, 0, 'LTU'),
#   Text(540, 0, 'LTU'),
#   Text(541, 0, 'LTU'),
#   Text(542, 0, 'LTU'),
#   Text(543, 0, 'LTU'),
#   Text(544, 0, 'LTU'),
#   Text(545, 0, 'LTU'),
#   Text(546, 0, 'LTU'),
#   Text(547, 0, 'LTU'),
#   Text(548, 0, 'LTU'),
#   Text(549, 0, 'LTU'),
#   Text(550, 0, 'LTU'),
#   Text(551, 0, 'LTU'),
#   Text(552, 0, 'LTU'),
#   Text(553, 0, 'LTU'),
#   Text(554, 0, 'LUX'),
#   Text(555, 0, 'LUX'),
#   Text(556, 0, 'LUX'),
#   Text(557, 0, 'LUX'),
#   Text(558, 0, 'LUX'),
#   Text(559, 0, 'LUX'),
#   Text(560, 0, 'LUX'),
#   Text(561, 0, 'LUX'),
#   Text(562, 0, 'LUX'),
#   Text(563, 0, 'LUX'),
#   Text(564, 0, 'LUX'),
#   Text(565, 0, 'LUX'),
#   Text(566, 0, 'LUX'),
#   Text(567, 0, 'LUX'),
#   Text(568, 0, 'LUX'),
#   Text(569, 0, 'LUX'),
#   Text(570, 0, 'LUX'),
#   Text(571, 0, 'LUX'),
#   Text(572, 0, 'LUX'),
#   Text(573, 0, 'LUX'),
#   Text(574, 0, 'LUX'),
#   Text(575, 0, 'LUX'),
#   Text(576, 0, 'LUX'),
#   Text(577, 0, 'LUX'),
#   Text(578, 0, 'LUX'),
#   Text(579, 0, 'LUX'),
#   Text(580, 0, 'LUX'),
#   Text(581, 0, 'LUX'),
#   Text(582, 0, 'LUX'),
#   Text(583, 0, 'LUX'),
#   Text(584, 0, 'LUX'),
#   Text(585, 0, 'LUX'),
#   Text(586, 0, 'LUX'),
#   Text(587, 0, 'LUX'),
#   Text(588, 0, 'LUX'),
#   Text(589, 0, 'LUX'),
#   Text(590, 0, 'LVA'),
#   Text(591, 0, 'LVA'),
#   Text(592, 0, 'LVA'),
#   Text(593, 0, 'LVA'),
#   Text(594, 0, 'LVA'),
#   Text(595, 0, 'LVA'),
#   Text(596, 0, 'LVA'),
#   Text(597, 0, 'LVA'),
#   Text(598, 0, 'LVA'),
#   Text(599, 0, 'LVA'),
#   Text(600, 0, 'LVA'),
#   Text(601, 0, 'LVA'),
#   Text(602, 0, 'LVA'),
#   Text(603, 0, 'LVA'),
#   Text(604, 0, 'LVA'),
#   Text(605, 0, 'LVA'),
#   Text(606, 0, 'LVA'),
#   Text(607, 0, 'LVA'),
#   Text(608, 0, 'LVA'),
#   Text(609, 0, 'LVA'),
#   Text(610, 0, 'LVA'),
#   Text(611, 0, 'LVA'),
#   Text(612, 0, 'LVA'),
#   Text(613, 0, 'LVA'),
#   Text(614, 0, 'LVA'),
#   Text(615, 0, 'LVA'),
#   Text(616, 0, 'LVA'),
#   Text(617, 0, 'LVA'),
#   Text(618, 0, 'LVA'),
#   Text(619, 0, 'LVA'),
#   Text(620, 0, 'LVA'),
#   Text(621, 0, 'LVA'),
#   Text(622, 0, 'LVA'),
#   Text(623, 0, 'MEX'),
#   Text(624, 0, 'MEX'),
#   Text(625, 0, 'MEX'),
#   Text(626, 0, 'MEX'),
#   Text(627, 0, 'MEX'),
#   Text(628, 0, 'MEX'),
#   Text(629, 0, 'MEX'),
#   Text(630, 0, 'MEX'),
#   Text(631, 0, 'MEX'),
#   Text(632, 0, 'MEX'),
#   Text(633, 0, 'MEX'),
#   Text(634, 0, 'MEX'),
#   Text(635, 0, 'MEX'),
#   Text(636, 0, 'MEX'),
#   Text(637, 0, 'MEX'),
#   Text(638, 0, 'MEX'),
#   Text(639, 0, 'MEX'),
#   Text(640, 0, 'MEX'),
#   Text(641, 0, 'MEX'),
#   Text(642, 0, 'MEX'),
#   Text(643, 0, 'MEX'),
#   Text(644, 0, 'NLD'),
#   Text(645, 0, 'NLD'),
#   Text(646, 0, 'NLD'),
#   Text(647, 0, 'NLD'),
#   Text(648, 0, 'NLD'),
#   Text(649, 0, 'NLD'),
#   Text(650, 0, 'NLD'),
#   Text(651, 0, 'NLD'),
#   Text(652, 0, 'NLD'),
#   Text(653, 0, 'NLD'),
#   Text(654, 0, 'NLD'),
#   Text(655, 0, 'NLD'),
#   Text(656, 0, 'NLD'),
#   Text(657, 0, 'NLD'),
#   Text(658, 0, 'NLD'),
#   Text(659, 0, 'NLD'),
#   Text(660, 0, 'NLD'),
#   Text(661, 0, 'NLD'),
#   Text(662, 0, 'NLD'),
#   Text(663, 0, 'NLD'),
#   Text(664, 0, 'NLD'),
#   Text(665, 0, 'NLD'),
#   Text(666, 0, 'NLD'),
#   Text(667, 0, 'NLD'),
#   Text(668, 0, 'NLD'),
#   Text(669, 0, 'NLD'),
#   Text(670, 0, 'NLD'),
#   Text(671, 0, 'NOR'),
#   Text(672, 0, 'NOR'),
#   Text(673, 0, 'NOR'),
#   Text(674, 0, 'NOR'),
#   Text(675, 0, 'NOR'),
#   Text(676, 0, 'NOR'),
#   Text(677, 0, 'NOR'),
#   Text(678, 0, 'NOR'),
#   Text(679, 0, 'NOR'),
#   Text(680, 0, 'NOR'),
#   Text(681, 0, 'NOR'),
#   Text(682, 0, 'NOR'),
#   Text(683, 0, 'NOR'),
#   Text(684, 0, 'NOR'),
#   Text(685, 0, 'NOR'),
#   Text(686, 0, 'NOR'),
#   Text(687, 0, 'NOR'),
#   Text(688, 0, 'NOR'),
#   Text(689, 0, 'NOR'),
#   Text(690, 0, 'NOR'),
#   Text(691, 0, 'NOR'),
#   Text(692, 0, 'NOR'),
#   Text(693, 0, 'NOR'),
#   Text(694, 0, 'NOR'),
#   Text(695, 0, 'NOR'),
#   Text(696, 0, 'NOR'),
#   Text(697, 0, 'NOR'),
#   Text(698, 0, 'NOR'),
#   Text(699, 0, 'NOR'),
#   Text(700, 0, 'NOR'),
#   Text(701, 0, 'NOR'),
#   Text(702, 0, 'NOR'),
#   Text(703, 0, 'NOR'),
#   Text(704, 0, 'NOR'),
#   Text(705, 0, 'NOR'),
#   Text(706, 0, 'NOR'),
#   Text(707, 0, 'NZL'),
#   Text(708, 0, 'NZL'),
#   Text(709, 0, 'NZL'),
#   Text(710, 0, 'NZL'),
#   Text(711, 0, 'NZL'),
#   Text(712, 0, 'NZL'),
#   Text(713, 0, 'NZL'),
#   Text(714, 0, 'NZL'),
#   Text(715, 0, 'NZL'),
#   Text(716, 0, 'NZL'),
#   Text(717, 0, 'NZL'),
#   Text(718, 0, 'NZL'),
#   Text(719, 0, 'NZL'),
#   Text(720, 0, 'NZL'),
#   Text(721, 0, 'NZL'),
#   Text(722, 0, 'NZL'),
#   Text(723, 0, 'NZL'),
#   Text(724, 0, 'NZL'),
#   Text(725, 0, 'NZL'),
#   Text(726, 0, 'NZL'),
#   Text(727, 0, 'NZL'),
#   Text(728, 0, 'NZL'),
#   Text(729, 0, 'NZL'),
#   Text(730, 0, 'NZL'),
#   Text(731, 0, 'NZL'),
#   Text(732, 0, 'NZL'),
#   Text(733, 0, 'NZL'),
#   Text(734, 0, 'NZL'),
#   Text(735, 0, 'NZL'),
#   Text(736, 0, 'NZL'),
#   Text(737, 0, 'NZL'),
#   Text(738, 0, 'NZL'),
#   Text(739, 0, 'NZL'),
#   Text(740, 0, 'NZL'),
#   Text(741, 0, 'NZL'),
#   Text(742, 0, 'NZL'),
#   Text(743, 0, 'OAVG'),
#   Text(744, 0, 'OAVG'),
#   Text(745, 0, 'OAVG'),
#   Text(746, 0, 'OAVG'),
#   Text(747, 0, 'OAVG'),
#   Text(748, 0, 'OAVG'),
#   Text(749, 0, 'OAVG'),
#   Text(750, 0, 'OAVG'),
#   Text(751, 0, 'OAVG'),
#   Text(752, 0, 'OAVG'),
#   Text(753, 0, 'OAVG'),
#   Text(754, 0, 'OAVG'),
#   Text(755, 0, 'OAVG'),
#   Text(756, 0, 'OAVG'),
#   Text(757, 0, 'OAVG'),
#   Text(758, 0, 'OAVG'),
#   Text(759, 0, 'OAVG'),
#   Text(760, 0, 'OAVG'),
#   Text(761, 0, 'OAVG'),
#   Text(762, 0, 'OAVG'),
#   Text(763, 0, 'OAVG'),
#   Text(764, 0, 'OAVG'),
#   Text(765, 0, 'OAVG'),
#   Text(766, 0, 'OAVG'),
#   Text(767, 0, 'OAVG'),
#   Text(768, 0, 'OAVG'),
#   Text(769, 0, 'OAVG'),
#   Text(770, 0, 'POL'),
#   Text(771, 0, 'POL'),
#   Text(772, 0, 'POL'),
#   Text(773, 0, 'POL'),
#   Text(774, 0, 'POL'),
#   Text(775, 0, 'POL'),
#   Text(776, 0, 'POL'),
#   Text(777, 0, 'POL'),
#   Text(778, 0, 'POL'),
#   Text(779, 0, 'POL'),
#   Text(780, 0, 'POL'),
#   Text(781, 0, 'POL'),
#   Text(782, 0, 'POL'),
#   Text(783, 0, 'POL'),
#   Text(784, 0, 'POL'),
#   Text(785, 0, 'POL'),
#   Text(786, 0, 'POL'),
#   Text(787, 0, 'POL'),
#   Text(788, 0, 'POL'),
#   Text(789, 0, 'POL'),
#   Text(790, 0, 'POL'),
#   Text(791, 0, 'POL'),
#   Text(792, 0, 'POL'),
#   Text(793, 0, 'POL'),
#   Text(794, 0, 'POL'),
#   Text(795, 0, 'POL'),
#   Text(796, 0, 'POL'),
#   Text(797, 0, 'POL'),
#   Text(798, 0, 'POL'),
#   Text(799, 0, 'POL'),
#   Text(800, 0, 'POL'),
#   Text(801, 0, 'POL'),
#   Text(802, 0, 'POL'),
#   Text(803, 0, 'POL'),
#   Text(804, 0, 'POL'),
#   Text(805, 0, 'POL'),
#   Text(806, 0, 'PRT'),
#   Text(807, 0, 'PRT'),
#   Text(808, 0, 'PRT'),
#   Text(809, 0, 'PRT'),
#   Text(810, 0, 'PRT'),
#   Text(811, 0, 'PRT'),
#   Text(812, 0, 'PRT'),
#   Text(813, 0, 'PRT'),
#   Text(814, 0, 'PRT'),
#   Text(815, 0, 'PRT'),
#   Text(816, 0, 'PRT'),
#   Text(817, 0, 'PRT'),
#   Text(818, 0, 'PRT'),
#   Text(819, 0, 'PRT'),
#   Text(820, 0, 'PRT'),
#   Text(821, 0, 'PRT'),
#   Text(822, 0, 'PRT'),
#   Text(823, 0, 'PRT'),
#   Text(824, 0, 'PRT'),
#   Text(825, 0, 'PRT'),
#   Text(826, 0, 'PRT'),
#   Text(827, 0, 'PRT'),
#   Text(828, 0, 'PRT'),
#   Text(829, 0, 'PRT'),
#   Text(830, 0, 'PRT'),
#   Text(831, 0, 'PRT'),
#   Text(832, 0, 'PRT'),
#   Text(833, 0, 'PRT'),
#   Text(834, 0, 'PRT'),
#   Text(835, 0, 'PRT'),
#   Text(836, 0, 'PRT'),
#   Text(837, 0, 'PRT'),
#   Text(838, 0, 'PRT'),
#   Text(839, 0, 'PRT'),
#   Text(840, 0, 'SVK'),
#   Text(841, 0, 'SVK'),
#   Text(842, 0, 'SVK'),
#   Text(843, 0, 'SVK'),
#   Text(844, 0, 'SVK'),
#   Text(845, 0, 'SVK'),
#   Text(846, 0, 'SVK'),
#   Text(847, 0, 'SVK'),
#   Text(848, 0, 'SVK'),
#   Text(849, 0, 'SVK'),
#   Text(850, 0, 'SVK'),
#   Text(851, 0, 'SVK'),
#   Text(852, 0, 'SVK'),
#   Text(853, 0, 'SVK'),
#   Text(854, 0, 'SVK'),
#   Text(855, 0, 'SVK'),
#   Text(856, 0, 'SVK'),
#   Text(857, 0, 'SVK'),
#   Text(858, 0, 'SVK'),
#   Text(859, 0, 'SVK'),
#   Text(860, 0, 'SVK'),
#   Text(861, 0, 'SVK'),
#   Text(862, 0, 'SVK'),
#   Text(863, 0, 'SVK'),
#   Text(864, 0, 'SVK'),
#   Text(865, 0, 'SVK'),
#   Text(866, 0, 'SVK'),
#   Text(867, 0, 'SVK'),
#   Text(868, 0, 'SVK'),
#   Text(869, 0, 'SVK'),
#   Text(870, 0, 'SVK'),
#   Text(871, 0, 'SVK'),
#   Text(872, 0, 'SVK'),
#   Text(873, 0, 'SVK'),
#   Text(874, 0, 'SVK'),
#   Text(875, 0, 'SVK'),
#   Text(876, 0, 'SVN'),
#   Text(877, 0, 'SVN'),
#   Text(878, 0, 'SVN'),
#   Text(879, 0, 'SVN'),
#   Text(880, 0, 'SVN'),
#   Text(881, 0, 'SVN'),
#   Text(882, 0, 'SVN'),
#   Text(883, 0, 'SVN'),
#   Text(884, 0, 'SVN'),
#   Text(885, 0, 'SVN'),
#   Text(886, 0, 'SVN'),
#   Text(887, 0, 'SVN'),
#   Text(888, 0, 'SVN'),
#   Text(889, 0, 'SVN'),
#   Text(890, 0, 'SVN'),
#   Text(891, 0, 'SVN'),
#   Text(892, 0, 'SVN'),
#   Text(893, 0, 'SVN'),
#   Text(894, 0, 'SVN'),
#   Text(895, 0, 'SVN'),
#   Text(896, 0, 'SVN'),
#   Text(897, 0, 'SVN'),
#   Text(898, 0, 'SWE'),
#   Text(899, 0, 'SWE'),
#   Text(900, 0, 'SWE'),
#   Text(901, 0, 'SWE'),
#   Text(902, 0, 'SWE'),
#   Text(903, 0, 'SWE'),
#   Text(904, 0, 'SWE'),
#   Text(905, 0, 'SWE'),
#   Text(906, 0, 'SWE'),
#   Text(907, 0, 'SWE'),
#   Text(908, 0, 'SWE'),
#   Text(909, 0, 'SWE'),
#   Text(910, 0, 'SWE'),
#   Text(911, 0, 'SWE'),
#   Text(912, 0, 'SWE'),
#   Text(913, 0, 'SWE'),
#   Text(914, 0, 'SWE'),
#   Text(915, 0, 'SWE'),
#   Text(916, 0, 'SWE'),
#   Text(917, 0, 'SWE'),
#   Text(918, 0, 'SWE'),
#   Text(919, 0, 'SWE'),
#   Text(920, 0, 'SWE'),
#   Text(921, 0, 'SWE'),
#   Text(922, 0, 'SWE'),
#   Text(923, 0, 'SWE'),
#   Text(924, 0, 'SWE'),
#   Text(925, 0, 'SWE'),
#   Text(926, 0, 'SWE'),
#   Text(927, 0, 'SWE'),
#   Text(928, 0, 'SWE'),
#   Text(929, 0, 'SWE'),
#   Text(930, 0, 'SWE'),
#   Text(931, 0, 'SWE'),
#   Text(932, 0, 'SWE'),
#   Text(933, 0, 'SWE'),
#   Text(934, 0, 'TUR'),
#   Text(935, 0, 'TUR'),
#   Text(936, 0, 'TUR'),
#   Text(937, 0, 'TUR'),
#   Text(938, 0, 'TUR'),
#   Text(939, 0, 'TUR'),
#   Text(940, 0, 'TUR'),
#   Text(941, 0, 'TUR'),
#   Text(942, 0, 'TUR'),
#   Text(943, 0, 'TUR'),
#   Text(944, 0, 'TUR'),
#   Text(945, 0, 'TUR'),
#   Text(946, 0, 'TUR'),
#   Text(947, 0, 'TUR'),
#   Text(948, 0, 'TUR'),
#   Text(949, 0, 'TUR'),
#   Text(950, 0, 'TUR'),
#   Text(951, 0, 'TUR'),
#   Text(952, 0, 'TUR'),
#   Text(953, 0, 'TUR'),
#   Text(954, 0, 'TUR'),
#   Text(955, 0, 'TUR'),
#   Text(956, 0, 'TUR'),
#   Text(957, 0, 'TUR'),
#   Text(958, 0, 'TUR'),
#   Text(959, 0, 'TUR'),
#   Text(960, 0, 'TUR'),
#   Text(961, 0, 'TUR'),
#   Text(962, 0, 'TUR'),
#   Text(963, 0, 'TUR'),
#   Text(964, 0, 'TUR'),
#   Text(965, 0, 'TUR'),
#   Text(966, 0, 'TUR'),
#   Text(967, 0, 'TUR'),
#   Text(968, 0, 'USA'),
#   Text(969, 0, 'USA'),
#   Text(970, 0, 'USA'),
#   Text(971, 0, 'USA'),
#   Text(972, 0, 'USA'),
#   Text(973, 0, 'USA'),
#   Text(974, 0, 'USA'),
#   Text(975, 0, 'USA'),
#   Text(976, 0, 'USA'),
#   Text(977, 0, 'USA'),
#   Text(978, 0, 'USA'),
#   Text(979, 0, 'USA'),
#   Text(980, 0, 'USA'),
#   Text(981, 0, 'USA'),
#   Text(982, 0, 'USA'),
#   Text(983, 0, 'USA'),
#   Text(984, 0, 'USA'),
#   Text(985, 0, 'USA'),
#   Text(986, 0, 'USA'),
#   Text(987, 0, 'USA'),
#   Text(988, 0, 'USA'),
#   Text(989, 0, 'USA'),
#   Text(990, 0, 'USA'),
#   Text(991, 0, 'USA'),
#   Text(992, 0, 'USA'),
#   Text(993, 0, 'USA'),
#   Text(994, 0, 'USA'),
#   Text(995, 0, 'USA'),
#   Text(996, 0, 'USA'),
#   Text(997, 0, 'USA'),
#   Text(998, 0, 'USA'),
#   Text(999, 0, 'USA'),
#   ...])

# %%
filtered_Secondary_completion_rates = Secondary_completion_rates[Secondary_completion_rates['SUBJECT'] == 'UPPSRY_WOMEN']
plt.figure(figsize=(10, 6))
plt.bar(filtered_Secondary_completion_rates['LOCATION'], filtered_Secondary_completion_rates['Value'])
plt.title('Graduation Rates of WOMEN by Location')
plt.xlabel('Location')
plt.ylabel('Graduation Rate (%)')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
filtered_Secondary_completion_rates = Secondary_completion_rates[Secondary_completion_rates['SUBJECT'] == 'UPPSRY_MEN']
plt.figure(figsize=(10, 6))
plt.bar(filtered_Secondary_completion_rates['LOCATION'], filtered_Secondary_completion_rates['Value'])
plt.title('Graduation Rates of MEN by Location')
plt.xlabel('Location')
plt.ylabel('Graduation Rate (%)')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
filtered_men = Secondary_completion_rates[Secondary_completion_rates['SUBJECT'] == 'UPPSRY_MEN']
filtered_women = Secondary_completion_rates[Secondary_completion_rates['SUBJECT'] == 'UPPSRY_WOMEN']
plt.figure(figsize=(12, 6))
bar_width = 0.5
locations = np.arange(len(filtered_women['LOCATION']))
plt.bar(locations, filtered_women['Value'], width=bar_width,label='WOMEN')
plt.bar(locations + bar_width, filtered_men['Value'], width=bar_width, label='MEN', color='grey', alpha=0.5)
plt.title('Graduation Rates of MEN and WOMEN by Location')
plt.xlabel('Location')
plt.ylabel('Graduation Rate (%)')
plt.xticks(locations + bar_width / 2, filtered_women['LOCATION'], rotation=45, ha='right')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
