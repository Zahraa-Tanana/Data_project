# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
from datetime import datetime

# %%
# %matplotlib inline

# %%
plt.rcParams["figure.figsize"] = (10, 5)

# %%
saved_style_state = matplotlib.rcParams.copy()

# %%
Secondary_completion_rates = pd.read_csv("Secondary completion rates.csv", skiprows=1)
print("done")
# Out:
# done

# %%
Secondary_completion_rates.head()
# Out:
#   LOCATION INDICATOR SUBJECT MEASURE FREQUENCY  TIME   Value  Flag Codes
# 0      AUT  GRADRATE  UPPSRY      PC         A  2010  84.210         NaN
# 1      AUT  GRADRATE  UPPSRY      PC         A  2011  83.621         NaN
# 2      AUT  GRADRATE  UPPSRY      PC         A  2012  84.955         NaN
# 3      AUT  GRADRATE  UPPSRY      PC         A  2013  83.765         NaN
# 4      AUT  GRADRATE  UPPSRY      PC         A  2014  83.544         NaN

# %%
Secondary_completion_rates.sample(5)
# Out:
#      LOCATION INDICATOR         SUBJECT MEASURE FREQUENCY  TIME   Value  \
# 1245      LUX  GRADRATE  P_SRY_NTRY_MEN      PC         A  2016   1.659
# 285       IRL  GRADRATE      UPPSRY_MEN      PC         A  2011  85.789
# 821       CHL  GRADRATE      UPPSRY_MEN      PC         A  2015  82.958
# 900       ISR  GRADRATE    UPPSRY_WOMEN      PC         A  2013  95.665
# 410       NLD  GRADRATE      UPPSRY_MEN      PC         A  2018  78.270
#
#       Flag Codes
# 1245         NaN
# 285          NaN
# 821          NaN
# 900          NaN
# 410          NaN

# %%
Secondary_completion_rates.columns
# Out:
# Index(['LOCATION', 'INDICATOR', 'SUBJECT', 'MEASURE', 'FREQUENCY', 'TIME',
#        'Value', 'Flag Codes'],
#       dtype='object')

# %%
row_one = Secondary_completion_rates.iloc[1]
row_one
# Out:
# LOCATION           AUT
# INDICATOR     GRADRATE
# SUBJECT         UPPSRY
# MEASURE             PC
# FREQUENCY            A
# TIME              2011
# Value           83.621
# Flag Codes         NaN
# Name: 1, dtype: object

# %%
row_one = ["Value"]

# %%
Secondary_completion_rates.Value
# Out:
# 0       84.210
# 1       83.621
# 2       84.955
# 3       83.765
# 4       83.544
#          ...
# 1757    81.416
# 1758    82.614
# 1759    83.794
# 1760    83.810
# 1761    85.871
# Name: Value, Length: 1762, dtype: float64

# %%
# Secondary_completion_rates["Value"].plot()
# Secondary_completion_rates["Value"].plot(x="TIME", y="Value")
Secondary_completion_rates_sorted = Secondary_completion_rates.sort_values(by='LOCATION')
Secondary_completion_rates.plot(x='LOCATION', y='Value')
plt.xlabel("LOCATION")
plt.ylabel("Value")
plt.show()

# %%
# Secondary_completion_rates.Value.hist()
# Secondary_completion_rates.plot(x="LOCATION", y="Value", kind='hist')
Secondary_completion_rates_sorted = Secondary_completion_rates.sort_values(by='LOCATION')
plt.bar(range(len(Secondary_completion_rates_sorted['LOCATION'])), Secondary_completion_rates_sorted['Value'])
step =40
plt.xticks(range(0, len(Secondary_completion_rates_sorted['LOCATION']), step), 
        Secondary_completion_rates_sorted['LOCATION'][::step], rotation=90)
# plt.hist(Secondary_completion_rates_sorted['Value'])
plt.xlabel("LOCATION")
plt.ylabel("Value")
# Out:
# Text(0, 0.5, 'Value')

# %%
Secondary_completion_rates_sorted = Secondary_completion_rates.sort_values(by='LOCATION')
plt.bar(range(len(Secondary_completion_rates_sorted['LOCATION'])), Secondary_completion_rates_sorted['Value'])
step =40
plt.xticks(range(0, len(Secondary_completion_rates_sorted['LOCATION']), step), 
        Secondary_completion_rates_sorted['LOCATION'][::step], rotation=90)
filtered_data = Secondary_completion_rates[Secondary_completion_rates['Value'] >= 50]
filtered_data_sorted = filtered_data.sort_values(by='LOCATION')
plt.bar(range(len(filtered_data_sorted['LOCATION'])), filtered_data_sorted['Value'])
plt.xlabel("LOCATION")
plt.ylabel("Value")
plt.xticks(range(len(filtered_data_sorted['LOCATION'])), filtered_data_sorted['LOCATION'], rotation=90)
# Out:
# ([<matplotlib.axis.XTick at 0x28d344310>,
#   <matplotlib.axis.XTick at 0x28d314cd0>,
#   <matplotlib.axis.XTick at 0x28d2c0890>,
#   <matplotlib.axis.XTick at 0x28e3a2250>,
#   <matplotlib.axis.XTick at 0x28e3a8450>,
#   <matplotlib.axis.XTick at 0x28e3a9c50>,
#   <matplotlib.axis.XTick at 0x28e3abe50>,
#   <matplotlib.axis.XTick at 0x28e3a6050>,
#   <matplotlib.axis.XTick at 0x28e3b0290>,
#   <matplotlib.axis.XTick at 0x28e3b2650>,
#   <matplotlib.axis.XTick at 0x28d345750>,
#   <matplotlib.axis.XTick at 0x28e3b4e90>,
#   <matplotlib.axis.XTick at 0x28e3b6f10>,
#   <matplotlib.axis.XTick at 0x28e3b9350>,
#   <matplotlib.axis.XTick at 0x28e3bb5d0>,
#   <matplotlib.axis.XTick at 0x28e3c56d0>,
#   <matplotlib.axis.XTick at 0x28e3c4f90>,
#   <matplotlib.axis.XTick at 0x28e3c7d50>,
#   <matplotlib.axis.XTick at 0x28e3d5fd0>,
#   <matplotlib.axis.XTick at 0x28e3d8210>,
#   <matplotlib.axis.XTick at 0x28e3da310>,
#   <matplotlib.axis.XTick at 0x28e3c6750>,
#   <matplotlib.axis.XTick at 0x28e3e0b10>,
#   <matplotlib.axis.XTick at 0x28e3e2e10>,
#   <matplotlib.axis.XTick at 0x28e3ed050>,
#   <matplotlib.axis.XTick at 0x28e3ef250>,
#   <matplotlib.axis.XTick at 0x28e3f1490>,
#   <matplotlib.axis.XTick at 0x28d2c2650>,
#   <matplotlib.axis.XTick at 0x28e3f3050>,
#   <matplotlib.axis.XTick at 0x28e3f5190>,
#   <matplotlib.axis.XTick at 0x28e3f7250>,
#   <matplotlib.axis.XTick at 0x28e401350>,
#   <matplotlib.axis.XTick at 0x28e3f26d0>,
#   <matplotlib.axis.XTick at 0x28e403a90>,
#   <matplotlib.axis.XTick at 0x28e409c90>,
#   <matplotlib.axis.XTick at 0x28e40be90>,
#   <matplotlib.axis.XTick at 0x28e40df90>,
#   <matplotlib.axis.XTick at 0x28e4100d0>,
#   <matplotlib.axis.XTick at 0x28e3f5b90>,
#   <matplotlib.axis.XTick at 0x28e412550>,
#   <matplotlib.axis.XTick at 0x28e4185d0>,
#   <matplotlib.axis.XTick at 0x28e41a850>,
#   <matplotlib.axis.XTick at 0x28e420790>,
#   <matplotlib.axis.XTick at 0x28e413010>,
#   <matplotlib.axis.XTick at 0x28e422e90>,
#   <matplotlib.axis.XTick at 0x28e3a5110>,
#   <matplotlib.axis.XTick at 0x28e40aad0>,
#   <matplotlib.axis.XTick at 0x28eafda90>,
#   <matplotlib.axis.XTick at 0x28eaffc10>,
#   <matplotlib.axis.XTick at 0x28eb05e50>,
#   <matplotlib.axis.XTick at 0x28eb08110>,
#   <matplotlib.axis.XTick at 0x28e400250>,
#   <matplotlib.axis.XTick at 0x28eb0af10>,
#   <matplotlib.axis.XTick at 0x28eb0d090>,
#   <matplotlib.axis.XTick at 0x28eb0f1d0>,
#   <matplotlib.axis.XTick at 0x28eb11450>,
#   <matplotlib.axis.XTick at 0x28eb0bf50>,
#   <matplotlib.axis.XTick at 0x28eb13d90>,
#   <matplotlib.axis.XTick at 0x28eb19e50>,
#   <matplotlib.axis.XTick at 0x28eb24210>,
#   <matplotlib.axis.XTick at 0x28eb262d0>,
#   <matplotlib.axis.XTick at 0x28eb19510>,
#   <matplotlib.axis.XTick at 0x28eb28d50>,
#   <matplotlib.axis.XTick at 0x28eb2ad90>,
#   <matplotlib.axis.XTick at 0x28eb2ced0>,
#   <matplotlib.axis.XTick at 0x28eb2f050>,
#   <matplotlib.axis.XTick at 0x28eb2c590>,
#   <matplotlib.axis.XTick at 0x28eb35a10>,
#   <matplotlib.axis.XTick at 0x28eb37a90>,
#   <matplotlib.axis.XTick at 0x28eb3db50>,
#   <matplotlib.axis.XTick at 0x28eb3fcd0>,
#   <matplotlib.axis.XTick at 0x28eb3d1d0>,
#   <matplotlib.axis.XTick at 0x28eb42710>,
#   <matplotlib.axis.XTick at 0x28eb4c690>,
#   <matplotlib.axis.XTick at 0x28eb4e890>,
#   <matplotlib.axis.XTick at 0x28eb50a50>,
#   <matplotlib.axis.XTick at 0x28eb4d5d0>,
#   <matplotlib.axis.XTick at 0x28eb53450>,
#   <matplotlib.axis.XTick at 0x28eb55590>,
#   <matplotlib.axis.XTick at 0x28eb57550>,
#   <matplotlib.axis.XTick at 0x28eb59650>,
#   <matplotlib.axis.XTick at 0x28eb55fd0>,
#   <matplotlib.axis.XTick at 0x28eb5bf50>,
#   <matplotlib.axis.XTick at 0x28eb62090>,
#   <matplotlib.axis.XTick at 0x28eb6c210>,
#   <matplotlib.axis.XTick at 0x28eb6e190>,
#   <matplotlib.axis.XTick at 0x28eb62810>,
#   <matplotlib.axis.XTick at 0x28eb749d0>,
#   <matplotlib.axis.XTick at 0x28eb76b90>,
#   <matplotlib.axis.XTick at 0x28eb78b90>,
#   <matplotlib.axis.XTick at 0x28eb7ac10>,
#   <matplotlib.axis.XTick at 0x28eb78550>,
#   <matplotlib.axis.XTick at 0x28eb85650>,
#   <matplotlib.axis.XTick at 0x28eb87750>,
#   <matplotlib.axis.XTick at 0x28eb89890>,
#   <matplotlib.axis.XTick at 0x28eb8b9d0>,
#   <matplotlib.axis.XTick at 0x28eb88710>,
#   <matplotlib.axis.XTick at 0x28eb34950>,
#   <matplotlib.axis.XTick at 0x28eb96110>,
#   <matplotlib.axis.XTick at 0x28eb98150>,
#   <matplotlib.axis.XTick at 0x28eb9a210>,
#   <matplotlib.axis.XTick at 0x28eb07a50>,
#   <matplotlib.axis.XTick at 0x28eba0950>,
#   <matplotlib.axis.XTick at 0x28eba29d0>,
#   <matplotlib.axis.XTick at 0x28eba4950>,
#   <matplotlib.axis.XTick at 0x28eba6990>,
#   <matplotlib.axis.XTick at 0x28eba8a10>,
#   <matplotlib.axis.XTick at 0x28eba8210>,
#   <matplotlib.axis.XTick at 0x28ebaae50>,
#   <matplotlib.axis.XTick at 0x28ebb4e90>,
#   <matplotlib.axis.XTick at 0x28ebb6f50>,
#   <matplotlib.axis.XTick at 0x28ebb8fd0>,
#   <matplotlib.axis.XTick at 0x28eba78d0>,
#   <matplotlib.axis.XTick at 0x28ebbb490>,
#   <matplotlib.axis.XTick at 0x28ebbd510>,
#   <matplotlib.axis.XTick at 0x28ebbf450>,
#   <matplotlib.axis.XTick at 0x28ebc9550>,
#   <matplotlib.axis.XTick at 0x28eb78350>,
#   <matplotlib.axis.XTick at 0x28ebcba50>,
#   <matplotlib.axis.XTick at 0x28ebd1a90>,
#   <matplotlib.axis.XTick at 0x28ebd3c90>,
#   <matplotlib.axis.XTick at 0x28ebd9c10>,
#   <matplotlib.axis.XTick at 0x28eb52cd0>,
#   <matplotlib.axis.XTick at 0x28ebe02d0>,
#   <matplotlib.axis.XTick at 0x28ebe2290>,
#   <matplotlib.axis.XTick at 0x28ebe8290>,
#   <matplotlib.axis.XTick at 0x28ebea310>,
#   <matplotlib.axis.XTick at 0x28eb63b50>,
#   <matplotlib.axis.XTick at 0x28ebecc90>,
#   <matplotlib.axis.XTick at 0x28ebeee50>,
#   <matplotlib.axis.XTick at 0x28ebf4dd0>,
#   <matplotlib.axis.XTick at 0x28ebf6ed0>,
#   <matplotlib.axis.XTick at 0x28ebee550>,
#   <matplotlib.axis.XTick at 0x28ebfd650>,
#   <matplotlib.axis.XTick at 0x28ebff7d0>,
#   <matplotlib.axis.XTick at 0x28ec05690>,
#   <matplotlib.axis.XTick at 0x28ec07790>,
#   <matplotlib.axis.XTick at 0x28ebfe510>,
#   <matplotlib.axis.XTick at 0x28ec0e050>,
#   <matplotlib.axis.XTick at 0x28ec10150>,
#   <matplotlib.axis.XTick at 0x28ec12190>,
#   <matplotlib.axis.XTick at 0x28ec18390>,
#   <matplotlib.axis.XTick at 0x28ec0f790>,
#   <matplotlib.axis.XTick at 0x28ec1ac10>,
#   <matplotlib.axis.XTick at 0x28ec28bd0>,
#   <matplotlib.axis.XTick at 0x28ec2ac90>,
#   <matplotlib.axis.XTick at 0x28ec2cd90>,
#   <matplotlib.axis.XTick at 0x28ec29790>,
#   <matplotlib.axis.XTick at 0x28ec2f3d0>,
#   <matplotlib.axis.XTick at 0x28ec35490>,
#   <matplotlib.axis.XTick at 0x28ec37550>,
#   <matplotlib.axis.XTick at 0x28ec394d0>,
#   <matplotlib.axis.XTick at 0x28ec35b90>,
#   <matplotlib.axis.XTick at 0x28ec3bdd0>,
#   <matplotlib.axis.XTick at 0x28ec3ddd0>,
#   <matplotlib.axis.XTick at 0x28ec3fe10>,
#   <matplotlib.axis.XTick at 0x28ec45e90>,
#   <matplotlib.axis.XTick at 0x28ec3d850>,
#   <matplotlib.axis.XTick at 0x28ebda410>,
#   <matplotlib.axis.XTick at 0x28ec4cf90>,
#   <matplotlib.axis.XTick at 0x28ec4f110>,
#   <matplotlib.axis.XTick at 0x28ec55190>,
#   <matplotlib.axis.XTick at 0x28ebda8d0>,
#   <matplotlib.axis.XTick at 0x28ec57850>,
#   <matplotlib.axis.XTick at 0x28ec5d8d0>,
#   <matplotlib.axis.XTick at 0x28ec5fa10>,
#   <matplotlib.axis.XTick at 0x28ec61a10>,
#   <matplotlib.axis.XTick at 0x28ebbc0d0>,
#   <matplotlib.axis.XTick at 0x28ec680d0>,
#   <matplotlib.axis.XTick at 0x28ec6a150>,
#   <matplotlib.axis.XTick at 0x28ec74290>,
#   <matplotlib.axis.XTick at 0x28ec762d0>,
#   <matplotlib.axis.XTick at 0x28ec84390>,
#   <matplotlib.axis.XTick at 0x28ec5e450>,
#   <matplotlib.axis.XTick at 0x28ec86810>,
#   <matplotlib.axis.XTick at 0x28ec8c890>,
#   <matplotlib.axis.XTick at 0x28ec8e890>,
#   <matplotlib.axis.XTick at 0x28ec908d0>,
#   <matplotlib.axis.XTick at 0x28ec77d10>,
#   <matplotlib.axis.XTick at 0x28ec92f50>,
#   <matplotlib.axis.XTick at 0x28ec98f50>,
#   <matplotlib.axis.XTick at 0x28ec9ae50>,
#   <matplotlib.axis.XTick at 0x28ec9ced0>,
#   <matplotlib.axis.XTick at 0x28eb51790>,
#   <matplotlib.axis.XTick at 0x28ec9f590>,
#   <matplotlib.axis.XTick at 0x28eca1590>,
#   <matplotlib.axis.XTick at 0x28eca3510>,
#   <matplotlib.axis.XTick at 0x28eca9510>,
#   <matplotlib.axis.XTick at 0x28ec93e10>,
#   <matplotlib.axis.XTick at 0x28ecabc10>,
#   <matplotlib.axis.XTick at 0x28ecb5b90>,
#   <matplotlib.axis.XTick at 0x28ecb7bd0>,
#   <matplotlib.axis.XTick at 0x28ecbdc10>,
#   <matplotlib.axis.XTick at 0x28ecaa6d0>,
#   <matplotlib.axis.XTick at 0x28ecc0450>,
#   <matplotlib.axis.XTick at 0x28ecc24d0>,
#   <matplotlib.axis.XTick at 0x28ecc84d0>,
#   <matplotlib.axis.XTick at 0x28ecca610>,
#   <matplotlib.axis.XTick at 0x28ecbc350>,
#   <matplotlib.axis.XTick at 0x28eccce90>,
#   <matplotlib.axis.XTick at 0x28eccf010>,
#   <matplotlib.axis.XTick at 0x28ecd4ed0>,
#   <matplotlib.axis.XTick at 0x28ecd6f50>,
#   <matplotlib.axis.XTick at 0x28eccead0>,
#   <matplotlib.axis.XTick at 0x28ece1690>,
#   <matplotlib.axis.XTick at 0x28ece3750>,
#   <matplotlib.axis.XTick at 0x28ece5790>,
#   <matplotlib.axis.XTick at 0x28ece77d0>,
#   <matplotlib.axis.XTick at 0x28ec99d90>,
#   <matplotlib.axis.XTick at 0x28ecf2050>,
#   <matplotlib.axis.XTick at 0x28ecf81d0>,
#   <matplotlib.axis.XTick at 0x28ecfa110>,
#   <matplotlib.axis.XTick at 0x28ecfc250>,
#   <matplotlib.axis.XTick at 0x28ecf9a10>,
#   <matplotlib.axis.XTick at 0x28ecfe850>,
#   <matplotlib.axis.XTick at 0x28ed10750>,
#   <matplotlib.axis.XTick at 0x28ed128d0>,
#   <matplotlib.axis.XTick at 0x28ed148d0>,
#   <matplotlib.axis.XTick at 0x28ed11310>,
#   <matplotlib.axis.XTick at 0x28eca9cd0>,
#   <matplotlib.axis.XTick at 0x28ed17810>,
#   <matplotlib.axis.XTick at 0x28ed1d810>,
#   <matplotlib.axis.XTick at 0x28ed1f7d0>,
#   <matplotlib.axis.XTick at 0x28ece62d0>,
#   <matplotlib.axis.XTick at 0x28ed21e10>,
#   <matplotlib.axis.XTick at 0x28ed23f90>,
#   <matplotlib.axis.XTick at 0x28ed29f10>,
#   <matplotlib.axis.XTick at 0x28ed2be50>,
#   <matplotlib.axis.XTick at 0x28e3a16d0>,
#   <matplotlib.axis.XTick at 0x28ed323d0>,
#   <matplotlib.axis.XTick at 0x28ed3c450>,
#   <matplotlib.axis.XTick at 0x28ed3e610>,
#   <matplotlib.axis.XTick at 0x28ed40550>,
#   <matplotlib.axis.XTick at 0x28ed42690>,
#   <matplotlib.axis.XTick at 0x28ed410d0>,
#   <matplotlib.axis.XTick at 0x28ed44b50>,
#   <matplotlib.axis.XTick at 0x28ed46b50>,
#   <matplotlib.axis.XTick at 0x28ed48bd0>,
#   <matplotlib.axis.XTick at 0x28ed4ac10>,
#   <matplotlib.axis.XTick at 0x28ed49cd0>,
#   <matplotlib.axis.XTick at 0x28ed511d0>,
#   <matplotlib.axis.XTick at 0x28ed532d0>,
#   <matplotlib.axis.XTick at 0x28ed5d410>,
#   <matplotlib.axis.XTick at 0x28ed5f410>,
#   <matplotlib.axis.XTick at 0x28ed3d5d0>,
#   <matplotlib.axis.XTick at 0x28ed65b10>,
#   <matplotlib.axis.XTick at 0x28ed67ad0>,
#   <matplotlib.axis.XTick at 0x28ed71bd0>,
#   <matplotlib.axis.XTick at 0x28ed73d10>,
#   <matplotlib.axis.XTick at 0x28ed65410>,
#   <matplotlib.axis.XTick at 0x28ed7a310>,
#   <matplotlib.axis.XTick at 0x28ed803d0>,
#   <matplotlib.axis.XTick at 0x28ed82510>,
#   <matplotlib.axis.XTick at 0x28ed88610>,
#   <matplotlib.axis.XTick at 0x28ed7ba50>,
#   <matplotlib.axis.XTick at 0x28ed8ae10>,
#   <matplotlib.axis.XTick at 0x28ed90f10>,
#   <matplotlib.axis.XTick at 0x28ed92f90>,
#   <matplotlib.axis.XTick at 0x28ed99010>,
#   <matplotlib.axis.XTick at 0x28ed89d50>,
#   <matplotlib.axis.XTick at 0x28ed9b810>,
#   <matplotlib.axis.XTick at 0x28ed9d810>,
#   <matplotlib.axis.XTick at 0x28ed9f850>,
#   <matplotlib.axis.XTick at 0x28eda1890>,
#   <matplotlib.axis.XTick at 0x28ed9bf50>,
#   <matplotlib.axis.XTick at 0x28eda8110>,
#   <matplotlib.axis.XTick at 0x28edaa190>,
#   <matplotlib.axis.XTick at 0x28edac310>,
#   <matplotlib.axis.XTick at 0x28edae210>,
#   <matplotlib.axis.XTick at 0x28eda9610>,
#   <matplotlib.axis.XTick at 0x28edb4910>,
#   <matplotlib.axis.XTick at 0x28edb69d0>,
#   <matplotlib.axis.XTick at 0x28edc0a50>,
#   <matplotlib.axis.XTick at 0x28edc2950>,
#   <matplotlib.axis.XTick at 0x28edc8a90>,
#   <matplotlib.axis.XTick at 0x28eda2850>,
#   <matplotlib.axis.XTick at 0x28edcb050>,
#   <matplotlib.axis.XTick at 0x28edd1110>,
#   <matplotlib.axis.XTick at 0x28edd30d0>,
#   <matplotlib.axis.XTick at 0x28edd9210>,
#   <matplotlib.axis.XTick at 0x28edc3450>,
#   <matplotlib.axis.XTick at 0x28ed30dd0>,
#   <matplotlib.axis.XTick at 0x28ede0410>,
#   <matplotlib.axis.XTick at 0x28ede2490>,
#   <matplotlib.axis.XTick at 0x28ede43d0>,
#   <matplotlib.axis.XTick at 0x28ede6390>,
#   <matplotlib.axis.XTick at 0x28edd2090>,
#   <matplotlib.axis.XTick at 0x28edf0650>,
#   <matplotlib.axis.XTick at 0x28edf2750>,
#   <matplotlib.axis.XTick at 0x28edf4890>,
#   <matplotlib.axis.XTick at 0x28edf6890>,
#   <matplotlib.axis.XTick at 0x28edf2f10>,
#   <matplotlib.axis.XTick at 0x28edf8f10>,
#   <matplotlib.axis.XTick at 0x28edfb150>,
#   <matplotlib.axis.XTick at 0x28edfd250>,
#   <matplotlib.axis.XTick at 0x28edff210>,
#   <matplotlib.axis.XTick at 0x28ee09210>,
#   <matplotlib.axis.XTick at 0x28edf5e50>,
#   <matplotlib.axis.XTick at 0x28ee0b550>,
#   <matplotlib.axis.XTick at 0x28ee11550>,
#   <matplotlib.axis.XTick at 0x28ee13650>,
#   <matplotlib.axis.XTick at 0x28ee1d650>,
#   <matplotlib.axis.XTick at 0x28ee09fd0>,
#   <matplotlib.axis.XTick at 0x28ee1fb90>,
#   <matplotlib.axis.XTick at 0x28ee25c90>,
#   <matplotlib.axis.XTick at 0x28ee27d10>,
#   <matplotlib.axis.XTick at 0x28ee29e50>,
#   <matplotlib.axis.XTick at 0x28edb6490>,
#   <matplotlib.axis.XTick at 0x28ee2c390>,
#   <matplotlib.axis.XTick at 0x28ee2e450>,
#   <matplotlib.axis.XTick at 0x28ee34510>,
#   <matplotlib.axis.XTick at 0x28ee36510>,
#   <matplotlib.axis.XTick at 0x28ee40610>,
#   <matplotlib.axis.XTick at 0x28ee2cb50>,
#   <matplotlib.axis.XTick at 0x28ee42a90>,
#   <matplotlib.axis.XTick at 0x28ee48b10>,
#   <matplotlib.axis.XTick at 0x28ee4ac10>,
#   <matplotlib.axis.XTick at 0x28ee4cb50>,
#   <matplotlib.axis.XTick at 0x28ee495d0>,
#   <matplotlib.axis.XTick at 0x28ee4f010>,
#   <matplotlib.axis.XTick at 0x28ee54fd0>,
#   <matplotlib.axis.XTick at 0x28ee57050>,
#   <matplotlib.axis.XTick at 0x28ee5cf50>,
#   <matplotlib.axis.XTick at 0x28ee5f010>,
#   <matplotlib.axis.XTick at 0x28ee5e950>,
#   <matplotlib.axis.XTick at 0x28ee69450>,
#   <matplotlib.axis.XTick at 0x28ee6b490>,
#   <matplotlib.axis.XTick at 0x28ee6d550>,
#   <matplotlib.axis.XTick at 0x28ee6f4d0>,
#   <matplotlib.axis.XTick at 0x28ee6a250>,
#   <matplotlib.axis.XTick at 0x28ee75a50>,
#   <matplotlib.axis.XTick at 0x28ee77990>,
#   <matplotlib.axis.XTick at 0x28ee7dad0>,
#   <matplotlib.axis.XTick at 0x28ee7fa50>,
#   <matplotlib.axis.XTick at 0x28ee81ad0>,
#   <matplotlib.axis.XTick at 0x28ee814d0>,
#   <matplotlib.axis.XTick at 0x28ee83dd0>,
#   <matplotlib.axis.XTick at 0x28ee8de10>,
#   <matplotlib.axis.XTick at 0x28ee8fed0>,
#   <matplotlib.axis.XTick at 0x28ee95ed0>,
#   <matplotlib.axis.XTick at 0x28ee41750>,
#   <matplotlib.axis.XTick at 0x28ee98590>,
#   <matplotlib.axis.XTick at 0x28ee9a310>,
#   <matplotlib.axis.XTick at 0x28eea0410>,
#   <matplotlib.axis.XTick at 0x28eea2590>,
#   <matplotlib.axis.XTick at 0x28eea1290>,
#   <matplotlib.axis.XTick at 0x28ee4e150>,
#   <matplotlib.axis.XTick at 0x28eea5650>,
#   <matplotlib.axis.XTick at 0x28eea7650>,
#   <matplotlib.axis.XTick at 0x28eeb16d0>,
#   <matplotlib.axis.XTick at 0x28eeb3790>,
#   <matplotlib.axis.XTick at 0x28ee1e190>,
#   <matplotlib.axis.XTick at 0x28eeb9d50>,
#   <matplotlib.axis.XTick at 0x28eebbe50>,
#   <matplotlib.axis.XTick at 0x28eebddd0>,
#   <matplotlib.axis.XTick at 0x28eebfe50>,
#   <matplotlib.axis.XTick at 0x28eeba510>,
#   <matplotlib.axis.XTick at 0x28eec63d0>,
#   <matplotlib.axis.XTick at 0x28eecc410>,
#   <matplotlib.axis.XTick at 0x28eece410>,
#   <matplotlib.axis.XTick at 0x28eed8390>,
#   <matplotlib.axis.XTick at 0x28eeda510>,
#   <matplotlib.axis.XTick at 0x28eeda050>,
#   <matplotlib.axis.XTick at 0x28eee09d0>,
#   <matplotlib.axis.XTick at 0x28eee2a90>,
#   <matplotlib.axis.XTick at 0x28eee4990>,
#   <matplotlib.axis.XTick at 0x28eee6910>,
#   <matplotlib.axis.XTick at 0x28eedb850>,
#   <matplotlib.axis.XTick at 0x28eee8fd0>,
#   <matplotlib.axis.XTick at 0x28eeeb0d0>,
#   <matplotlib.axis.XTick at 0x28eeed210>,
#   <matplotlib.axis.XTick at 0x28eeef290>,
#   <matplotlib.axis.XTick at 0x28eef9350>,
#   <matplotlib.axis.XTick at 0x28eef8b50>,
#   <matplotlib.axis.XTick at 0x28eefb5d0>,
#   <matplotlib.axis.XTick at 0x28ef05610>,
#   <matplotlib.axis.XTick at 0x28ef076d0>,
#   <matplotlib.axis.XTick at 0x28ef0d750>,
#   <matplotlib.axis.XTick at 0x28eef9d90>,
#   <matplotlib.axis.XTick at 0x28ef0fbd0>,
#   <matplotlib.axis.XTick at 0x28ef15bd0>,
#   <matplotlib.axis.XTick at 0x28ef17d10>,
#   <matplotlib.axis.XTick at 0x28ef19d10>,
#   <matplotlib.axis.XTick at 0x28ef16ad0>,
#   <matplotlib.axis.XTick at 0x28ef24210>,
#   <matplotlib.axis.XTick at 0x28ef26190>,
#   <matplotlib.axis.XTick at 0x28ef281d0>,
#   <matplotlib.axis.XTick at 0x28ef2a290>,
#   <matplotlib.axis.XTick at 0x28ef341d0>,
#   <matplotlib.axis.XTick at 0x28eefa6d0>,
#   <matplotlib.axis.XTick at 0x28ef36790>,
#   <matplotlib.axis.XTick at 0x28ef38810>,
#   <matplotlib.axis.XTick at 0x28ef3a910>,
#   <matplotlib.axis.XTick at 0x28ef408d0>,
#   <matplotlib.axis.XTick at 0x28ef37250>,
#   <matplotlib.axis.XTick at 0x28ef42e90>,
#   <matplotlib.axis.XTick at 0x28ef4ced0>,
#   <matplotlib.axis.XTick at 0x28ef4efd0>,
#   <matplotlib.axis.XTick at 0x28ef50f50>,
#   <matplotlib.axis.XTick at 0x28ef52fd0>,
#   <matplotlib.axis.XTick at 0x28ef51a50>,
#   <matplotlib.axis.XTick at 0x28ef59250>,
#   <matplotlib.axis.XTick at 0x28ef5b350>,
#   <matplotlib.axis.XTick at 0x28ef653d0>,
#   <matplotlib.axis.XTick at 0x28ef67410>,
#   <matplotlib.axis.XTick at 0x28ef58b50>,
#   <matplotlib.axis.XTick at 0x28ef69a10>,
#   <matplotlib.axis.XTick at 0x28ef6bc50>,
#   <matplotlib.axis.XTick at 0x28ef71d10>,
#   <matplotlib.axis.XTick at 0x28ef73dd0>,
#   <matplotlib.axis.XTick at 0x28ef71690>,
#   <matplotlib.axis.XTick at 0x28ef0e610>,
#   <matplotlib.axis.XTick at 0x28ef76b10>,
#   <matplotlib.axis.XTick at 0x28ef7cc50>,
#   <matplotlib.axis.XTick at 0x28ef7ec50>,
#   <matplotlib.axis.XTick at 0x28ef84d50>,
#   <matplotlib.axis.XTick at 0x28ef41910>,
#   <matplotlib.axis.XTick at 0x28ef87190>,
#   <matplotlib.axis.XTick at 0x28ef8d190>,
#   <matplotlib.axis.XTick at 0x28ef8f210>,
#   <matplotlib.axis.XTick at 0x28ef95310>,
#   <matplotlib.axis.XTick at 0x28ef8dd10>,
#   <matplotlib.axis.XTick at 0x28ef97790>,
#   <matplotlib.axis.XTick at 0x28ef9d7d0>,
#   <matplotlib.axis.XTick at 0x28ef9f750>,
#   <matplotlib.axis.XTick at 0x28efa17d0>,
#   <matplotlib.axis.XTick at 0x28efa3850>,
#   <matplotlib.axis.XTick at 0x28ef772d0>,
#   <matplotlib.axis.XTick at 0x28efa9d90>,
#   <matplotlib.axis.XTick at 0x28efabe10>,
#   <matplotlib.axis.XTick at 0x28efb5e50>,
#   <matplotlib.axis.XTick at 0x28efb7fd0>,
#   <matplotlib.axis.XTick at 0x28efab790>,
#   <matplotlib.axis.XTick at 0x28efc2850>,
#   <matplotlib.axis.XTick at 0x28efc4850>,
#   <matplotlib.axis.XTick at 0x28efc6850>,
#   <matplotlib.axis.XTick at 0x28efc88d0>,
#   <matplotlib.axis.XTick at 0x28efca910>,
#   <matplotlib.axis.XTick at 0x28efc9790>,
#   <matplotlib.axis.XTick at 0x28efccc50>,
#   <matplotlib.axis.XTick at 0x28efcec50>,
#   <matplotlib.axis.XTick at 0x28efd4d10>,
#   <matplotlib.axis.XTick at 0x28eaf3a50>,
#   <matplotlib.axis.XTick at 0x28efd5a10>,
#   <matplotlib.axis.XTick at 0x28efcf390>,
#   <matplotlib.axis.XTick at 0x28efe2f90>,
#   <matplotlib.axis.XTick at 0x28efe25d0>,
#   <matplotlib.axis.XTick at 0x28efe6d90>,
#   <matplotlib.axis.XTick at 0x28efe6490>,
#   <matplotlib.axis.XTick at 0x28ef40390>,
#   <matplotlib.axis.XTick at 0x28efe3610>,
#   <matplotlib.axis.XTick at 0x28efeda10>,
#   <matplotlib.axis.XTick at 0x28eff2a10>,
#   <matplotlib.axis.XTick at 0x28eff2510>,
#   <matplotlib.axis.XTick at 0x28eff2310>,
#   <matplotlib.axis.XTick at 0x28efa02d0>,
#   <matplotlib.axis.XTick at 0x28eff67d0>,
#   <matplotlib.axis.XTick at 0x28f80a8d0>,
#   <matplotlib.axis.XTick at 0x28f80a5d0>,
#   <matplotlib.axis.XTick at 0x28f80b110>,
#   <matplotlib.axis.XTick at 0x28eff5410>,
#   <matplotlib.axis.XTick at 0x28eff7590>,
#   <matplotlib.axis.XTick at 0x28f8127d0>,
#   <matplotlib.axis.XTick at 0x28f811e10>,
#   <matplotlib.axis.XTick at 0x28f816650>,
#   <matplotlib.axis.XTick at 0x28f816310>,
#   <matplotlib.axis.XTick at 0x28f80ff90>,
#   <matplotlib.axis.XTick at 0x28f813010>,
#   <matplotlib.axis.XTick at 0x28f822350>,
#   <matplotlib.axis.XTick at 0x28f823f10>,
#   <matplotlib.axis.XTick at 0x28f829790>,
#   <matplotlib.axis.XTick at 0x28f828e50>,
#   <matplotlib.axis.XTick at 0x28f829f90>,
#   <matplotlib.axis.XTick at 0x28f836110>,
#   <matplotlib.axis.XTick at 0x28f837650>,
#   <matplotlib.axis.XTick at 0x28f83bfd0>,
#   <matplotlib.axis.XTick at 0x28f83bd90>,
#   <matplotlib.axis.XTick at 0x28f836ad0>,
#   <matplotlib.axis.XTick at 0x28f834e50>,
#   <matplotlib.axis.XTick at 0x28efc0b50>,
#   <matplotlib.axis.XTick at 0x28f84a610>,
#   <matplotlib.axis.XTick at 0x28f8498d0>,
#   <matplotlib.axis.XTick at 0x28f84b7d0>,
#   <matplotlib.axis.XTick at 0x28f839a50>,
#   <matplotlib.axis.XTick at 0x28f823bd0>,
#   <matplotlib.axis.XTick at 0x28f857f90>,
#   <matplotlib.axis.XTick at 0x28f861f10>,
#   <matplotlib.axis.XTick at 0x28f8634d0>,
#   <matplotlib.axis.XTick at 0x28f862910>,
#   <matplotlib.axis.XTick at 0x28f863710>,
#   <matplotlib.axis.XTick at 0x28f865190>,
#   <matplotlib.axis.XTick at 0x28f869e50>,
#   <matplotlib.axis.XTick at 0x28f86b950>,
#   <matplotlib.axis.XTick at 0x28f871f50>,
#   <matplotlib.axis.XTick at 0x28f873450>,
#   <matplotlib.axis.XTick at 0x28f86bc50>,
#   <matplotlib.axis.XTick at 0x28f875ad0>,
#   <matplotlib.axis.XTick at 0x28f877a50>,
#   <matplotlib.axis.XTick at 0x28f87ce10>,
#   <matplotlib.axis.XTick at 0x28f87db90>,
#   <matplotlib.axis.XTick at 0x28f870b90>,
#   <matplotlib.axis.XTick at 0x28f877c90>,
#   <matplotlib.axis.XTick at 0x28f887fd0>,
#   <matplotlib.axis.XTick at 0x28f88bd50>,
#   <matplotlib.axis.XTick at 0x28f889a10>,
#   <matplotlib.axis.XTick at 0x28f888890>,
#   <matplotlib.axis.XTick at 0x28f88ac10>,
#   <matplotlib.axis.XTick at 0x28f895710>,
#   <matplotlib.axis.XTick at 0x28f8a7e50>,
#   <matplotlib.axis.XTick at 0x28f8a7110>,
#   <matplotlib.axis.XTick at 0x28f8afcd0>,
#   <matplotlib.axis.XTick at 0x28f8af390>,
#   <matplotlib.axis.XTick at 0x28f8a4510>,
#   <matplotlib.axis.XTick at 0x28f8b1e90>,
#   <matplotlib.axis.XTick at 0x28f8b3dd0>,
#   <matplotlib.axis.XTick at 0x28f8bbd50>,
#   <matplotlib.axis.XTick at 0x28f8b9150>,
#   <matplotlib.axis.XTick at 0x28f8aedd0>,
#   <matplotlib.axis.XTick at 0x28f8b0fd0>,
#   <matplotlib.axis.XTick at 0x28f8c2fd0>,
#   <matplotlib.axis.XTick at 0x28f8c7a50>,
#   <matplotlib.axis.XTick at 0x28f8c75d0>,
#   <matplotlib.axis.XTick at 0x28f80a490>,
#   <matplotlib.axis.XTick at 0x28f8c5610>,
#   <matplotlib.axis.XTick at 0x28f8cb910>,
#   <matplotlib.axis.XTick at 0x28f8d3a90>,
#   <matplotlib.axis.XTick at 0x28f8d2dd0>,
#   <matplotlib.axis.XTick at 0x28f8db7d0>,
#   <matplotlib.axis.XTick at 0x28f8db550>,
#   <matplotlib.axis.XTick at 0x28f8d2610>,
#   <matplotlib.axis.XTick at 0x28f8e3990>,
#   <matplotlib.axis.XTick at 0x28f8e34d0>,
#   <matplotlib.axis.XTick at 0x28f8e7810>,
#   <matplotlib.axis.XTick at 0x28f8e5a10>,
#   <matplotlib.axis.XTick at 0x28f8db210>,
#   <matplotlib.axis.XTick at 0x28f8e4490>,
#   <matplotlib.axis.XTick at 0x28f8eeb50>,
#   <matplotlib.axis.XTick at 0x28f8fb650>,
#   <matplotlib.axis.XTick at 0x28f8fa9d0>,
#   <matplotlib.axis.XTick at 0x28f8f82d0>,
#   <matplotlib.axis.XTick at 0x28f8fb010>,
#   <matplotlib.axis.XTick at 0x28f8ff690>,
#   <matplotlib.axis.XTick at 0x28f90f5d0>,
#   <matplotlib.axis.XTick at 0x28f90ed10>,
#   <matplotlib.axis.XTick at 0x28f913590>,
#   <matplotlib.axis.XTick at 0x28f8ef190>,
#   <matplotlib.axis.XTick at 0x28f90de10>,
#   <matplotlib.axis.XTick at 0x28f8ca510>,
#   <matplotlib.axis.XTick at 0x28f917b90>,
#   <matplotlib.axis.XTick at 0x28f917a50>,
#   <matplotlib.axis.XTick at 0x28f91f790>,
#   <matplotlib.axis.XTick at 0x28f8e02d0>,
#   <matplotlib.axis.XTick at 0x28f914990>,
#   <matplotlib.axis.XTick at 0x28f9275d0>,
#   <matplotlib.axis.XTick at 0x28f927090>,
#   <matplotlib.axis.XTick at 0x28f92f3d0>,
#   <matplotlib.axis.XTick at 0x28f92dc90>,
#   <matplotlib.axis.XTick at 0x28f92ccd0>,
#   <matplotlib.axis.XTick at 0x28f9375d0>,
#   <matplotlib.axis.XTick at 0x28f936c50>,
#   <matplotlib.axis.XTick at 0x28f93f310>,
#   <matplotlib.axis.XTick at 0x28f93e710>,
#   <matplotlib.axis.XTick at 0x28f936cd0>,
#   <matplotlib.axis.XTick at 0x28f93fa50>,
#   <matplotlib.axis.XTick at 0x28f943210>,
#   <matplotlib.axis.XTick at 0x28f953410>,
#   <matplotlib.axis.XTick at 0x28f952f50>,
#   <matplotlib.axis.XTick at 0x28f957250>,
#   <matplotlib.axis.XTick at 0x28f956d10>,
#   <matplotlib.axis.XTick at 0x28f87df10>,
#   <matplotlib.axis.XTick at 0x28f9632d0>,
#   <matplotlib.axis.XTick at 0x28f962550>,
#   <matplotlib.axis.XTick at 0x28f966cd0>,
#   <matplotlib.axis.XTick at 0x28f964b50>,
#   <matplotlib.axis.XTick at 0x28f9664d0>,
#   <matplotlib.axis.XTick at 0x28f96acd0>,
#   <matplotlib.axis.XTick at 0x28f968d50>,
#   <matplotlib.axis.XTick at 0x28f976b10>,
#   <matplotlib.axis.XTick at 0x28f976610>,
#   <matplotlib.axis.XTick at 0x28f96a690>,
#   <matplotlib.axis.XTick at 0x28f96b690>,
#   <matplotlib.axis.XTick at 0x28f97e550>,
#   <matplotlib.axis.XTick at 0x28f982b90>,
#   <matplotlib.axis.XTick at 0x28f982890>,
#   <matplotlib.axis.XTick at 0x28f98a9d0>,
#   <matplotlib.axis.XTick at 0x28f98a1d0>,
#   <matplotlib.axis.XTick at 0x28f977910>,
#   <matplotlib.axis.XTick at 0x28f992a50>,
#   <matplotlib.axis.XTick at 0x28f992510>,
#   <matplotlib.axis.XTick at 0x28f993d90>,
#   <matplotlib.axis.XTick at 0x28f99a310>,
#   <matplotlib.axis.XTick at 0x28f99af10>,
#   <matplotlib.axis.XTick at 0x28f9a27d0>,
#   <matplotlib.axis.XTick at 0x28f9a2350>,
#   <matplotlib.axis.XTick at 0x28f9ae650>,
#   <matplotlib.axis.XTick at 0x28f9ae390>,
#   <matplotlib.axis.XTick at 0x28f9a2290>,
#   <matplotlib.axis.XTick at 0x28f9a35d0>,
#   <matplotlib.axis.XTick at 0x28f9b2310>,
#   <matplotlib.axis.XTick at 0x28f9ba610>,
#   <matplotlib.axis.XTick at 0x28f9ba1d0>,
#   <matplotlib.axis.XTick at 0x28f9c2650>,
#   <matplotlib.axis.XTick at 0x28f9c2090>,
#   <matplotlib.axis.XTick at 0x28f9ace90>,
#   <matplotlib.axis.XTick at 0x28f9ca590>,
#   <matplotlib.axis.XTick at 0x28f9c9c50>,
#   <matplotlib.axis.XTick at 0x28f9cb7d0>,
#   <matplotlib.axis.XTick at 0x28f9c8d10>,
#   <matplotlib.axis.XTick at 0x28f9c9f50>,
#   <matplotlib.axis.XTick at 0x28f9d25d0>,
#   <matplotlib.axis.XTick at 0x28f9d2010>,
#   <matplotlib.axis.XTick at 0x28f9d37d0>,
#   <matplotlib.axis.XTick at 0x28f9d9750>,
#   <matplotlib.axis.XTick at 0x28f9bafd0>,
#   <matplotlib.axis.XTick at 0x28f941cd0>,
#   <matplotlib.axis.XTick at 0x28f9db010>,
#   <matplotlib.axis.XTick at 0x28f9ea710>,
#   <matplotlib.axis.XTick at 0x28f9f2910>,
#   <matplotlib.axis.XTick at 0x28f9f23d0>,
#   <matplotlib.axis.XTick at 0x28f9d0110>,
#   <matplotlib.axis.XTick at 0x28f9eba50>,
#   <matplotlib.axis.XTick at 0x28f9f62d0>,
#   <matplotlib.axis.XTick at 0x28f9fe550>,
#   <matplotlib.axis.XTick at 0x28f9fe390>,
#   <matplotlib.axis.XTick at 0x28f9fe010>,
#   <matplotlib.axis.XTick at 0x28f9ff690>,
#   <matplotlib.axis.XTick at 0x28fa06210>,
#   <matplotlib.axis.XTick at 0x28fa0e550>,
#   <matplotlib.axis.XTick at 0x28fa0dc10>,
#   <matplotlib.axis.XTick at 0x28fa16390>,
#   <matplotlib.axis.XTick at 0x28fa06d10>,
#   <matplotlib.axis.XTick at 0x28fa04fd0>,
#   <matplotlib.axis.XTick at 0x28fa1e590>,
#   <matplotlib.axis.XTick at 0x28fa1e250>,
#   <matplotlib.axis.XTick at 0x28fa26410>,
#   <matplotlib.axis.XTick at 0x28fa25790>,
#   <matplotlib.axis.XTick at 0x28fa074d0>,
#   <matplotlib.axis.XTick at 0x28fa1fc50>,
#   <matplotlib.axis.XTick at 0x28fa2dd50>,
#   <matplotlib.axis.XTick at 0x28fa2fd10>,
#   <matplotlib.axis.XTick at 0x28fa35b90>,
#   <matplotlib.axis.XTick at 0x28fa35010>,
#   <matplotlib.axis.XTick at 0x28fa36b90>,
#   <matplotlib.axis.XTick at 0x28fa3fd10>,
#   <matplotlib.axis.XTick at 0x28fa3fa10>,
#   <matplotlib.axis.XTick at 0x28fa47b10>,
#   <matplotlib.axis.XTick at 0x28fa47650>,
#   <matplotlib.axis.XTick at 0x28fa3d990>,
#   <matplotlib.axis.XTick at 0x28fa3f650>,
#   <matplotlib.axis.XTick at 0x28fa4ba90>,
#   <matplotlib.axis.XTick at 0x28fa53cd0>,
#   <matplotlib.axis.XTick at 0x28fa53950>,
#   <matplotlib.axis.XTick at 0x28fa5bb10>,
#   <matplotlib.axis.XTick at 0x28fa5ae90>,
#   <matplotlib.axis.XTick at 0x28fa53450>,
#   <matplotlib.axis.XTick at 0x28fa6bbd0>,
#   <matplotlib.axis.XTick at 0x28fa6ae10>,
#   <matplotlib.axis.XTick at 0x28fa738d0>,
#   <matplotlib.axis.XTick at 0x28fa70ad0>,
#   <matplotlib.axis.XTick at 0x28fa733d0>,
#   <matplotlib.axis.XTick at 0x28fa77a50>,
#   <matplotlib.axis.XTick at 0x28fa75090>,
#   <matplotlib.axis.XTick at 0x28fa7f850>,
#   <matplotlib.axis.XTick at 0x28fa7ef90>,
#   <matplotlib.axis.XTick at 0x28fa76250>,
#   <matplotlib.axis.XTick at 0x28fa769d0>,
#   <matplotlib.axis.XTick at 0x28fa87650>,
#   <matplotlib.axis.XTick at 0x28fa8b6d0>,
#   <matplotlib.axis.XTick at 0x28fa8ad50>,
#   <matplotlib.axis.XTick at 0x28fa93450>,
#   <matplotlib.axis.XTick at 0x28fa91c10>,
#   <matplotlib.axis.XTick at 0x28fa92e50>,
#   <matplotlib.axis.XTick at 0x28fa9b410>,
#   <matplotlib.axis.XTick at 0x28fa9aa90>,
#   <matplotlib.axis.XTick at 0x28faa31d0>,
#   <matplotlib.axis.XTick at 0x28fa24090>,
#   <matplotlib.axis.XTick at 0x28faa2150>,
#   <matplotlib.axis.XTick at 0x28faa7310>,
#   <matplotlib.axis.XTick at 0x28faa6ed0>,
#   <matplotlib.axis.XTick at 0x28fab3110>,
#   <matplotlib.axis.XTick at 0x28fab2cd0>,
#   <matplotlib.axis.XTick at 0x28faa6350>,
#   <matplotlib.axis.XTick at 0x28fa05e50>,
#   <matplotlib.axis.XTick at 0x28fa73fd0>,
#   <matplotlib.axis.XTick at 0x28fab6e50>,
#   <matplotlib.axis.XTick at 0x28fac7710>,
#   <matplotlib.axis.XTick at 0x28fac72d0>,
#   <matplotlib.axis.XTick at 0x28f9b21d0>,
#   <matplotlib.axis.XTick at 0x28faa19d0>,
#   <matplotlib.axis.XTick at 0x28facabd0>,
#   <matplotlib.axis.XTick at 0x28fad32d0>,
#   <matplotlib.axis.XTick at 0x28fad25d0>,
#   <matplotlib.axis.XTick at 0x28fad2c50>,
#   <matplotlib.axis.XTick at 0x28fa9ad50>,
#   <matplotlib.axis.XTick at 0x28fad6dd0>,
#   <matplotlib.axis.XTick at 0x28fadf350>,
#   <matplotlib.axis.XTick at 0x28fadee90>,
#   <matplotlib.axis.XTick at 0x28faef210>,
#   <matplotlib.axis.XTick at 0x28faa6c50>,
#   <matplotlib.axis.XTick at 0x28fadeb50>,
#   <matplotlib.axis.XTick at 0x28faf3450>,
#   <matplotlib.axis.XTick at 0x28faf3150>,
#   <matplotlib.axis.XTick at 0x28faf7290>,
#   <matplotlib.axis.XTick at 0x28faf65d0>,
#   <matplotlib.axis.XTick at 0x28fadec10>,
#   <matplotlib.axis.XTick at 0x28faf2350>,
#   <matplotlib.axis.XTick at 0x28fafa7d0>,
#   <matplotlib.axis.XTick at 0x28fafefd0>,
#   <matplotlib.axis.XTick at 0x28fafe6d0>,
#   <matplotlib.axis.XTick at 0x28fafc790>,
#   <matplotlib.axis.XTick at 0x28fafe590>,
#   <matplotlib.axis.XTick at 0x28fb08710>,
#   <matplotlib.axis.XTick at 0x28fb16b90>,
#   <matplotlib.axis.XTick at 0x28fb162d0>,
#   <matplotlib.axis.XTick at 0x28fb1aa10>,
#   <matplotlib.axis.XTick at 0x28fafbf10>,
#   <matplotlib.axis.XTick at 0x28fb08950>,
#   <matplotlib.axis.XTick at 0x28fb22c50>,
#   <matplotlib.axis.XTick at 0x28fb22990>,
#   <matplotlib.axis.XTick at 0x28fb2ab10>,
#   <matplotlib.axis.XTick at 0x28fb2a250>,
#   <matplotlib.axis.XTick at 0x28fb178d0>,
#   <matplotlib.axis.XTick at 0x28fb2a390>,
#   <matplotlib.axis.XTick at 0x28fb32390>,
#   <matplotlib.axis.XTick at 0x28fb3a890>,
#   <matplotlib.axis.XTick at 0x28fb39f90>,
#   <matplotlib.axis.XTick at 0x28fab3810>,
#   <matplotlib.axis.XTick at 0x28fb393d0>,
#   <matplotlib.axis.XTick at 0x28fb42390>,
#   <matplotlib.axis.XTick at 0x28fb4a750>,
#   <matplotlib.axis.XTick at 0x28fb4a210>,
#   <matplotlib.axis.XTick at 0x28fb4e550>,
#   <matplotlib.axis.XTick at 0x28fb22290>,
#   <matplotlib.axis.XTick at 0x28fb4af50>,
#   <matplotlib.axis.XTick at 0x28fb56810>,
#   <matplotlib.axis.XTick at 0x28fb55a10>,
#   <matplotlib.axis.XTick at 0x28fb5e710>,
#   <matplotlib.axis.XTick at 0x28fb5dd50>,
#   <matplotlib.axis.XTick at 0x28fb48090>,
#   <matplotlib.axis.XTick at 0x28fb57fd0>,
#   <matplotlib.axis.XTick at 0x28fb6dd10>,
#   <matplotlib.axis.XTick at 0x28fb72590>,
#   <matplotlib.axis.XTick at 0x28fb71e90>,
#   <matplotlib.axis.XTick at 0x28fb1bbd0>,
#   <matplotlib.axis.XTick at 0x28fb71cd0>,
#   <matplotlib.axis.XTick at 0x28fb7a050>,
#   <matplotlib.axis.XTick at 0x28fb6fed0>,
#   <matplotlib.axis.XTick at 0x28fb81650>,
#   <matplotlib.axis.XTick at 0x28fb83550>,
#   <matplotlib.axis.XTick at 0x28fb7b050>,
#   <matplotlib.axis.XTick at 0x28fb79f10>,
#   <matplotlib.axis.XTick at 0x28fa3e6d0>,
#   <matplotlib.axis.XTick at 0x28fb8e950>,
#   <matplotlib.axis.XTick at 0x28fb8e010>,
#   <matplotlib.axis.XTick at 0x28fb96810>,
#   <matplotlib.axis.XTick at 0x28fb80a90>,
#   <matplotlib.axis.XTick at 0x28fb87890>,
#   <matplotlib.axis.XTick at 0x28fb9e650>,
#   <matplotlib.axis.XTick at 0x28fb9dd50>,
#   <matplotlib.axis.XTick at 0x28fba2550>,
#   <matplotlib.axis.XTick at 0x28fba0c90>,
#   <matplotlib.axis.XTick at 0x28fba3710>,
#   <matplotlib.axis.XTick at 0x28fbaa650>,
#   <matplotlib.axis.XTick at 0x28fbaa0d0>,
#   <matplotlib.axis.XTick at 0x28fbab8d0>,
#   <matplotlib.axis.XTick at 0x28fbb2110>,
#   <matplotlib.axis.XTick at 0x28fbb36d0>,
#   <matplotlib.axis.XTick at 0x28fbab250>,
#   <matplotlib.axis.XTick at 0x28fbba150>,
#   <matplotlib.axis.XTick at 0x28fbce550>,
#   <matplotlib.axis.XTick at 0x28fbcdb90>,
#   <matplotlib.axis.XTick at 0x28fbcdd90>,
#   <matplotlib.axis.XTick at 0x28fb2bad0>,
#   <matplotlib.axis.XTick at 0x28fbb1c50>,
#   <matplotlib.axis.XTick at 0x28fbd0d50>,
#   <matplotlib.axis.XTick at 0x28fbd41d0>,
#   <matplotlib.axis.XTick at 0x28fbd7950>,
#   <matplotlib.axis.XTick at 0x28fbd5910>,
#   <matplotlib.axis.XTick at 0x28fbd6dd0>,
#   <matplotlib.axis.XTick at 0x28fbdfed0>,
#   <matplotlib.axis.XTick at 0x28fbe3e10>,
#   <matplotlib.axis.XTick at 0x28fbe1150>,
#   <matplotlib.axis.XTick at 0x28fbefc90>,
#   <matplotlib.axis.XTick at 0x28fbef990>,
#   <matplotlib.axis.XTick at 0x28fbe2cd0>,
#   <matplotlib.axis.XTick at 0x28fbf3f10>,
#   <matplotlib.axis.XTick at 0x28fbf3610>,
#   <matplotlib.axis.XTick at 0x28fbf7d10>,
#   <matplotlib.axis.XTick at 0x28fbf7850>,
#   <matplotlib.axis.XTick at 0x28fbed690>,
#   <matplotlib.axis.XTick at 0x28fb94510>,
#   <matplotlib.axis.XTick at 0x28fbfbb50>,
#   <matplotlib.axis.XTick at 0x28fc03bd0>,
#   <matplotlib.axis.XTick at 0x28fc035d0>,
#   <matplotlib.axis.XTick at 0x28fc00790>,
#   <matplotlib.axis.XTick at 0x28fc02250>,
#   <matplotlib.axis.XTick at 0x28fc0cc90>,
#   <matplotlib.axis.XTick at 0x28fc1b950>,
#   <matplotlib.axis.XTick at 0x28fc1b410>,
#   <matplotlib.axis.XTick at 0x28fc1f7d0>,
#   <matplotlib.axis.XTick at 0x28fc1f350>,
#   <matplotlib.axis.XTick at 0x28fc1a0d0>,
#   <matplotlib.axis.XTick at 0x28fc27850>,
#   <matplotlib.axis.XTick at 0x28fc25390>,
#   <matplotlib.axis.XTick at 0x28fc2f6d0>,
#   <matplotlib.axis.XTick at 0x28fc2f1d0>,
#   <matplotlib.axis.XTick at 0x28fc1c810>,
#   <matplotlib.axis.XTick at 0x28fc27010>,
#   <matplotlib.axis.XTick at 0x28fc3add0>,
#   <matplotlib.axis.XTick at 0x28fc3f550>,
#   <matplotlib.axis.XTick at 0x28fc3f110>,
#   <matplotlib.axis.XTick at 0x28fc3c1d0>,
#   <matplotlib.axis.XTick at 0x28fc3e490>,
#   <matplotlib.axis.XTick at 0x28fc44d90>,
#   <matplotlib.axis.XTick at 0x28fc4b310>,
#   <matplotlib.axis.XTick at 0x28fc4a690>,
#   <matplotlib.axis.XTick at 0x28fc53150>,
#   <matplotlib.axis.XTick at 0x28fc46ad0>,
#   <matplotlib.axis.XTick at 0x28fc47b90>,
#   <matplotlib.axis.XTick at 0x28fc4bd90>,
#   <matplotlib.axis.XTick at 0x28fc5f790>,
#   <matplotlib.axis.XTick at 0x28fc5f450>,
#   <matplotlib.axis.XTick at 0x28fc63710>,
#   <matplotlib.axis.XTick at 0x28fb1b910>,
#   <matplotlib.axis.XTick at 0x28fc2ef90>,
#   <matplotlib.axis.XTick at 0x28fc6f590>,
#   <matplotlib.axis.XTick at 0x28fc6ed10>,
#   <matplotlib.axis.XTick at 0x28fc77450>,
#   <matplotlib.axis.XTick at 0x28fc75b90>,
#   <matplotlib.axis.XTick at 0x28fc76650>,
#   <matplotlib.axis.XTick at 0x28fc7f550>,
#   <matplotlib.axis.XTick at 0x28fc7e990>,
#   <matplotlib.axis.XTick at 0x28fc87510>,
#   <matplotlib.axis.XTick at 0x28fc86fd0>,
#   <matplotlib.axis.XTick at 0x28fc7ca90>,
#   <matplotlib.axis.XTick at 0x28fbf8ed0>,
#   <matplotlib.axis.XTick at 0x28fc8b410>,
#   <matplotlib.axis.XTick at 0x28fc8f590>,
#   <matplotlib.axis.XTick at 0x28fc8e910>,
#   <matplotlib.axis.XTick at 0x28fc97310>,
#   <matplotlib.axis.XTick at 0x28fc96bd0>,
#   <matplotlib.axis.XTick at 0x28fc844d0>,
#   <matplotlib.axis.XTick at 0x28fca2f90>,
#   <matplotlib.axis.XTick at 0x28fca2b10>,
#   <matplotlib.axis.XTick at 0x28fcaaed0>,
#   <matplotlib.axis.XTick at 0x28fa9be50>,
#   <matplotlib.axis.XTick at 0x28fcab5d0>,
#   <matplotlib.axis.XTick at 0x28fc5ca10>,
#   <matplotlib.axis.XTick at 0x28fcb6490>,
#   <matplotlib.axis.XTick at 0x28fcbaad0>,
#   <matplotlib.axis.XTick at 0x28fcb9e90>,
#   <matplotlib.axis.XTick at 0x28fcb5cd0>,
#   <matplotlib.axis.XTick at 0x28fcb7ad0>,
#   <matplotlib.axis.XTick at 0x28fcbe9d0>,
#   <matplotlib.axis.XTick at 0x28fcce990>,
#   <matplotlib.axis.XTick at 0x28fcce550>,
#   <matplotlib.axis.XTick at 0x28fcd6850>,
#   <matplotlib.axis.XTick at 0x28fcd6290>,
#   <matplotlib.axis.XTick at 0x28fcb9310>,
#   <matplotlib.axis.XTick at 0x28fcda810>,
#   <matplotlib.axis.XTick at 0x28fcd9c50>,
#   <matplotlib.axis.XTick at 0x28fcde650>,
#   <matplotlib.axis.XTick at 0x28fcd9450>,
#   <matplotlib.axis.XTick at 0x28fcdae90>,
#   <matplotlib.axis.XTick at 0x28fce6810>,
#   <matplotlib.axis.XTick at 0x28fce6390>,
#   <matplotlib.axis.XTick at 0x28fcee610>,
#   <matplotlib.axis.XTick at 0x28fcee390>,
#   <matplotlib.axis.XTick at 0x28fce5e50>,
#   <matplotlib.axis.XTick at 0x28fce76d0>,
#   <matplotlib.axis.XTick at 0x28fcf1850>,
#   <matplotlib.axis.XTick at 0x28fcfa6d0>,
#   <matplotlib.axis.XTick at 0x28fcfa190>,
#   <matplotlib.axis.XTick at 0x28fd06590>,
#   <matplotlib.axis.XTick at 0x28fd05e50>,
#   <matplotlib.axis.XTick at 0x28fceef10>,
#   <matplotlib.axis.XTick at 0x28fd078d0>,
#   <matplotlib.axis.XTick at 0x28fd0db50>,
#   <matplotlib.axis.XTick at 0x28fd0ffd0>,
#   <matplotlib.axis.XTick at 0x28fcddb90>,
#   <matplotlib.axis.XTick at 0x28fd0f210>,
#   <matplotlib.axis.XTick at 0x28fd1a510>,
#   <matplotlib.axis.XTick at 0x28fd1a250>,
#   <matplotlib.axis.XTick at 0x28fd262d0>,
#   <matplotlib.axis.XTick at 0x28fd25990>,
#   <matplotlib.axis.XTick at 0x28fcf8e10>,
#   <matplotlib.axis.XTick at 0x28fd18f50>,
#   <matplotlib.axis.XTick at 0x28fcd7dd0>,
#   <matplotlib.axis.XTick at 0x28fd2e4d0>,
#   <matplotlib.axis.XTick at 0x28fd3a890>,
#   <matplotlib.axis.XTick at 0x28fd3a210>,
#   <matplotlib.axis.XTick at 0x28fd06250>,
#   <matplotlib.axis.XTick at 0x28fcbd450>,
#   <matplotlib.axis.XTick at 0x28fd3e2d0>,
#   <matplotlib.axis.XTick at 0x28fd42390>,
#   <matplotlib.axis.XTick at 0x28fd40d50>,
#   <matplotlib.axis.XTick at 0x28fd41ed0>,
#   <matplotlib.axis.XTick at 0x28fd43b50>,
#   <matplotlib.axis.XTick at 0x28fd4e010>,
#   <matplotlib.axis.XTick at 0x28fd4f750>,
#   <matplotlib.axis.XTick at 0x28fd55750>,
#   <matplotlib.axis.XTick at 0x28fd57d10>,
#   <matplotlib.axis.XTick at 0x28fd4cdd0>,
#   <matplotlib.axis.XTick at 0x28fd4f5d0>,
#   <matplotlib.axis.XTick at 0x28fd625d0>,
#   <matplotlib.axis.XTick at 0x28fd617d0>,
#   <matplotlib.axis.XTick at 0x28fd66310>,
#   <matplotlib.axis.XTick at 0x28fd65dd0>,
#   <matplotlib.axis.XTick at 0x28fd67ed0>,
#   <matplotlib.axis.XTick at 0x28fd5fe90>,
#   <matplotlib.axis.XTick at 0x28fd6e150>,
#   <matplotlib.axis.XTick at 0x28fd6f8d0>,
#   <matplotlib.axis.XTick at 0x28fd79e90>,
#   <matplotlib.axis.XTick at 0x28fd78d50>,
#   <matplotlib.axis.XTick at 0x28fd7a7d0>,
#   <matplotlib.axis.XTick at 0x28fd89e50>,
#   <matplotlib.axis.XTick at 0x28fd8be50>,
#   <matplotlib.axis.XTick at 0x28fd8fd50>,
#   <matplotlib.axis.XTick at 0x28fd8f4d0>,
#   <matplotlib.axis.XTick at 0x28fd78bd0>,
#   <matplotlib.axis.XTick at 0x28fd89a50>,
#   <matplotlib.axis.XTick at 0x28fd93690>,
#   <matplotlib.axis.XTick at 0x28fd97d10>,
#   <matplotlib.axis.XTick at 0x28fd97850>,
#   <matplotlib.axis.XTick at 0x28fda7b90>,
#   <matplotlib.axis.XTick at 0x28fcbfb90>,
#   <matplotlib.axis.XTick at 0x28fd60d10>,
#   <matplotlib.axis.XTick at 0x28fdaf990>,
#   <matplotlib.axis.XTick at 0x28fdadb90>,
#   <matplotlib.axis.XTick at 0x28fdb3650>,
#   <matplotlib.axis.XTick at 0x28fdb0110>,
#   <matplotlib.axis.XTick at 0x28fdb22d0>,
#   <matplotlib.axis.XTick at 0x28fdb75d0>,
#   <matplotlib.axis.XTick at 0x28fdb6d10>,
#   <matplotlib.axis.XTick at 0x28fdbf5d0>,
#   <matplotlib.axis.XTick at 0x28fdbe850>,
#   <matplotlib.axis.XTick at 0x28fdb5e50>,
#   <matplotlib.axis.XTick at 0x28fdb4e90>,
#   <matplotlib.axis.XTick at 0x28fdc72d0>,
#   <matplotlib.axis.XTick at 0x28fdd3710>,
#   <matplotlib.axis.XTick at 0x28fdd31d0>,
#   <matplotlib.axis.XTick at 0x28fdd7350>,
#   <matplotlib.axis.XTick at 0x28fdd6490>,
#   <matplotlib.axis.XTick at 0x28fd93c10>,
#   <matplotlib.axis.XTick at 0x28fddf2d0>,
#   <matplotlib.axis.XTick at 0x28fdde610>,
#   <matplotlib.axis.XTick at 0x28fde3210>,
#   <matplotlib.axis.XTick at 0x28fd89d50>,
#   <matplotlib.axis.XTick at 0x28fde2c10>,
#   <matplotlib.axis.XTick at 0x28fdef3d0>,
#   <matplotlib.axis.XTick at 0x28fdef0d0>,
#   <matplotlib.axis.XTick at 0x28fdfb250>,
#   <matplotlib.axis.XTick at 0x28fdfa550>,
#   <matplotlib.axis.XTick at 0x28fdece90>,
#   <matplotlib.axis.XTick at 0x28fdefa50>,
#   <matplotlib.axis.XTick at 0x28fd5fd10>,
#   <matplotlib.axis.XTick at 0x28fe03110>,
#   <matplotlib.axis.XTick at 0x28fe07910>,
#   <matplotlib.axis.XTick at 0x28fe07310>,
#   <matplotlib.axis.XTick at 0x28fdd4610>,
#   <matplotlib.axis.XTick at 0x28fdb4510>,
#   <matplotlib.axis.XTick at 0x28fe0b6d0>,
#   <matplotlib.axis.XTick at 0x28fe139d0>,
#   <matplotlib.axis.XTick at 0x28fe12d10>,
#   <matplotlib.axis.XTick at 0x28fe12150>,
#   <matplotlib.axis.XTick at 0x28fe13250>,
#   <matplotlib.axis.XTick at 0x28fe1b350>,
#   <matplotlib.axis.XTick at 0x28fe23890>,
#   <matplotlib.axis.XTick at 0x28fe23450>,
#   <matplotlib.axis.XTick at 0x28fe27750>,
#   <matplotlib.axis.XTick at 0x28fe27350>,
#   <matplotlib.axis.XTick at 0x28fe23fd0>,
#   <matplotlib.axis.XTick at 0x28fe2b910>,
#   <matplotlib.axis.XTick at 0x28fe2b5d0>,
#   <matplotlib.axis.XTick at 0x28fe37810>,
#   <matplotlib.axis.XTick at 0x28fe372d0>,
#   <matplotlib.axis.XTick at 0x28fe24f90>,
#   <matplotlib.axis.XTick at 0x28fe0b310>,
#   <matplotlib.axis.XTick at 0x28fe46b50>,
#   <matplotlib.axis.XTick at 0x28fe4b590>,
#   <matplotlib.axis.XTick at 0x28fe4a890>,
#   <matplotlib.axis.XTick at 0x28fe485d0>,
#   <matplotlib.axis.XTick at 0x28fe49c50>,
#   <matplotlib.axis.XTick at 0x28fe53290>,
#   <matplotlib.axis.XTick at 0x28fe57450>,
#   <matplotlib.axis.XTick at 0x28fe56fd0>,
#   <matplotlib.axis.XTick at 0x28fe5f0d0>,
#   <matplotlib.axis.XTick at 0x28fe20a50>,
#   <matplotlib.axis.XTick at 0x28fe50fd0>,
#   <matplotlib.axis.XTick at 0x28fe67210>,
#   <matplotlib.axis.XTick at 0x28fe66f10>,
#   <matplotlib.axis.XTick at 0x28fe6ef90>,
#   <matplotlib.axis.XTick at 0x28fe6e2d0>,
#   <matplotlib.axis.XTick at 0x28fdd5dd0>,
#   <matplotlib.axis.XTick at 0x28fe66ad0>,
#   <matplotlib.axis.XTick at 0x28fe765d0>,
#   <matplotlib.axis.XTick at 0x28fe82d90>,
#   <matplotlib.axis.XTick at 0x28fe820d0>,
#   <matplotlib.axis.XTick at 0x28fe80750>,
#   <matplotlib.axis.XTick at 0x28fe83e90>,
#   ...],
#  [Text(0, 0, 'AUT'),
#   Text(1, 0, 'AUT'),
#   Text(2, 0, 'AUT'),
#   Text(3, 0, 'AUT'),
#   Text(4, 0, 'AUT'),
#   Text(5, 0, 'AUT'),
#   Text(6, 0, 'AUT'),
#   Text(7, 0, 'AUT'),
#   Text(8, 0, 'AUT'),
#   Text(9, 0, 'AUT'),
#   Text(10, 0, 'AUT'),
#   Text(11, 0, 'AUT'),
#   Text(12, 0, 'AUT'),
#   Text(13, 0, 'AUT'),
#   Text(14, 0, 'AUT'),
#   Text(15, 0, 'AUT'),
#   Text(16, 0, 'AUT'),
#   Text(17, 0, 'AUT'),
#   Text(18, 0, 'AUT'),
#   Text(19, 0, 'AUT'),
#   Text(20, 0, 'AUT'),
#   Text(21, 0, 'AUT'),
#   Text(22, 0, 'AUT'),
#   Text(23, 0, 'AUT'),
#   Text(24, 0, 'AUT'),
#   Text(25, 0, 'AUT'),
#   Text(26, 0, 'AUT'),
#   Text(27, 0, 'AUT'),
#   Text(28, 0, 'AUT'),
#   Text(29, 0, 'AUT'),
#   Text(30, 0, 'AUT'),
#   Text(31, 0, 'AUT'),
#   Text(32, 0, 'AUT'),
#   Text(33, 0, 'BEL'),
#   Text(34, 0, 'BEL'),
#   Text(35, 0, 'BEL'),
#   Text(36, 0, 'BEL'),
#   Text(37, 0, 'BEL'),
#   Text(38, 0, 'BEL'),
#   Text(39, 0, 'BRA'),
#   Text(40, 0, 'BRA'),
#   Text(41, 0, 'BRA'),
#   Text(42, 0, 'BRA'),
#   Text(43, 0, 'BRA'),
#   Text(44, 0, 'BRA'),
#   Text(45, 0, 'BRA'),
#   Text(46, 0, 'BRA'),
#   Text(47, 0, 'BRA'),
#   Text(48, 0, 'BRA'),
#   Text(49, 0, 'BRA'),
#   Text(50, 0, 'BRA'),
#   Text(51, 0, 'BRA'),
#   Text(52, 0, 'BRA'),
#   Text(53, 0, 'BRA'),
#   Text(54, 0, 'BRA'),
#   Text(55, 0, 'BRA'),
#   Text(56, 0, 'BRA'),
#   Text(57, 0, 'BRA'),
#   Text(58, 0, 'BRA'),
#   Text(59, 0, 'BRA'),
#   Text(60, 0, 'CAN'),
#   Text(61, 0, 'CAN'),
#   Text(62, 0, 'CAN'),
#   Text(63, 0, 'CAN'),
#   Text(64, 0, 'CAN'),
#   Text(65, 0, 'CAN'),
#   Text(66, 0, 'CAN'),
#   Text(67, 0, 'CAN'),
#   Text(68, 0, 'CAN'),
#   Text(69, 0, 'CAN'),
#   Text(70, 0, 'CAN'),
#   Text(71, 0, 'CAN'),
#   Text(72, 0, 'CAN'),
#   Text(73, 0, 'CAN'),
#   Text(74, 0, 'CAN'),
#   Text(75, 0, 'CAN'),
#   Text(76, 0, 'CAN'),
#   Text(77, 0, 'CAN'),
#   Text(78, 0, 'CAN'),
#   Text(79, 0, 'CAN'),
#   Text(80, 0, 'CAN'),
#   Text(81, 0, 'CAN'),
#   Text(82, 0, 'CAN'),
#   Text(83, 0, 'CAN'),
#   Text(84, 0, 'CAN'),
#   Text(85, 0, 'CAN'),
#   Text(86, 0, 'CAN'),
#   Text(87, 0, 'CAN'),
#   Text(88, 0, 'CAN'),
#   Text(89, 0, 'CAN'),
#   Text(90, 0, 'CAN'),
#   Text(91, 0, 'CAN'),
#   Text(92, 0, 'CAN'),
#   Text(93, 0, 'CAN'),
#   Text(94, 0, 'CAN'),
#   Text(95, 0, 'CAN'),
#   Text(96, 0, 'CHE'),
#   Text(97, 0, 'CHE'),
#   Text(98, 0, 'CHE'),
#   Text(99, 0, 'CHE'),
#   Text(100, 0, 'CHE'),
#   Text(101, 0, 'CHE'),
#   Text(102, 0, 'CHE'),
#   Text(103, 0, 'CHE'),
#   Text(104, 0, 'CHE'),
#   Text(105, 0, 'CHE'),
#   Text(106, 0, 'CHE'),
#   Text(107, 0, 'CHE'),
#   Text(108, 0, 'CHE'),
#   Text(109, 0, 'CHE'),
#   Text(110, 0, 'CHE'),
#   Text(111, 0, 'CHE'),
#   Text(112, 0, 'CHE'),
#   Text(113, 0, 'CHE'),
#   Text(114, 0, 'CHE'),
#   Text(115, 0, 'CHE'),
#   Text(116, 0, 'CHE'),
#   Text(117, 0, 'CHL'),
#   Text(118, 0, 'CHL'),
#   Text(119, 0, 'CHL'),
#   Text(120, 0, 'CHL'),
#   Text(121, 0, 'CHL'),
#   Text(122, 0, 'CHL'),
#   Text(123, 0, 'CHL'),
#   Text(124, 0, 'CHL'),
#   Text(125, 0, 'CHL'),
#   Text(126, 0, 'CHL'),
#   Text(127, 0, 'CHL'),
#   Text(128, 0, 'CHL'),
#   Text(129, 0, 'CHL'),
#   Text(130, 0, 'CHL'),
#   Text(131, 0, 'CHL'),
#   Text(132, 0, 'CHL'),
#   Text(133, 0, 'CHL'),
#   Text(134, 0, 'CHL'),
#   Text(135, 0, 'CHL'),
#   Text(136, 0, 'CHL'),
#   Text(137, 0, 'CHL'),
#   Text(138, 0, 'CHL'),
#   Text(139, 0, 'CHL'),
#   Text(140, 0, 'CHL'),
#   Text(141, 0, 'CHL'),
#   Text(142, 0, 'CHL'),
#   Text(143, 0, 'CHL'),
#   Text(144, 0, 'CHL'),
#   Text(145, 0, 'CHL'),
#   Text(146, 0, 'CHL'),
#   Text(147, 0, 'CHL'),
#   Text(148, 0, 'CHL'),
#   Text(149, 0, 'CHL'),
#   Text(150, 0, 'CHL'),
#   Text(151, 0, 'CHL'),
#   Text(152, 0, 'CHL'),
#   Text(153, 0, 'COL'),
#   Text(154, 0, 'COL'),
#   Text(155, 0, 'COL'),
#   Text(156, 0, 'COL'),
#   Text(157, 0, 'COL'),
#   Text(158, 0, 'COL'),
#   Text(159, 0, 'COL'),
#   Text(160, 0, 'COL'),
#   Text(161, 0, 'COL'),
#   Text(162, 0, 'COL'),
#   Text(163, 0, 'COL'),
#   Text(164, 0, 'COL'),
#   Text(165, 0, 'COL'),
#   Text(166, 0, 'COL'),
#   Text(167, 0, 'COL'),
#   Text(168, 0, 'COL'),
#   Text(169, 0, 'COL'),
#   Text(170, 0, 'COL'),
#   Text(171, 0, 'CRI'),
#   Text(172, 0, 'CRI'),
#   Text(173, 0, 'CRI'),
#   Text(174, 0, 'CRI'),
#   Text(175, 0, 'CRI'),
#   Text(176, 0, 'CZE'),
#   Text(177, 0, 'CZE'),
#   Text(178, 0, 'CZE'),
#   Text(179, 0, 'CZE'),
#   Text(180, 0, 'CZE'),
#   Text(181, 0, 'CZE'),
#   Text(182, 0, 'CZE'),
#   Text(183, 0, 'CZE'),
#   Text(184, 0, 'CZE'),
#   Text(185, 0, 'CZE'),
#   Text(186, 0, 'CZE'),
#   Text(187, 0, 'CZE'),
#   Text(188, 0, 'CZE'),
#   Text(189, 0, 'CZE'),
#   Text(190, 0, 'CZE'),
#   Text(191, 0, 'CZE'),
#   Text(192, 0, 'CZE'),
#   Text(193, 0, 'CZE'),
#   Text(194, 0, 'CZE'),
#   Text(195, 0, 'CZE'),
#   Text(196, 0, 'CZE'),
#   Text(197, 0, 'CZE'),
#   Text(198, 0, 'CZE'),
#   Text(199, 0, 'CZE'),
#   Text(200, 0, 'DEU'),
#   Text(201, 0, 'DEU'),
#   Text(202, 0, 'DEU'),
#   Text(203, 0, 'DEU'),
#   Text(204, 0, 'DEU'),
#   Text(205, 0, 'DEU'),
#   Text(206, 0, 'DEU'),
#   Text(207, 0, 'DEU'),
#   Text(208, 0, 'DEU'),
#   Text(209, 0, 'DEU'),
#   Text(210, 0, 'DEU'),
#   Text(211, 0, 'DEU'),
#   Text(212, 0, 'DEU'),
#   Text(213, 0, 'DEU'),
#   Text(214, 0, 'DEU'),
#   Text(215, 0, 'DEU'),
#   Text(216, 0, 'DEU'),
#   Text(217, 0, 'DEU'),
#   Text(218, 0, 'DNK'),
#   Text(219, 0, 'DNK'),
#   Text(220, 0, 'DNK'),
#   Text(221, 0, 'DNK'),
#   Text(222, 0, 'DNK'),
#   Text(223, 0, 'DNK'),
#   Text(224, 0, 'DNK'),
#   Text(225, 0, 'DNK'),
#   Text(226, 0, 'DNK'),
#   Text(227, 0, 'DNK'),
#   Text(228, 0, 'DNK'),
#   Text(229, 0, 'DNK'),
#   Text(230, 0, 'DNK'),
#   Text(231, 0, 'DNK'),
#   Text(232, 0, 'DNK'),
#   Text(233, 0, 'DNK'),
#   Text(234, 0, 'DNK'),
#   Text(235, 0, 'DNK'),
#   Text(236, 0, 'DNK'),
#   Text(237, 0, 'DNK'),
#   Text(238, 0, 'DNK'),
#   Text(239, 0, 'DNK'),
#   Text(240, 0, 'DNK'),
#   Text(241, 0, 'DNK'),
#   Text(242, 0, 'DNK'),
#   Text(243, 0, 'DNK'),
#   Text(244, 0, 'DNK'),
#   Text(245, 0, 'DNK'),
#   Text(246, 0, 'DNK'),
#   Text(247, 0, 'DNK'),
#   Text(248, 0, 'DNK'),
#   Text(249, 0, 'DNK'),
#   Text(250, 0, 'DNK'),
#   Text(251, 0, 'DNK'),
#   Text(252, 0, 'DNK'),
#   Text(253, 0, 'DNK'),
#   Text(254, 0, 'ESP'),
#   Text(255, 0, 'ESP'),
#   Text(256, 0, 'ESP'),
#   Text(257, 0, 'ESP'),
#   Text(258, 0, 'ESP'),
#   Text(259, 0, 'ESP'),
#   Text(260, 0, 'ESP'),
#   Text(261, 0, 'ESP'),
#   Text(262, 0, 'ESP'),
#   Text(263, 0, 'ESP'),
#   Text(264, 0, 'ESP'),
# ...
#   Text(306, 0, 'FIN'),
#   Text(307, 0, 'FIN'),
#   Text(308, 0, 'FIN'),
#   Text(309, 0, 'FIN'),
#   Text(310, 0, 'FIN'),
#   Text(311, 0, 'FIN'),
#   Text(312, 0, 'FIN'),
#   Text(313, 0, 'FIN'),
#   Text(314, 0, 'FIN'),
#   Text(315, 0, 'FIN'),
#   Text(316, 0, 'FIN'),
#   Text(317, 0, 'FIN'),
#   Text(318, 0, 'FIN'),
#   Text(319, 0, 'FIN'),
#   Text(320, 0, 'FIN'),
#   Text(321, 0, 'FIN'),
#   Text(322, 0, 'FIN'),
#   Text(323, 0, 'FIN'),
#   Text(324, 0, 'FIN'),
#   Text(325, 0, 'FIN'),
#   Text(326, 0, 'FIN'),
#   Text(327, 0, 'FIN'),
#   Text(328, 0, 'FIN'),
#   Text(329, 0, 'FIN'),
#   Text(330, 0, 'FIN'),
#   Text(331, 0, 'FIN'),
#   Text(332, 0, 'FIN'),
#   Text(333, 0, 'FIN'),
#   Text(334, 0, 'FIN'),
#   Text(335, 0, 'FIN'),
#   Text(336, 0, 'FIN'),
#   Text(337, 0, 'FIN'),
#   Text(338, 0, 'FIN'),
#   Text(339, 0, 'FIN'),
#   Text(340, 0, 'GBR'),
#   Text(341, 0, 'GBR'),
#   Text(342, 0, 'GBR'),
#   Text(343, 0, 'GBR'),
#   Text(344, 0, 'GBR'),
#   Text(345, 0, 'GBR'),
#   Text(346, 0, 'GBR'),
#   Text(347, 0, 'GBR'),
#   Text(348, 0, 'GBR'),
#   Text(349, 0, 'GBR'),
#   Text(350, 0, 'GBR'),
#   Text(351, 0, 'GBR'),
#   Text(352, 0, 'GBR'),
#   Text(353, 0, 'GBR'),
#   Text(354, 0, 'GBR'),
#   Text(355, 0, 'GRC'),
#   Text(356, 0, 'GRC'),
#   Text(357, 0, 'GRC'),
#   Text(358, 0, 'GRC'),
#   Text(359, 0, 'GRC'),
#   Text(360, 0, 'GRC'),
#   Text(361, 0, 'GRC'),
#   Text(362, 0, 'GRC'),
#   Text(363, 0, 'GRC'),
#   Text(364, 0, 'GRC'),
#   Text(365, 0, 'GRC'),
#   Text(366, 0, 'GRC'),
#   Text(367, 0, 'GRC'),
#   Text(368, 0, 'GRC'),
#   Text(369, 0, 'GRC'),
#   Text(370, 0, 'GRC'),
#   Text(371, 0, 'GRC'),
#   Text(372, 0, 'GRC'),
#   Text(373, 0, 'GRC'),
#   Text(374, 0, 'GRC'),
#   Text(375, 0, 'GRC'),
#   Text(376, 0, 'HUN'),
#   Text(377, 0, 'HUN'),
#   Text(378, 0, 'HUN'),
#   Text(379, 0, 'HUN'),
#   Text(380, 0, 'HUN'),
#   Text(381, 0, 'HUN'),
#   Text(382, 0, 'HUN'),
#   Text(383, 0, 'HUN'),
#   Text(384, 0, 'HUN'),
#   Text(385, 0, 'HUN'),
#   Text(386, 0, 'HUN'),
#   Text(387, 0, 'HUN'),
#   Text(388, 0, 'HUN'),
#   Text(389, 0, 'HUN'),
#   Text(390, 0, 'HUN'),
#   Text(391, 0, 'HUN'),
#   Text(392, 0, 'HUN'),
#   Text(393, 0, 'HUN'),
#   Text(394, 0, 'HUN'),
#   Text(395, 0, 'HUN'),
#   Text(396, 0, 'HUN'),
#   Text(397, 0, 'HUN'),
#   Text(398, 0, 'HUN'),
#   Text(399, 0, 'HUN'),
#   Text(400, 0, 'HUN'),
#   Text(401, 0, 'HUN'),
#   Text(402, 0, 'HUN'),
#   Text(403, 0, 'HUN'),
#   Text(404, 0, 'HUN'),
#   Text(405, 0, 'HUN'),
#   Text(406, 0, 'HUN'),
#   Text(407, 0, 'HUN'),
#   Text(408, 0, 'HUN'),
#   Text(409, 0, 'HUN'),
#   Text(410, 0, 'HUN'),
#   Text(411, 0, 'HUN'),
#   Text(412, 0, 'IRL'),
#   Text(413, 0, 'IRL'),
#   Text(414, 0, 'IRL'),
#   Text(415, 0, 'IRL'),
#   Text(416, 0, 'IRL'),
#   Text(417, 0, 'IRL'),
#   Text(418, 0, 'IRL'),
#   Text(419, 0, 'IRL'),
#   Text(420, 0, 'IRL'),
#   Text(421, 0, 'IRL'),
#   Text(422, 0, 'IRL'),
#   Text(423, 0, 'IRL'),
#   Text(424, 0, 'IRL'),
#   Text(425, 0, 'IRL'),
#   Text(426, 0, 'IRL'),
#   Text(427, 0, 'IRL'),
#   Text(428, 0, 'IRL'),
#   Text(429, 0, 'IRL'),
#   Text(430, 0, 'ISL'),
#   Text(431, 0, 'ISL'),
#   Text(432, 0, 'ISL'),
#   Text(433, 0, 'ISL'),
#   Text(434, 0, 'ISL'),
#   Text(435, 0, 'ISL'),
#   Text(436, 0, 'ISL'),
#   Text(437, 0, 'ISL'),
#   Text(438, 0, 'ISL'),
#   Text(439, 0, 'ISL'),
#   Text(440, 0, 'ISL'),
#   Text(441, 0, 'ISL'),
#   Text(442, 0, 'ISL'),
#   Text(443, 0, 'ISL'),
#   Text(444, 0, 'ISL'),
#   Text(445, 0, 'ISL'),
#   Text(446, 0, 'ISL'),
#   Text(447, 0, 'ISL'),
#   Text(448, 0, 'ISL'),
#   Text(449, 0, 'ISL'),
#   Text(450, 0, 'ISL'),
#   Text(451, 0, 'ISL'),
#   Text(452, 0, 'ISL'),
#   Text(453, 0, 'ISL'),
#   Text(454, 0, 'ISR'),
#   Text(455, 0, 'ISR'),
#   Text(456, 0, 'ISR'),
#   Text(457, 0, 'ISR'),
#   Text(458, 0, 'ISR'),
#   Text(459, 0, 'ISR'),
#   Text(460, 0, 'ISR'),
#   Text(461, 0, 'ISR'),
#   Text(462, 0, 'ISR'),
#   Text(463, 0, 'ISR'),
#   Text(464, 0, 'ISR'),
#   Text(465, 0, 'ISR'),
#   Text(466, 0, 'ISR'),
#   Text(467, 0, 'ISR'),
#   Text(468, 0, 'ISR'),
#   Text(469, 0, 'ISR'),
#   Text(470, 0, 'ISR'),
#   Text(471, 0, 'ISR'),
#   Text(472, 0, 'ISR'),
#   Text(473, 0, 'ISR'),
#   Text(474, 0, 'ISR'),
#   Text(475, 0, 'ISR'),
#   Text(476, 0, 'ISR'),
#   Text(477, 0, 'ISR'),
#   Text(478, 0, 'ISR'),
#   Text(479, 0, 'ISR'),
#   Text(480, 0, 'ISR'),
#   Text(481, 0, 'ISR'),
#   Text(482, 0, 'ISR'),
#   Text(483, 0, 'ISR'),
#   Text(484, 0, 'ISR'),
#   Text(485, 0, 'ISR'),
#   Text(486, 0, 'ISR'),
#   Text(487, 0, 'ISR'),
#   Text(488, 0, 'ISR'),
#   Text(489, 0, 'ISR'),
#   Text(490, 0, 'ITA'),
#   Text(491, 0, 'ITA'),
#   Text(492, 0, 'ITA'),
#   Text(493, 0, 'ITA'),
#   Text(494, 0, 'ITA'),
#   Text(495, 0, 'ITA'),
#   Text(496, 0, 'ITA'),
#   Text(497, 0, 'ITA'),
#   Text(498, 0, 'ITA'),
#   Text(499, 0, 'ITA'),
#   Text(500, 0, 'KOR'),
#   Text(501, 0, 'KOR'),
#   Text(502, 0, 'KOR'),
#   Text(503, 0, 'KOR'),
#   Text(504, 0, 'KOR'),
#   Text(505, 0, 'KOR'),
#   Text(506, 0, 'KOR'),
#   Text(507, 0, 'KOR'),
#   Text(508, 0, 'KOR'),
#   Text(509, 0, 'KOR'),
#   Text(510, 0, 'KOR'),
#   Text(511, 0, 'KOR'),
#   Text(512, 0, 'KOR'),
#   Text(513, 0, 'KOR'),
#   Text(514, 0, 'KOR'),
#   Text(515, 0, 'KOR'),
#   Text(516, 0, 'KOR'),
#   Text(517, 0, 'KOR'),
#   Text(518, 0, 'LTU'),
#   Text(519, 0, 'LTU'),
#   Text(520, 0, 'LTU'),
#   Text(521, 0, 'LTU'),
#   Text(522, 0, 'LTU'),
#   Text(523, 0, 'LTU'),
#   Text(524, 0, 'LTU'),
#   Text(525, 0, 'LTU'),
#   Text(526, 0, 'LTU'),
#   Text(527, 0, 'LTU'),
#   Text(528, 0, 'LTU'),
#   Text(529, 0, 'LTU'),
#   Text(530, 0, 'LTU'),
#   Text(531, 0, 'LTU'),
#   Text(532, 0, 'LTU'),
#   Text(533, 0, 'LTU'),
#   Text(534, 0, 'LTU'),
#   Text(535, 0, 'LTU'),
#   Text(536, 0, 'LTU'),
#   Text(537, 0, 'LTU'),
#   Text(538, 0, 'LTU'),
#   Text(539, 0, 'LTU'),
#   Text(540, 0, 'LTU'),
#   Text(541, 0, 'LTU'),
#   Text(542, 0, 'LTU'),
#   Text(543, 0, 'LTU'),
#   Text(544, 0, 'LTU'),
#   Text(545, 0, 'LTU'),
#   Text(546, 0, 'LTU'),
#   Text(547, 0, 'LTU'),
#   Text(548, 0, 'LTU'),
#   Text(549, 0, 'LTU'),
#   Text(550, 0, 'LTU'),
#   Text(551, 0, 'LTU'),
#   Text(552, 0, 'LTU'),
#   Text(553, 0, 'LTU'),
#   Text(554, 0, 'LUX'),
#   Text(555, 0, 'LUX'),
#   Text(556, 0, 'LUX'),
#   Text(557, 0, 'LUX'),
#   Text(558, 0, 'LUX'),
#   Text(559, 0, 'LUX'),
#   Text(560, 0, 'LUX'),
#   Text(561, 0, 'LUX'),
#   Text(562, 0, 'LUX'),
#   Text(563, 0, 'LUX'),
#   Text(564, 0, 'LUX'),
#   Text(565, 0, 'LUX'),
#   Text(566, 0, 'LUX'),
#   Text(567, 0, 'LUX'),
#   Text(568, 0, 'LUX'),
#   Text(569, 0, 'LUX'),
#   Text(570, 0, 'LUX'),
#   Text(571, 0, 'LUX'),
#   Text(572, 0, 'LUX'),
#   Text(573, 0, 'LUX'),
#   Text(574, 0, 'LUX'),
#   Text(575, 0, 'LUX'),
#   Text(576, 0, 'LUX'),
#   Text(577, 0, 'LUX'),
#   Text(578, 0, 'LUX'),
#   Text(579, 0, 'LUX'),
#   Text(580, 0, 'LUX'),
#   Text(581, 0, 'LUX'),
#   Text(582, 0, 'LUX'),
#   Text(583, 0, 'LUX'),
#   Text(584, 0, 'LUX'),
#   Text(585, 0, 'LUX'),
#   Text(586, 0, 'LUX'),
#   Text(587, 0, 'LUX'),
#   Text(588, 0, 'LUX'),
#   Text(589, 0, 'LUX'),
#   Text(590, 0, 'LVA'),
#   Text(591, 0, 'LVA'),
#   Text(592, 0, 'LVA'),
#   Text(593, 0, 'LVA'),
#   Text(594, 0, 'LVA'),
#   Text(595, 0, 'LVA'),
#   Text(596, 0, 'LVA'),
#   Text(597, 0, 'LVA'),
#   Text(598, 0, 'LVA'),
#   Text(599, 0, 'LVA'),
#   Text(600, 0, 'LVA'),
#   Text(601, 0, 'LVA'),
#   Text(602, 0, 'LVA'),
#   Text(603, 0, 'LVA'),
#   Text(604, 0, 'LVA'),
#   Text(605, 0, 'LVA'),
#   Text(606, 0, 'LVA'),
#   Text(607, 0, 'LVA'),
#   Text(608, 0, 'LVA'),
#   Text(609, 0, 'LVA'),
#   Text(610, 0, 'LVA'),
#   Text(611, 0, 'LVA'),
#   Text(612, 0, 'LVA'),
#   Text(613, 0, 'LVA'),
#   Text(614, 0, 'LVA'),
#   Text(615, 0, 'LVA'),
#   Text(616, 0, 'LVA'),
#   Text(617, 0, 'LVA'),
#   Text(618, 0, 'LVA'),
#   Text(619, 0, 'LVA'),
#   Text(620, 0, 'LVA'),
#   Text(621, 0, 'LVA'),
#   Text(622, 0, 'LVA'),
#   Text(623, 0, 'MEX'),
#   Text(624, 0, 'MEX'),
#   Text(625, 0, 'MEX'),
#   Text(626, 0, 'MEX'),
#   Text(627, 0, 'MEX'),
#   Text(628, 0, 'MEX'),
#   Text(629, 0, 'MEX'),
#   Text(630, 0, 'MEX'),
#   Text(631, 0, 'MEX'),
#   Text(632, 0, 'MEX'),
#   Text(633, 0, 'MEX'),
#   Text(634, 0, 'MEX'),
#   Text(635, 0, 'MEX'),
#   Text(636, 0, 'MEX'),
#   Text(637, 0, 'MEX'),
#   Text(638, 0, 'MEX'),
#   Text(639, 0, 'MEX'),
#   Text(640, 0, 'MEX'),
#   Text(641, 0, 'MEX'),
#   Text(642, 0, 'MEX'),
#   Text(643, 0, 'MEX'),
#   Text(644, 0, 'NLD'),
#   Text(645, 0, 'NLD'),
#   Text(646, 0, 'NLD'),
#   Text(647, 0, 'NLD'),
#   Text(648, 0, 'NLD'),
#   Text(649, 0, 'NLD'),
#   Text(650, 0, 'NLD'),
#   Text(651, 0, 'NLD'),
#   Text(652, 0, 'NLD'),
#   Text(653, 0, 'NLD'),
#   Text(654, 0, 'NLD'),
#   Text(655, 0, 'NLD'),
#   Text(656, 0, 'NLD'),
#   Text(657, 0, 'NLD'),
#   Text(658, 0, 'NLD'),
#   Text(659, 0, 'NLD'),
#   Text(660, 0, 'NLD'),
#   Text(661, 0, 'NLD'),
#   Text(662, 0, 'NLD'),
#   Text(663, 0, 'NLD'),
#   Text(664, 0, 'NLD'),
#   Text(665, 0, 'NLD'),
#   Text(666, 0, 'NLD'),
#   Text(667, 0, 'NLD'),
#   Text(668, 0, 'NLD'),
#   Text(669, 0, 'NLD'),
#   Text(670, 0, 'NLD'),
#   Text(671, 0, 'NOR'),
#   Text(672, 0, 'NOR'),
#   Text(673, 0, 'NOR'),
#   Text(674, 0, 'NOR'),
#   Text(675, 0, 'NOR'),
#   Text(676, 0, 'NOR'),
#   Text(677, 0, 'NOR'),
#   Text(678, 0, 'NOR'),
#   Text(679, 0, 'NOR'),
#   Text(680, 0, 'NOR'),
#   Text(681, 0, 'NOR'),
#   Text(682, 0, 'NOR'),
#   Text(683, 0, 'NOR'),
#   Text(684, 0, 'NOR'),
#   Text(685, 0, 'NOR'),
#   Text(686, 0, 'NOR'),
#   Text(687, 0, 'NOR'),
#   Text(688, 0, 'NOR'),
#   Text(689, 0, 'NOR'),
#   Text(690, 0, 'NOR'),
#   Text(691, 0, 'NOR'),
#   Text(692, 0, 'NOR'),
#   Text(693, 0, 'NOR'),
#   Text(694, 0, 'NOR'),
#   Text(695, 0, 'NOR'),
#   Text(696, 0, 'NOR'),
#   Text(697, 0, 'NOR'),
#   Text(698, 0, 'NOR'),
#   Text(699, 0, 'NOR'),
#   Text(700, 0, 'NOR'),
#   Text(701, 0, 'NOR'),
#   Text(702, 0, 'NOR'),
#   Text(703, 0, 'NOR'),
#   Text(704, 0, 'NOR'),
#   Text(705, 0, 'NOR'),
#   Text(706, 0, 'NOR'),
#   Text(707, 0, 'NZL'),
#   Text(708, 0, 'NZL'),
#   Text(709, 0, 'NZL'),
#   Text(710, 0, 'NZL'),
#   Text(711, 0, 'NZL'),
#   Text(712, 0, 'NZL'),
#   Text(713, 0, 'NZL'),
#   Text(714, 0, 'NZL'),
#   Text(715, 0, 'NZL'),
#   Text(716, 0, 'NZL'),
#   Text(717, 0, 'NZL'),
#   Text(718, 0, 'NZL'),
#   Text(719, 0, 'NZL'),
#   Text(720, 0, 'NZL'),
#   Text(721, 0, 'NZL'),
#   Text(722, 0, 'NZL'),
#   Text(723, 0, 'NZL'),
#   Text(724, 0, 'NZL'),
#   Text(725, 0, 'NZL'),
#   Text(726, 0, 'NZL'),
#   Text(727, 0, 'NZL'),
#   Text(728, 0, 'NZL'),
#   Text(729, 0, 'NZL'),
#   Text(730, 0, 'NZL'),
#   Text(731, 0, 'NZL'),
#   Text(732, 0, 'NZL'),
#   Text(733, 0, 'NZL'),
#   Text(734, 0, 'NZL'),
#   Text(735, 0, 'NZL'),
#   Text(736, 0, 'NZL'),
#   Text(737, 0, 'NZL'),
#   Text(738, 0, 'NZL'),
#   Text(739, 0, 'NZL'),
#   Text(740, 0, 'NZL'),
#   Text(741, 0, 'NZL'),
#   Text(742, 0, 'NZL'),
#   Text(743, 0, 'OAVG'),
#   Text(744, 0, 'OAVG'),
#   Text(745, 0, 'OAVG'),
#   Text(746, 0, 'OAVG'),
#   Text(747, 0, 'OAVG'),
#   Text(748, 0, 'OAVG'),
#   Text(749, 0, 'OAVG'),
#   Text(750, 0, 'OAVG'),
#   Text(751, 0, 'OAVG'),
#   Text(752, 0, 'OAVG'),
#   Text(753, 0, 'OAVG'),
#   Text(754, 0, 'OAVG'),
#   Text(755, 0, 'OAVG'),
#   Text(756, 0, 'OAVG'),
#   Text(757, 0, 'OAVG'),
#   Text(758, 0, 'OAVG'),
#   Text(759, 0, 'OAVG'),
#   Text(760, 0, 'OAVG'),
#   Text(761, 0, 'OAVG'),
#   Text(762, 0, 'OAVG'),
#   Text(763, 0, 'OAVG'),
#   Text(764, 0, 'OAVG'),
#   Text(765, 0, 'OAVG'),
#   Text(766, 0, 'OAVG'),
#   Text(767, 0, 'OAVG'),
#   Text(768, 0, 'OAVG'),
#   Text(769, 0, 'OAVG'),
#   Text(770, 0, 'POL'),
#   Text(771, 0, 'POL'),
#   Text(772, 0, 'POL'),
#   Text(773, 0, 'POL'),
#   Text(774, 0, 'POL'),
#   Text(775, 0, 'POL'),
#   Text(776, 0, 'POL'),
#   Text(777, 0, 'POL'),
#   Text(778, 0, 'POL'),
#   Text(779, 0, 'POL'),
#   Text(780, 0, 'POL'),
#   Text(781, 0, 'POL'),
#   Text(782, 0, 'POL'),
#   Text(783, 0, 'POL'),
#   Text(784, 0, 'POL'),
#   Text(785, 0, 'POL'),
#   Text(786, 0, 'POL'),
#   Text(787, 0, 'POL'),
#   Text(788, 0, 'POL'),
#   Text(789, 0, 'POL'),
#   Text(790, 0, 'POL'),
#   Text(791, 0, 'POL'),
#   Text(792, 0, 'POL'),
#   Text(793, 0, 'POL'),
#   Text(794, 0, 'POL'),
#   Text(795, 0, 'POL'),
#   Text(796, 0, 'POL'),
#   Text(797, 0, 'POL'),
#   Text(798, 0, 'POL'),
#   Text(799, 0, 'POL'),
#   Text(800, 0, 'POL'),
#   Text(801, 0, 'POL'),
#   Text(802, 0, 'POL'),
#   Text(803, 0, 'POL'),
#   Text(804, 0, 'POL'),
#   Text(805, 0, 'POL'),
#   Text(806, 0, 'PRT'),
#   Text(807, 0, 'PRT'),
#   Text(808, 0, 'PRT'),
#   Text(809, 0, 'PRT'),
#   Text(810, 0, 'PRT'),
#   Text(811, 0, 'PRT'),
#   Text(812, 0, 'PRT'),
#   Text(813, 0, 'PRT'),
#   Text(814, 0, 'PRT'),
#   Text(815, 0, 'PRT'),
#   Text(816, 0, 'PRT'),
#   Text(817, 0, 'PRT'),
#   Text(818, 0, 'PRT'),
#   Text(819, 0, 'PRT'),
#   Text(820, 0, 'PRT'),
#   Text(821, 0, 'PRT'),
#   Text(822, 0, 'PRT'),
#   Text(823, 0, 'PRT'),
#   Text(824, 0, 'PRT'),
#   Text(825, 0, 'PRT'),
#   Text(826, 0, 'PRT'),
#   Text(827, 0, 'PRT'),
#   Text(828, 0, 'PRT'),
#   Text(829, 0, 'PRT'),
#   Text(830, 0, 'PRT'),
#   Text(831, 0, 'PRT'),
#   Text(832, 0, 'PRT'),
#   Text(833, 0, 'PRT'),
#   Text(834, 0, 'PRT'),
#   Text(835, 0, 'PRT'),
#   Text(836, 0, 'PRT'),
#   Text(837, 0, 'PRT'),
#   Text(838, 0, 'PRT'),
#   Text(839, 0, 'PRT'),
#   Text(840, 0, 'SVK'),
#   Text(841, 0, 'SVK'),
#   Text(842, 0, 'SVK'),
#   Text(843, 0, 'SVK'),
#   Text(844, 0, 'SVK'),
#   Text(845, 0, 'SVK'),
#   Text(846, 0, 'SVK'),
#   Text(847, 0, 'SVK'),
#   Text(848, 0, 'SVK'),
#   Text(849, 0, 'SVK'),
#   Text(850, 0, 'SVK'),
#   Text(851, 0, 'SVK'),
#   Text(852, 0, 'SVK'),
#   Text(853, 0, 'SVK'),
#   Text(854, 0, 'SVK'),
#   Text(855, 0, 'SVK'),
#   Text(856, 0, 'SVK'),
#   Text(857, 0, 'SVK'),
#   Text(858, 0, 'SVK'),
#   Text(859, 0, 'SVK'),
#   Text(860, 0, 'SVK'),
#   Text(861, 0, 'SVK'),
#   Text(862, 0, 'SVK'),
#   Text(863, 0, 'SVK'),
#   Text(864, 0, 'SVK'),
#   Text(865, 0, 'SVK'),
#   Text(866, 0, 'SVK'),
#   Text(867, 0, 'SVK'),
#   Text(868, 0, 'SVK'),
#   Text(869, 0, 'SVK'),
#   Text(870, 0, 'SVK'),
#   Text(871, 0, 'SVK'),
#   Text(872, 0, 'SVK'),
#   Text(873, 0, 'SVK'),
#   Text(874, 0, 'SVK'),
#   Text(875, 0, 'SVK'),
#   Text(876, 0, 'SVN'),
#   Text(877, 0, 'SVN'),
#   Text(878, 0, 'SVN'),
#   Text(879, 0, 'SVN'),
#   Text(880, 0, 'SVN'),
#   Text(881, 0, 'SVN'),
#   Text(882, 0, 'SVN'),
#   Text(883, 0, 'SVN'),
#   Text(884, 0, 'SVN'),
#   Text(885, 0, 'SVN'),
#   Text(886, 0, 'SVN'),
#   Text(887, 0, 'SVN'),
#   Text(888, 0, 'SVN'),
#   Text(889, 0, 'SVN'),
#   Text(890, 0, 'SVN'),
#   Text(891, 0, 'SVN'),
#   Text(892, 0, 'SVN'),
#   Text(893, 0, 'SVN'),
#   Text(894, 0, 'SVN'),
#   Text(895, 0, 'SVN'),
#   Text(896, 0, 'SVN'),
#   Text(897, 0, 'SVN'),
#   Text(898, 0, 'SWE'),
#   Text(899, 0, 'SWE'),
#   Text(900, 0, 'SWE'),
#   Text(901, 0, 'SWE'),
#   Text(902, 0, 'SWE'),
#   Text(903, 0, 'SWE'),
#   Text(904, 0, 'SWE'),
#   Text(905, 0, 'SWE'),
#   Text(906, 0, 'SWE'),
#   Text(907, 0, 'SWE'),
#   Text(908, 0, 'SWE'),
#   Text(909, 0, 'SWE'),
#   Text(910, 0, 'SWE'),
#   Text(911, 0, 'SWE'),
#   Text(912, 0, 'SWE'),
#   Text(913, 0, 'SWE'),
#   Text(914, 0, 'SWE'),
#   Text(915, 0, 'SWE'),
#   Text(916, 0, 'SWE'),
#   Text(917, 0, 'SWE'),
#   Text(918, 0, 'SWE'),
#   Text(919, 0, 'SWE'),
#   Text(920, 0, 'SWE'),
#   Text(921, 0, 'SWE'),
#   Text(922, 0, 'SWE'),
#   Text(923, 0, 'SWE'),
#   Text(924, 0, 'SWE'),
#   Text(925, 0, 'SWE'),
#   Text(926, 0, 'SWE'),
#   Text(927, 0, 'SWE'),
#   Text(928, 0, 'SWE'),
#   Text(929, 0, 'SWE'),
#   Text(930, 0, 'SWE'),
#   Text(931, 0, 'SWE'),
#   Text(932, 0, 'SWE'),
#   Text(933, 0, 'SWE'),
#   Text(934, 0, 'TUR'),
#   Text(935, 0, 'TUR'),
#   Text(936, 0, 'TUR'),
#   Text(937, 0, 'TUR'),
#   Text(938, 0, 'TUR'),
#   Text(939, 0, 'TUR'),
#   Text(940, 0, 'TUR'),
#   Text(941, 0, 'TUR'),
#   Text(942, 0, 'TUR'),
#   Text(943, 0, 'TUR'),
#   Text(944, 0, 'TUR'),
#   Text(945, 0, 'TUR'),
#   Text(946, 0, 'TUR'),
#   Text(947, 0, 'TUR'),
#   Text(948, 0, 'TUR'),
#   Text(949, 0, 'TUR'),
#   Text(950, 0, 'TUR'),
#   Text(951, 0, 'TUR'),
#   Text(952, 0, 'TUR'),
#   Text(953, 0, 'TUR'),
#   Text(954, 0, 'TUR'),
#   Text(955, 0, 'TUR'),
#   Text(956, 0, 'TUR'),
#   Text(957, 0, 'TUR'),
#   Text(958, 0, 'TUR'),
#   Text(959, 0, 'TUR'),
#   Text(960, 0, 'TUR'),
#   Text(961, 0, 'TUR'),
#   Text(962, 0, 'TUR'),
#   Text(963, 0, 'TUR'),
#   Text(964, 0, 'TUR'),
#   Text(965, 0, 'TUR'),
#   Text(966, 0, 'TUR'),
#   Text(967, 0, 'TUR'),
#   Text(968, 0, 'USA'),
#   Text(969, 0, 'USA'),
#   Text(970, 0, 'USA'),
#   Text(971, 0, 'USA'),
#   Text(972, 0, 'USA'),
#   Text(973, 0, 'USA'),
#   Text(974, 0, 'USA'),
#   Text(975, 0, 'USA'),
#   Text(976, 0, 'USA'),
#   Text(977, 0, 'USA'),
#   Text(978, 0, 'USA'),
#   Text(979, 0, 'USA'),
#   Text(980, 0, 'USA'),
#   Text(981, 0, 'USA'),
#   Text(982, 0, 'USA'),
#   Text(983, 0, 'USA'),
#   Text(984, 0, 'USA'),
#   Text(985, 0, 'USA'),
#   Text(986, 0, 'USA'),
#   Text(987, 0, 'USA'),
#   Text(988, 0, 'USA'),
#   Text(989, 0, 'USA'),
#   Text(990, 0, 'USA'),
#   Text(991, 0, 'USA'),
#   Text(992, 0, 'USA'),
#   Text(993, 0, 'USA'),
#   Text(994, 0, 'USA'),
#   Text(995, 0, 'USA'),
#   Text(996, 0, 'USA'),
#   Text(997, 0, 'USA'),
#   Text(998, 0, 'USA'),
#   Text(999, 0, 'USA'),
#   ...])
